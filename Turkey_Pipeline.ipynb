# %%
import os
import pickle

from datetime import timedelta
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
import graph_tool.all as gt
TURKEY_DIR = '/pool001/jschless/turkish_astroturfing'
follower_data_dir = os.path.join(TURKEY_DIR, 'follower_info')

# %% [markdown]
# # Build Follower Network

# %%
# Get unique users and make a dictionary mapping them to a unique number
df = pd.read_csv(os.path.join(TURKEY_DIR, 'trend_tweets.csv'))
uids = {k: v for v, k in enumerate(df.author_id.unique())}

# %%
# Build list of directed edges 
edges = []
for fi in os.listdir(follower_data_dir):
    user = uids.get(int(fi[:-4]), None)  
    if user is None:
        raise Exception(f"User id {fi[:-4]} not in dictionary")

    if os.path.getsize(os.path.join(follower_data_dir, fi)) > 0: # make sure file isn't empty
        with open(os.path.join(follower_data_dir, fi), 'rb') as f:
            followers = pickle.load(f)
            edges += [(uids[fol], user) for fol in followers if fol in uids]

# %%
# Build graph
g = gt.Graph(directed=True)
g.add_edge_list(edges)
g

# %% [markdown]
# # Load Tweet Information

# %%
df = pd.read_csv(os.path.join(TURKEY_DIR, 'trend_tweets.csv'),
                parse_dates=['date', 'trend_date', 'created_at'])
df.head()
# Out:
#             author_id          created_at       date                   id  \
# 0  895667392533102592 2019-06-15 00:02:42 2019-06-15  1139684621174505474
# 1  895667392533102592 2019-06-15 00:02:42 2019-06-15  1139684621174505474
# 2            18865007 2019-06-15 00:02:47 2019-06-15  1139684642137628672
# 3            18865007 2019-06-15 00:02:47 2019-06-15  1139684642137628672
# 4          2636562654 2019-06-15 00:03:29 2019-06-15  1139684818323591170
#
#                                                 text  \
# 0  RT @rbklndr: Türkiye Belediyeler Birliği Başka...
# 1  RT @rbklndr: Türkiye Belediyeler Birliği Başka...
# 2  ... belki de en önemli sınavını verecek Tite'n...
# 3  ... belki de en önemli sınavını verecek Tite'n...
# 4  RT @kacsaatolduson: Rabia Naz için verilen ara...
#
#                          trend trend_date tweet_type
# 0                    başarılar 2019-06-14    retweet
# 1  Türkiye Belediyeler Birliği 2019-06-13    retweet
# 2                 #CopaAmerica 2019-06-15      tweet
# 3                 #CopaAmerica 2019-06-14      tweet
# 4                    Rabia Naz 2019-06-14    retweet

# %%
# convert to {hashtag => [tweets]}
campaigns = df.groupby("trend").apply(lambda x: x.to_dict(orient="records")).to_dict()

# %%
# get exposures
def is_following(child, parent):
    # returns true if child is following parent
    child_id = uids.get(child, None)
    parent_id = uids.get(parent, None)
    if child_id is None or parent_id is None:
        return False

    try: 
        return g.edge(child_id, parent_id) is not None
    except ValueError as e:
        print(e, 'probably missing follower information') 
        return False

exposures = {}
for ht, tweets in tqdm(campaigns.items()):
    ht_exposures = {}

    # sort tweets in reverse order 
    sorted_tweets = sorted(tweets, key=lambda x: x['date'])[::-1]
    for i in range(len(sorted_tweets)):
        n_exposures = 0
        child = sorted_tweets[i]
        for j in range(i, len(sorted_tweets)):
            # loop through all tweets that happened before
            potential_parent = sorted_tweets[j]
            if is_following(child['author_id'], potential_parent['author_id']):
                n_exposures += 1

        ht_exposures[child['author_id']] = n_exposures

    exposures[ht] = ht_exposures
# Out:
#   0%|          | 0/17160 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0c77138c32d2> in <module>
#      25             # loop through all tweets that happened before
#      26             potential_parent = sorted_tweets[j]
# ---> 27             if is_following(child['author_id'], potential_parent['author_id']):
#      28                 n_exposures += 1
#      29
#
# <ipython-input-4-0c77138c32d2> in is_following(child, parent)
#       2 def is_following(child, parent):
#       3     # returns true if child is following parent
# ----> 4     child_id = uids.get(child, None)
#       5     parent_id = uids.get(parent, None)
#       6     if child_id is None or parent_id is None:
#
# NameError: name 'uids' is not defined

# %% [markdown]
# # Process Trending Information

# %%
trend_file = 'trend_analysis_top10.csv' 
#trend_file = 'world_trend_analysis_top10.csv'

trending_info = pd.read_csv(os.path.join(TURKEY_DIR, trend_file),
                           parse_dates=['tr_start', 'tr_end', 'lifetime', 'date'])

trending_info['trend'] = trending_info.keyword

trending_info = trending_info.drop(columns=['date', 'id', 'keyword'])

trending_info.head()
# Out:
#              tr_start              tr_end     vol  max_rank  \
# 0 2019-06-27 06:14:01 2019-06-27 08:09:03      -1         8
# 1 2019-06-20 18:38:28 2019-06-20 22:24:33   14474         1
# 2 2019-06-20 22:29:29 2019-06-20 23:59:37   14495         6
# 3 2019-07-15 04:12:22 2019-07-15 13:02:52  118537         1
# 4 2019-07-15 13:32:57 2019-07-15 13:47:54  124473         1
#
#                     lifetime  attack                      trend
# 0  0 days 01:55:02.000000000   False                    "Maçka"
# 1  0 days 03:46:05.000000000    True  #1200ÜcretliAtamasıHaktır
# 2  0 days 01:30:08.000000000   False  #1200ücretliatamasıhaktır
# 3  0 days 08:50:30.000000000   False           #15TEMMUZDESTANI
# 4  0 days 00:14:57.000000000   False           #15TEMMUZDESTANI

# %%
import emoji
import string

def give_emoji_free_text(text):
    allchars = [str for str in text]
    emoji_list = [c for c in allchars if c in emoji.UNICODE_EMOJI]
    clean_text = ' '.join([str for str in text.split() if not any(i in str for i in emoji_list)])

    return clean_text

def lexicon_classifier(line, trend):
    line = give_emoji_free_text(line)
    line = line.replace(trend, '')
    line = line.replace('  ', ' ')

    line = line.strip()

    if (len(line) == 0):
        return False

    if (line[0].isupper()):
        return False

    invalidChars = set(string.punctuation.replace("(", "…").replace(")", "...").replace('.', ".").replace('.', '.'))
    invalidChars = invalidChars.union(set(["%d" % i for i in range(0,10)])) # added numbers

    if any(char in invalidChars for char in line):
        return False

    tokens = line.split(' ')
    if (len(tokens) > 10 or len(tokens) < 3):
        return False



    return True

# %%
mega_df = df.merge(trending_info, on='trend')
mega_df["time_since_trending"] = mega_df.created_at - mega_df.tr_start
mega_df["time_since_trending"] = mega_df.time_since_trending.apply(lambda x: int(x.total_seconds() / 60))
mega_df["lexicon"] = mega_df.apply(lambda x: lexicon_classifier(x.text, x.trend), axis=1)


# Filtering
mega_df = mega_df[mega_df.attack == True] # only interested in attacked trends 
mega_df = mega_df.dropna()
mega_df.head()
# Out:
#        author_id          created_at       date                   id  \
# 98373  622902679 2019-06-15 02:00:50 2019-06-15  1139522012223852544
# 98374  622902679 2019-06-15 02:00:50 2019-06-15  1139522012223852544
# 98375  622902679 2019-06-15 02:00:50 2019-06-15  1139522012223852544
# 98376  622902679 2019-06-15 02:00:50 2019-06-15  1139522012223852544
# 98377  622902679 2019-06-15 02:00:50 2019-06-15  1139522012223852544
#
#                                                     text             trend  \
# 98373  RT @umutmurare: Trabzon’un yiğit evladı Şehit ...  #İyikiVarsınEren
# 98374  RT @umutmurare: Trabzon’un yiğit evladı Şehit ...  #İyikiVarsınEren
# 98375  RT @umutmurare: Trabzon’un yiğit evladı Şehit ...  #İyikiVarsınEren
# 98376  RT @umutmurare: Trabzon’un yiğit evladı Şehit ...  #İyikiVarsınEren
# 98377  RT @umutmurare: Trabzon’un yiğit evladı Şehit ...  #İyikiVarsınEren
#
#       trend_date tweet_type            tr_start              tr_end  vol  \
# 98373 2019-06-14   deletion 2019-07-02 20:44:22 2019-07-02 21:15:12   -1
# 98374 2019-06-14   deletion 2019-07-02 21:33:37 2019-07-02 21:48:40   -1
# 98375 2019-06-14   deletion 2019-07-02 21:58:30 2019-07-03 00:53:17   -1
# 98376 2019-06-15   deletion 2019-07-02 20:44:22 2019-07-02 21:15:12   -1
# 98377 2019-06-15   deletion 2019-07-02 21:33:37 2019-07-02 21:48:40   -1
#
#        max_rank                   lifetime  attack  time_since_trending  \
# 98373         1  0 days 00:30:50.000000000    True               -25603
# 98374         3  0 days 00:15:03.000000000    True               -25652
# 98375         3  0 days 02:54:47.000000000    True               -25677
# 98376         1  0 days 00:30:50.000000000    True               -25603
# 98377         3  0 days 00:15:03.000000000    True               -25652
#
#        lexicon
# 98373    False
# 98374    False
# 98375    False
# 98376    False
# 98377    False

# %%
astrobots = set(mega_df.query('lexicon == True').author_id.unique())

# %%
len(astrobots)
# Out:
# 7260

# %%
pd.set_option('display.max_colwidth', None)

# %%
plt.hist(mega_df.query('time_since_trending < 0').groupby('author_id').count().id)
# Out:
# (array([1.3547e+04, 1.8770e+03, 6.1500e+02, 2.0600e+02, 6.3000e+01,
#         2.5000e+01, 5.0000e+00, 1.0000e+00, 2.0000e+00, 3.0000e+00]),
#  array([  1. ,  24.7,  48.4,  72.1,  95.8, 119.5, 143.2, 166.9, 190.6,
#         214.3, 238. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Build timeseries

# %%
unique_authors = set()
def build_df(hashtag, tweet_dict, 
             include_missing=True, time_bin='5Min', minutes_to_round=5,
             drop_astrobots=True):
    for tweet in tweet_dict:
        # annotate whether we have follower information for user
        follower_file = os.path.join(follower_data_dir, str(tweet['author_id']) + '.txt') 
        tweet['follower_data'] = os.path.isfile(follower_file) and os.path.getsize(follower_file) > 0 
        
        # annotate number of exposures before posting
        tweet['n_exposures'] = 0 #exposures[hashtag][tweet['author_id']]

    df = pd.DataFrame.from_dict(tweet_dict)
    df.index = pd.to_datetime(df['created_at'])

    if not include_missing: 
        # Remove tweets from users lacking follower info
        df = df[df.follower_data == True]
        
    if drop_astrobots:
        df = df[~df.author_id.isin(astrobots)]
        

    trending_data = trending_info[trending_info.trend == hashtag]
    
    if len(trending_data) == 0: # hashtag never trended
        return 
    elif len(df) == 0: # trended but all tweets were removed because of missing follower data
        return
    elif trending_data.iloc[0].attack == False: # wasn't attacked
        return 

    start, end = trending_data.iloc[0].tr_start, trending_data.iloc[0].tr_end
    start = start - timedelta(minutes=start.minute % minutes_to_round,
                              seconds=start.second,
                              microseconds=start.microsecond)


    global unique_authors
    for a in df[df.tweet_type == "tweet"].author_id.unique():
        unique_authors.add(a)

    
    # Binning various statistics of interest
    series_list = []
    types = ['tweet', 'retweet', 'deletion']
    
    for t in types:
        temp = df[df.tweet_type == t] 
        temp = temp.resample(time_bin).count().author_id
        series_list.append(temp)
        
    temp = df[df.tweet_type == 'tweet']
    temp = temp[temp.n_exposures == 0].resample(time_bin).count().author_id
    
    
    series_list.append(temp)
    
    #return df, min_date, max_date
    
    new_df = pd.DataFrame(series_list).T
    new_df.columns = [*types, 'zero_exposure_tweets']
    
    # normalize time to minutes before / after trend
    new_df['absolute_time'] = new_df.index
    new_df.index = new_df.index - start
    new_df.index = new_df.index.map(lambda x: int(x.total_seconds() / 60))

    # add additional info to dataset
    new_df['trend'] = hashtag
    new_df['time'] = new_df.index
    new_df['time_i'] = range(len(new_df))
    new_df['trending_start'] = start

    return new_df

# %%
dfs = []
for trend, tweets in tqdm(campaigns.items()):
    if len(tweets) > 1000:
        temp_df = build_df(trend, tweets,
                          time_bin='5Min', minutes_to_round=5)

        if not temp_df is None:
            temp_df = temp_df.assign(threshold=(temp_df.time > 0).astype(int))
            dfs.append(temp_df)
panel_df = pd.concat(dfs)
# Out:
# 100%|██████████| 17160/17160 [00:15<00:00, 1142.74it/s]

# %%
with open('authors.pkl', 'wb') as f:
    pickle.dump(unique_authors, f)

# %%
ls
# Out:
# a4.html
# a4.js
# a4_new.js
# Advanced_Trending_Statistics.ipynb
# Alternate_Attribution_Methods.ipynb
# Analysis_of_Attribution_Models.ipynb
# authors.pkl
# build_cascades.py
# campaign_cascades.pkl
# Campaign_Characterization.ipynb
# cascade.py
# clustering.py
# clustering.py~
# Clustering_Tweets.ipynb
# color-legend.js
# colorlegend.js
# config.py
# d3-annotation.js
# data/
# Digraph.gv
# Digraph.gv.pdf
# encode_sentences.py
# Exploration.ipynb
# Exposure_Curves.ipynb
# exposure_script.py
# exposure_script.py~
# exposure_script_rt_and_nt.py
# follower_hydration.py
# Follower_Network.ipynb
# Hashtag_Cascades_Aggregate.ipynb
# Hashtag_Cascades_Case_Study.ipynb
# hashtags.py
# hdbscan_script.py
# imports.py
# index.html
# index.php
# main.css
# nearest_neighbors_revised.py
# nearest_neighbors_script2.py
# nearest_neighbors_script_local2.py
# nearest_neighbors_script_local.py
# nearest_neighbors_script.py
# network_plots.py
# new_network_exposures.py
# normal_tweet_popularity_by_user_type.png
# plots/
# plotting.py
# preprocessing.py
# __pycache__/
# README.md
# RT_Cascades.ipynb
# Semantic_Similarity_Aggregate.ipynb
# SemanticSimilarity.ipynb
# Sentence_Transformers.ipynb
# Sentence_Transformers.py
# Sentence_Transformers.py~
# specification_curve_2.py
# specification_curve.py
# table.tex
# temp.graphml
# temp.html
# temp.jpeg
# Templated_Tweets_v_Regular_Tweets.ipynb
# temp.pdf
# temp.png
# test.js
# test_pickle.pkl
# #THESIS_Preliminary_Findings.ipynb#
# THESIS_Preliminary_Findings.ipynb
# THESIS_Specification_Curve.ipynb
# THESIS_Trending_Effect.ipynb
# THESIS_Trending_Effect_Qualitative-Copy1.ipynb
# THESIS_Trending_Effect_Qualitative.ipynb
# THESIS_Trending_Effect_Table_Regressions.ipynb
# Time_to_trend.ipynb
# top_tweets_by_user.png
# top_tweets.pkl
# Trending_Effect_Individual_Removing_Uncertainty.ipynb
# Trending_Event_Study.ipynb
# trending.py
# Trending_Topics_Causal_Impact_Gen2.ipynb
# Trending_Topics_Causal_Impact.ipynb
# Trending_Topics_Causal_Impact_Robustness_Bins.ipynb
# Trending_Topics_Causal_Impact_Robustness_Treatment_Time.ipynb
# Trending_Topics_Causal_Impact_Trending_Position.ipynb
# Turkey_Pipeline.ipynb
# Turkey_User_Hydration.ipynb
# tweet.py
# Untitled.ipynb
# Visualize_Adjacency_Matrix.ipynb
# Visualize_Huge_Network.ipynb
# Visualizing_Trending_Effect.ipynb

# %%
len(unique_authors)
# Out:
# 7499

# %% [markdown]
# ### Plotting

# %%
import trending, statsmodels.formula.api as smf

# %%
import seaborn as sns

sns.set(style="darkgrid")

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="time", y="tweet",
             data=panel_df.loc[(panel_df.index>-60)&(panel_df.index<120)])
sns.lineplot(x="time", y="deletion",
             data=panel_df.loc[(panel_df.index>-60)&(panel_df.index<120)])

plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(15,5))
trending.plot_event_study(panel_df, cat='deletion', lower=-120, upper=120)

# %%
plt.figure(figsize=(15,5))
trending.plot_event_study(panel_df, cat='tweet', lower=-120, upper=240)
plt.grid()

# %% [markdown]
# ## Statistical Analysis

# %%
from statsmodels.formula.api import poisson
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.formula.api import negativebinomial
query = panel_df.query('time >= -120 & time <= 180').fillna(0)
#query.loc[query.time < 0, 'tweet'] = 0
query.trend = pd.Categorical(query.trend).codes
query = query.dropna()

formula_string = "tweet ~ time*threshold"

query['ln_tweet'] = np.log(query.tweet + 1)

ols = smf.ols(formula_string, data=query).fit(
    cov_type='cluster', cov_kwds={'groups': query['trend']})


re = smf.mixedlm(formula_string, data=query, groups=query['trend']).fit()
re_ln = smf.mixedlm('ln_' + formula_string, data=query, groups=query['trend']).fit()

pois = poisson(formula_string, data=query).fit()
negbin = negativebinomial(formula_string, data=query).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 2.560361
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 1.698223
#          Iterations: 20
#          Function evaluations: 27
#          Gradient evaluations: 27

# %%
np.exp(.294)
# Out:
# 1.3417839036669714

# %%
from statsmodels.iolib.summary2 import summary_col
summary_col([ols, re, re_ln, pois, negbin], 
           model_names=['OLS', 'Random Effects', 'Random Effects (logged outcome)', 'Poisson', 'Negative Binomial'])
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#
# =================================================================================================
#                  OLS    Random Effects Random Effects (logged outcome) Poisson  Negative Binomial
# -------------------------------------------------------------------------------------------------
# Group Var               0.4697         0.5432
#                         (0.1039)       (0.1195)
# Intercept      1.4663   1.4364         0.5891                          0.6465   0.5208
#                (0.2768) (0.3237)       (0.0872)                        (0.0709) (0.1458)
# R-squared      0.0453
#                0.0466
# alpha                                                                           2.7578
#                                                                                 (0.1415)
# threshold      0.9837   1.0175         0.2945                          0.2528   0.3770
#                (0.3332) (0.2360)       (0.0607)                        (0.0780) (0.1705)
# time           0.0156   0.0126         0.0042                          0.0330   0.0288
#                (0.0031) (0.0033)       (0.0008)                        (0.0025) (0.0034)
# time:threshold -0.0180  -0.0151        -0.0055                         -0.0340  -0.0298
#                (0.0042) (0.0035)       (0.0009)                        (0.0026) (0.0035)
# =================================================================================================
# Standard errors in parentheses.
# """

# %%
query.tweet.sum()
# Out:
# 4086.0

# %%
len(query.trend.unique())
# Out:
# 47

# %%
import trending
plt.figure(figsize=(15,5))
trending.plot_event_study(query, cat='tweet', lower=-120, upper=240)
plt.title("Turkish Astroturfed Trends Event Study")
# Out:
# Text(0.5, 1.0, 'Turkish Astroturfed Trends Event Study')

# %%
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  tweet   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     17.73
# Date:                Tue, 20 Apr 2021   Prob (F-statistic):           8.67e-08
# Time:                        12:14:46   Log-Likelihood:                -5437.3
# No. Observations:                2137   AIC:                         1.088e+04
# Df Residuals:                    2133   BIC:                         1.091e+04
# Df Model:                           3
# Covariance Type:              cluster
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          1.4663      0.277      5.298      0.000       0.924       2.009
# time               0.0156      0.003      5.064      0.000       0.010       0.022
# threshold          0.9837      0.333      2.952      0.003       0.331       1.637
# time:threshold    -0.0180      0.004     -4.252      0.000      -0.026      -0.010
# ==============================================================================
# Omnibus:                     1281.227   Durbin-Watson:                   0.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14722.135
# Skew:                           2.655   Prob(JB):                         0.00
# Kurtosis:                      14.711   Cond. No.                         716.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
query = panel_df.query('time >= 0 & time <= 120').fillna(0)
query.trend = pd.Categorical(query.trend).codes
query = query.dropna()

ols = smf.ols("tweet ~ time", data=query).fit(
    cov_type='cluster', cov_kwds={'groups': query['trend']})
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  tweet   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4765
# Date:                Tue, 20 Apr 2021   Prob (F-statistic):              0.493
# Time:                        12:11:53   Log-Likelihood:                -2919.1
# No. Observations:                1132   AIC:                             5842.
# Df Residuals:                    1130   BIC:                             5852.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.4395      0.340      7.180      0.000       1.774       3.105
# time          -0.0021      0.003     -0.690      0.490      -0.008       0.004
# ==============================================================================
# Omnibus:                      399.101   Durbin-Watson:                   1.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1198.499
# Skew:                           1.794   Prob(JB):                    5.61e-261
# Kurtosis:                       6.540   Cond. No.                         139.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
import numpy as np
query = panel_df.query('time >= 0 & time <= 120').fillna(0)
query.trend = pd.Categorical(query.trend).codes
query = query.dropna()
query['ln_tweet'] = np.log(query.tweet+1)
ols = smf.ols("ln_tweet ~ time", data=query).fit(
    cov_type='cluster', cov_kwds={'groups': query['trend']})
ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ln_tweet   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1931
# Date:                Tue, 20 Apr 2021   Prob (F-statistic):              0.662
# Time:                        08:38:51   Log-Likelihood:                -1558.6
# No. Observations:                1134   AIC:                             3121.
# Df Residuals:                    1132   BIC:                             3131.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9111      0.108      8.428      0.000       0.699       1.123
# time          -0.0004      0.001     -0.439      0.660      -0.002       0.002
# ==============================================================================
# Omnibus:                       85.240   Durbin-Watson:                   1.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.174
# Skew:                           0.741   Prob(JB):                     2.39e-23
# Kurtosis:                       2.925   Cond. No.                         138.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
df.created_at.describe()
# Out:
# count                   25366
# unique                  11091
# top       2019-09-01 05:59:50
# freq                       45
# Name: created_at, dtype: object

# %%
df.date
# Out:
# 0        2019-09-01
# 1        2019-09-01
# 2        2019-09-01
# 3        2019-09-01
# 4        2019-09-01
#             ...
# 25361    2019-09-01
# 25362    2019-09-01
# 25363    2019-09-01
# 25364    2019-09-01
# 25365    2019-09-01
# Name: date, Length: 25366, dtype: object

# %% [markdown]
# # Scratch

# %%
df.groupby("trend").size().sort_values(ascending=False).head(40)
# Out:
# trend
# #İnşaAllahBinali              13769
# İstanbul                      12064
# #BYvsEİ                       11023
# #KararMilletin                10045
# 15 Temmuz                      9905
# #BugünHerŞeyÇokGüzelOlacak     9210
# #LeylayaUmutOl                 8035
# Binali Yıldırım                7508
# #pazartesi                     7352
# #MGMAVOTE                      7267
# #cumartesi                     7128
# #Pride2019                     6777
# #EkrandakiYalancı              6718
# #YeniBirBaşlangıç              6703
# #SiverektekiKatliamaSesVer     6666
# #15TemmuzDestanı               6332
# #İstanbulunUmuduİmamoğlu       6147
# #15TemmuzGecesi                6041
# #herseycokguzeloldu            5916
# Öcalan                         5910
# #kayyum                        5827
# #15TEMMUZDESTANI               5732
# #pazar                         5678
# #unutMADIMAKlımda              5659
# #AilemizHerŞeyimiz             5644
# #yks2019                       5555
# #izmiryanıyor                  5443
# #HayırlıCumalar                5397
# #GümbürGümbürBinali            5390
# #Srebrenitsa                   5385
# Ekrem                          5373
# #salı                          5366
# #Kazdağınadokunma              5334
# 30 Ağustos                     5269
# #AfiliAşk                      5010
# #15Temmuz                      4967
# Ağaç Bayramı                   4959
# Ekrem İmamoğlu                 4881
# #VerMehteriBinali              4607
# #AyKer                         4504
# dtype: int64

# %%
num, den = 0, 0 
sizes = []
for trend, tweets in campaigns.items():
    den += 1
    temp = trending_info[trending_info.keyword == trend]
    if len(temp) > 0:
        sizes.append(len(tweets))
        num += 1

print(num/den)
# Out:
# 0.04095112285336856

# %%
plt.hist(sizes)
# Out:
# (array([26.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  1.,  1.]),
#  array([  1. ,  58.1, 115.2, 172.3, 229.4, 286.5, 343.6, 400.7, 457.8,
#         514.9, 572. ]),
#  <BarContainer object of 10 artists>)

# %%
df[df.trend == "\"Zilli\""]
# Out:
#      author_id           created_at        date                   id  \
# 322   80162128  2019-09-01 01:15:04  2019-09-01  1167969086350872577
#
#                                                   text    trend  trend_date  \
# 322  RT @Emniyetci_: Erkek neden "Delikanlı" kadın ...  "Zilli"  2019-08-30
#
#     tweet_type
# 322    retweet

# %%
df.tweet_type
# Out:
# 0         retweet
# 1         retweet
# 2         retweet
# 3        deletion
# 4         retweet
#            ...
# 25361    deletion
# 25362    deletion
# 25363    deletion
# 25364    deletion
# 25365    deletion
# Name: tweet_type, Length: 25366, dtype: object

# %%
campaigns = df.groupby("trend").apply(lambda x: x.to_dict(orient="records")).to_dict()

# %%
campaigns["#1EylülDünyaBarışGünü"]
# Out:
# [{'author_id': 1012033887084666881,
#   'created_at': '2019-09-01 04:14:18',
#   'date': '2019-09-01',
#   'id': 1168014191887867904,
#   'text': 'bugün  #1EylülDünyaBarışGünü  bugün kardeşlik  günü https://t.co/LA2eZID5Wr',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 884912305,
#   'created_at': '2019-09-01 05:03:59',
#   'date': '2019-09-01',
#   'id': 1168026695145787392,
#   'text': 'RT @sevimari1: Birbirimize sarılalım ki, bu topraklarda çiçekler açsın. #1EylülDünyaBarışGünü 🕊',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 4838589401,
#   'created_at': '2019-09-01 05:18:11',
#   'date': '2019-09-01',
#   'id': 1168030268692631553,
#   'text': 'RT @evrenselgzt: Sefer Selvi #1EylülDünyaBarışGünü mitinginde kullanılacak bazı sloganların yasaklanmasını çizdi https://t.co/4ZkMUBfQjo https://t.co/S6am4XELF4',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 2309922296,
#   'created_at': '2019-09-01 05:30:02',
#   'date': '2019-09-01',
#   'id': 1168033250826055681,
#   'text': "İnsanlığın #1EylülDünyaBarışGünü nü Kutlarım  Oysa ki Herkese Yetecek Kadar Her Şey Var  ''Yeryüzünde bir tek çocuk dahi acı çekiyorsa, tanrı yoktur!''   Dostoyevski https://t.co/MDDv0MIVJv",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 1082274749823225856,
#   'created_at': '2019-09-01 05:33:16',
#   'date': '2019-09-01',
#   'id': 1168034064504258561,
#   'text': 'RT @mehmetyetim63: Bugün 1 Eylül Dünya Barış Günü imiş  Gerçi her ne kadar da gerçekleşmeyeceğini bilsemde  Barışın tüm dünyaya egemen olmasını savaşların bitmesini ve kimsenin gözyaşını dökmemesini diliyorum. Dünya Barış Günü Kutlu olsun.  #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 3127109427,
#   'created_at': '2019-09-01 05:35:52',
#   'date': '2019-09-01',
#   'id': 1168034718840832003,
#   'text': 'RT @sakiksirri: Bugünlerden geriye,  bir yarına gidenler kalır  bir de yarınlar için direnenler... #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 850510875274473472,
#   'created_at': '2019-09-01 06:40:05',
#   'date': '2019-09-01',
#   'id': 1168050879469105153,
#   'text': 'RT @tahsintarhan: “...Ben insanım, insancılım Çünkü Allah’ın yarattığı kulum ‘Yurtta barış, dünyada barış’ derim Barışseverim, ben Ata’nın izindeyim.”   #1EylülDünyaBarışGünü kutlu olsun. https://t.co/tijvmUJxzY',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 850510875274473472,
#   'created_at': '2019-09-01 06:40:05',
#   'date': '2019-09-01',
#   'id': 1168050879469105153,
#   'text': 'RT @tahsintarhan: “...Ben insanım, insancılım Çünkü Allah’ın yarattığı kulum ‘Yurtta barış, dünyada barış’ derim Barışseverim, ben Ata’nın izindeyim.”   #1EylülDünyaBarışGünü kutlu olsun. https://t.co/tijvmUJxzY',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1163042103062122496,
#   'created_at': '2019-09-01 06:55:01',
#   'date': '2019-09-01',
#   'id': 1168054637582331904,
#   'text': 'Bana hayalci olduğumu söyleyebilirsin  Ama bu dünyada tek hayalci ben değilim  Umarım bir gün sen de bize katılırsın  Ve dünya tek vücut olarak yaşar …  John Lennon  #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 1163042103062122496,
#   'created_at': '2019-09-01 06:55:01',
#   'date': '2019-09-01',
#   'id': 1168054637582331904,
#   'text': 'Bana hayalci olduğumu söyleyebilirsin  Ama bu dünyada tek hayalci ben değilim  Umarım bir gün sen de bize katılırsın  Ve dünya tek vücut olarak yaşar …  John Lennon  #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 1117504284319416320,
#   'created_at': '2019-09-01 06:59:22',
#   'date': '2019-09-01',
#   'id': 1168055732278706176,
#   'text': 'Barış bu toprakların hayali olmaktan öteye gidemeyen bir ütopya sadece. Akepe gitmediği sürece imkansıza yakındır hatta. Bu yüzden tüm halkların barışı için tek bir oluşuma karşı birlikte savaş gerekir ve yapılmalıdır. #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 1117504284319416320,
#   'created_at': '2019-09-01 06:59:22',
#   'date': '2019-09-01',
#   'id': 1168055732278706176,
#   'text': 'Barış bu toprakların hayali olmaktan öteye gidemeyen bir ütopya sadece. Akepe gitmediği sürece imkansıza yakındır hatta. Bu yüzden tüm halkların barışı için tek bir oluşuma karşı birlikte savaş gerekir ve yapılmalıdır. #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 998699957711462400,
#   'created_at': '2019-09-01 07:15:27',
#   'date': '2019-09-01',
#   'id': 1168059779811426305,
#   'text': 'RT @KozGazete: İzmir 1 Eylül Mitingi Duyurusu 1 Eylül Barış Günü mitingine katılmak üzere İzmir’de Gündoğdu Meydanı’nda Söz ve Eylem ile birlikte açacağımız “Halklara Karşı Savaşa, Sınıflar Arası Barışa Son” ortak pankartı arkasında buluşuyoruz. https://t.co/wDF6M1P3i4 #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 998699957711462400,
#   'created_at': '2019-09-01 07:15:27',
#   'date': '2019-09-01',
#   'id': 1168059779811426305,
#   'text': 'RT @KozGazete: İzmir 1 Eylül Mitingi Duyurusu 1 Eylül Barış Günü mitingine katılmak üzere İzmir’de Gündoğdu Meydanı’nda Söz ve Eylem ile birlikte açacağımız “Halklara Karşı Savaşa, Sınıflar Arası Barışa Son” ortak pankartı arkasında buluşuyoruz. https://t.co/wDF6M1P3i4 #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 960262383246761985,
#   'created_at': '2019-09-01 07:24:20',
#   'date': '2019-09-01',
#   'id': 1168062015354499072,
#   'text': 'Usta be! Barış ne zaman gelir? Mesela kaç kundaklık bebe ölse yeter? Vatan kaç kez sağolsa; Savaş bir kez ölür? #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 960262383246761985,
#   'created_at': '2019-09-01 07:24:20',
#   'date': '2019-09-01',
#   'id': 1168062015354499072,
#   'text': 'Usta be! Barış ne zaman gelir? Mesela kaç kundaklık bebe ölse yeter? Vatan kaç kez sağolsa; Savaş bir kez ölür? #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 3297793856,
#   'created_at': '2019-09-01 07:24:30',
#   'date': '2019-09-01',
#   'id': 1168062057306120192,
#   'text': 'RT @ajansdreklam: O gün gelsin neşemiz tazelensin de gör Dünyayı hele sen bir barış olsun da gör Seyreyle deli ozanı Baştan başa sevda, baştan başa tutku Dili baldan tatlı...  / Melih Cevdet Anday #1EylülDünyaBarışGünü https://t.co/1igYRhqr6I',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 3297793856,
#   'created_at': '2019-09-01 07:24:30',
#   'date': '2019-09-01',
#   'id': 1168062057306120192,
#   'text': 'RT @ajansdreklam: O gün gelsin neşemiz tazelensin de gör Dünyayı hele sen bir barış olsun da gör Seyreyle deli ozanı Baştan başa sevda, baştan başa tutku Dili baldan tatlı...  / Melih Cevdet Anday #1EylülDünyaBarışGünü https://t.co/1igYRhqr6I',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 960262383246761985,
#   'created_at': '2019-09-01 07:24:35',
#   'date': '2019-09-01',
#   'id': 1168062015354499072,
#   'text': 'Usta be! Barış ne zaman gelir? Mesela kaç kundaklık bebe ölse yeter? Vatan kaç kez sağolsa; Savaş bir kez ölür? #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 960262383246761985,
#   'created_at': '2019-09-01 07:24:35',
#   'date': '2019-09-01',
#   'id': 1168062015354499072,
#   'text': 'Usta be! Barış ne zaman gelir? Mesela kaç kundaklık bebe ölse yeter? Vatan kaç kez sağolsa; Savaş bir kez ölür? #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 960262383246761985,
#   'created_at': '2019-09-01 07:24:35',
#   'date': '2019-09-01',
#   'id': 1168062015354499072,
#   'text': 'Usta be! Barış ne zaman gelir? Mesela kaç kundaklık bebe ölse yeter? Vatan kaç kez sağolsa; Savaş bir kez ölür? #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 960262383246761985,
#   'created_at': '2019-09-01 07:24:35',
#   'date': '2019-09-01',
#   'id': 1168062015354499072,
#   'text': 'Usta be! Barış ne zaman gelir? Mesela kaç kundaklık bebe ölse yeter? Vatan kaç kez sağolsa; Savaş bir kez ölür? #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 960262383246761985,
#   'created_at': '2019-09-01 07:24:35',
#   'date': '2019-09-01',
#   'id': 1168062015354499072,
#   'text': 'Usta be! Barış ne zaman gelir? Mesela kaç kundaklık bebe ölse yeter? Vatan kaç kez sağolsa; Savaş bir kez ölür? #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 960262383246761985,
#   'created_at': '2019-09-01 07:24:35',
#   'date': '2019-09-01',
#   'id': 1168062015354499072,
#   'text': 'Usta be! Barış ne zaman gelir? Mesela kaç kundaklık bebe ölse yeter? Vatan kaç kez sağolsa; Savaş bir kez ölür? #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 363209709,
#   'created_at': '2019-09-01 07:35:03',
#   'date': '2019-09-01',
#   'id': 1168064712279515137,
#   'text': 'RT @Ata_18811: "Öyle bir ağlasam Öyle bir ağlasam ki çocuklar Size hiç gözyaşı kalmasa.  Öyle bir aç kalsam Öyle bir aç kalsam ki çocuklar Size hiç açlık kalmasa.  Öyle bir ölsem Öyle bir ölsem ki çocuklar Size hiç ölüm kalmasa ..."  Aziz NESİN  #1EylülDünyaBarışGünü  İyi pazarlar 🌿 https://t.co/UyDl5jNsgI',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 363209709,
#   'created_at': '2019-09-01 07:35:03',
#   'date': '2019-09-01',
#   'id': 1168064712279515137,
#   'text': 'RT @Ata_18811: "Öyle bir ağlasam Öyle bir ağlasam ki çocuklar Size hiç gözyaşı kalmasa.  Öyle bir aç kalsam Öyle bir aç kalsam ki çocuklar Size hiç açlık kalmasa.  Öyle bir ölsem Öyle bir ölsem ki çocuklar Size hiç ölüm kalmasa ..."  Aziz NESİN  #1EylülDünyaBarışGünü  İyi pazarlar 🌿 https://t.co/UyDl5jNsgI',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 3046091502,
#   'created_at': '2019-09-01 07:43:22',
#   'date': '2019-09-01',
#   'id': 1168066805262368768,
#   'text': "RT @n555775: #pazar  Bir gün aklına gelecek olursam Bana bir şiir ısmarla Eylül'ü konuşalım           #CemalSüreya        #1EylülDünyaBarışGünü  🌿🍃  #Günaydın 🌞Mutlu pazarlar ❤ 🍁 https://t.co/k7PCtmu8PR",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 3046091502,
#   'created_at': '2019-09-01 07:43:22',
#   'date': '2019-09-01',
#   'id': 1168066805262368768,
#   'text': "RT @n555775: #pazar  Bir gün aklına gelecek olursam Bana bir şiir ısmarla Eylül'ü konuşalım           #CemalSüreya        #1EylülDünyaBarışGünü  🌿🍃  #Günaydın 🌞Mutlu pazarlar ❤ 🍁 https://t.co/k7PCtmu8PR",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 855291012788269057,
#   'created_at': '2019-09-01 07:48:43',
#   'date': '2019-09-01',
#   'id': 1168068151646593025,
#   'text': "RT @ErtugrulFilizay: Almanya'nın 1 Eylül 1939 yılında Polonya'yı işgal etmesiyle başlayan 2. Dünya Savaşında 50 milyondan fazla insan öldü...  Bunu unutmamak amacıyla ilan edilen #1EylülDünyaBarışGünü kutlu olsun..  Ülkemizde ve dünyada barışın ve kardeşliğin yeşerip kök salması umudu ve dileğiyle... https://t.co/c7YaKfwB74",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 855291012788269057,
#   'created_at': '2019-09-01 07:48:43',
#   'date': '2019-09-01',
#   'id': 1168068151646593025,
#   'text': "RT @ErtugrulFilizay: Almanya'nın 1 Eylül 1939 yılında Polonya'yı işgal etmesiyle başlayan 2. Dünya Savaşında 50 milyondan fazla insan öldü...  Bunu unutmamak amacıyla ilan edilen #1EylülDünyaBarışGünü kutlu olsun..  Ülkemizde ve dünyada barışın ve kardeşliğin yeşerip kök salması umudu ve dileğiyle... https://t.co/c7YaKfwB74",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1030707523,
#   'created_at': '2019-09-01 07:54:52',
#   'date': '2019-09-01',
#   'id': 1168069699344588800,
#   'text': '1Eylül Dünya Barış Günü nde bir kez daha Ustayı saygıyla sevgiyle anıyoruz. Barış Emekle Gelecek. #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 1030707523,
#   'created_at': '2019-09-01 07:54:52',
#   'date': '2019-09-01',
#   'id': 1168069699344588800,
#   'text': '1Eylül Dünya Barış Günü nde bir kez daha Ustayı saygıyla sevgiyle anıyoruz. Barış Emekle Gelecek. #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 1513212895,
#   'created_at': '2019-09-01 08:12:50',
#   'date': '2019-09-01',
#   'id': 1168074220800217089,
#   'text': 'RT @cigdemgng: #1EylülDünyaBarışGünü  Canım ATAM yaklaşık 100 yıl önce durumu özetlemiş YURTTA SULH DÜNYADA SULH https://t.co/UikuLq6Uuu',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1513212895,
#   'created_at': '2019-09-01 08:12:50',
#   'date': '2019-09-01',
#   'id': 1168074220800217089,
#   'text': 'RT @cigdemgng: #1EylülDünyaBarışGünü  Canım ATAM yaklaşık 100 yıl önce durumu özetlemiş YURTTA SULH DÜNYADA SULH https://t.co/UikuLq6Uuu',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1159070029155094529,
#   'created_at': '2019-09-01 08:13:44',
#   'date': '2019-09-01',
#   'id': 1168074447279910912,
#   'text': 'RT @emekci_hareket: Eşitlik ve özgürlük temelinde Halklar barışmalı  #1EylülDünyaBarışGünü https://t.co/H8tYBNIJ5L',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1159070029155094529,
#   'created_at': '2019-09-01 08:13:44',
#   'date': '2019-09-01',
#   'id': 1168074447279910912,
#   'text': 'RT @emekci_hareket: Eşitlik ve özgürlük temelinde Halklar barışmalı  #1EylülDünyaBarışGünü https://t.co/H8tYBNIJ5L',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 199783092,
#   'created_at': '2019-09-01 08:14:22',
#   'date': '2019-09-01',
#   'id': 1168074606676234243,
#   'text': 'Barış hükümlerin en güzelidir.  #1EylülDünyaBarışGünü #Eylül',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 199783092,
#   'created_at': '2019-09-01 08:14:22',
#   'date': '2019-09-01',
#   'id': 1168074606676234243,
#   'text': 'Barış hükümlerin en güzelidir.  #1EylülDünyaBarışGünü #Eylül',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 983236880614477824,
#   'created_at': '2019-09-01 08:17:24',
#   'date': '2019-09-01',
#   'id': 1168075370006011904,
#   'text': 'RT @ararat4787: Bir barış güvercini vardı bu topraklarda. Onu yüreğinden vurdular. O gittiğinden beri barışa olan inancımda gitti.. Tahir Elçi Anısına Saygıyla..  #1EylülDünyaBarışGünü https://t.co/4ZvvZ8JI1G',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 983236880614477824,
#   'created_at': '2019-09-01 08:17:24',
#   'date': '2019-09-01',
#   'id': 1168075370006011904,
#   'text': 'RT @ararat4787: Bir barış güvercini vardı bu topraklarda. Onu yüreğinden vurdular. O gittiğinden beri barışa olan inancımda gitti.. Tahir Elçi Anısına Saygıyla..  #1EylülDünyaBarışGünü https://t.co/4ZvvZ8JI1G',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 78533273,
#   'created_at': '2019-09-01 08:18:41',
#   'date': '2019-09-01',
#   'id': 1168075692979802112,
#   'text': 'RT @CHPATAKANUNVER: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir\xa0barıştır." #1EylülDünyaBarışGünü #DünyaBarışGünü 🕊 https://t.co/GEC13o61xk',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 78533273,
#   'created_at': '2019-09-01 08:18:41',
#   'date': '2019-09-01',
#   'id': 1168075692979802112,
#   'text': 'RT @CHPATAKANUNVER: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir\xa0barıştır." #1EylülDünyaBarışGünü #DünyaBarışGünü 🕊 https://t.co/GEC13o61xk',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 789162789700902912,
#   'created_at': '2019-09-01 08:19:28',
#   'date': '2019-09-01',
#   'id': 1168075890116501504,
#   'text': 'RT @fatmacumhurefe: “Hangi nedenle olursa olsun,insanların birbirlerini öldürmek zorunda oldukları dünyayı sevmiyorum ben.” ~Vedat Türkali~ #1EylülDünyaBarışGünü kutlu olsun✌️  “Yurtta BARIŞ dünyada BARIŞ” https://t.co/OLgEbACOJC',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 789162789700902912,
#   'created_at': '2019-09-01 08:19:28',
#   'date': '2019-09-01',
#   'id': 1168075890116501504,
#   'text': 'RT @fatmacumhurefe: “Hangi nedenle olursa olsun,insanların birbirlerini öldürmek zorunda oldukları dünyayı sevmiyorum ben.” ~Vedat Türkali~ #1EylülDünyaBarışGünü kutlu olsun✌️  “Yurtta BARIŞ dünyada BARIŞ” https://t.co/OLgEbACOJC',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1167132019404488710,
#   'created_at': '2019-09-01 08:24:39',
#   'date': '2019-09-01',
#   'id': 1168077194557644802,
#   'text': 'RT @benimbenismail: Ömrü savaş cephelerinde geçen Atatürk,  "Yurtta barış, dünyada barış" diyorsa dinleyeceksin..!! #1EylülDünyaBarışGünü https://t.co/XEDvw8lVbZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1167132019404488710,
#   'created_at': '2019-09-01 08:24:39',
#   'date': '2019-09-01',
#   'id': 1168077194557644802,
#   'text': 'RT @benimbenismail: Ömrü savaş cephelerinde geçen Atatürk,  "Yurtta barış, dünyada barış" diyorsa dinleyeceksin..!! #1EylülDünyaBarışGünü https://t.co/XEDvw8lVbZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 773264699626516484,
#   'created_at': '2019-09-01 08:28:22',
#   'date': '2019-09-01',
#   'id': 1168078129862258689,
#   'text': 'RT @ajansdreklam: "Savaşı icat eden, görmesin cennet."  / Yaşar Kemal #1EylülDünyaBarışGünü https://t.co/40PrMFizNY',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 773264699626516484,
#   'created_at': '2019-09-01 08:28:22',
#   'date': '2019-09-01',
#   'id': 1168078129862258689,
#   'text': 'RT @ajansdreklam: "Savaşı icat eden, görmesin cennet."  / Yaşar Kemal #1EylülDünyaBarışGünü https://t.co/40PrMFizNY',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 789162789700902912,
#   'created_at': '2019-09-01 08:30:00',
#   'date': '2019-09-01',
#   'id': 1168075890116501504,
#   'text': 'RT @fatmacumhurefe: “Hangi nedenle olursa olsun,insanların birbirlerini öldürmek zorunda oldukları dünyayı sevmiyorum ben.” ~Vedat Türkali~ #1EylülDünyaBarışGünü kutlu olsun✌️  “Yurtta BARIŞ dünyada BARIŞ” https://t.co/OLgEbACOJC',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 789162789700902912,
#   'created_at': '2019-09-01 08:30:00',
#   'date': '2019-09-01',
#   'id': 1168075890116501504,
#   'text': 'RT @fatmacumhurefe: “Hangi nedenle olursa olsun,insanların birbirlerini öldürmek zorunda oldukları dünyayı sevmiyorum ben.” ~Vedat Türkali~ #1EylülDünyaBarışGünü kutlu olsun✌️  “Yurtta BARIŞ dünyada BARIŞ” https://t.co/OLgEbACOJC',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 789162789700902912,
#   'created_at': '2019-09-01 08:30:00',
#   'date': '2019-09-01',
#   'id': 1168075890116501504,
#   'text': 'RT @fatmacumhurefe: “Hangi nedenle olursa olsun,insanların birbirlerini öldürmek zorunda oldukları dünyayı sevmiyorum ben.” ~Vedat Türkali~ #1EylülDünyaBarışGünü kutlu olsun✌️  “Yurtta BARIŞ dünyada BARIŞ” https://t.co/OLgEbACOJC',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 789162789700902912,
#   'created_at': '2019-09-01 08:30:00',
#   'date': '2019-09-01',
#   'id': 1168075890116501504,
#   'text': 'RT @fatmacumhurefe: “Hangi nedenle olursa olsun,insanların birbirlerini öldürmek zorunda oldukları dünyayı sevmiyorum ben.” ~Vedat Türkali~ #1EylülDünyaBarışGünü kutlu olsun✌️  “Yurtta BARIŞ dünyada BARIŞ” https://t.co/OLgEbACOJC',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 789162789700902912,
#   'created_at': '2019-09-01 08:30:00',
#   'date': '2019-09-01',
#   'id': 1168075890116501504,
#   'text': 'RT @fatmacumhurefe: “Hangi nedenle olursa olsun,insanların birbirlerini öldürmek zorunda oldukları dünyayı sevmiyorum ben.” ~Vedat Türkali~ #1EylülDünyaBarışGünü kutlu olsun✌️  “Yurtta BARIŞ dünyada BARIŞ” https://t.co/OLgEbACOJC',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 789162789700902912,
#   'created_at': '2019-09-01 08:30:00',
#   'date': '2019-09-01',
#   'id': 1168075890116501504,
#   'text': 'RT @fatmacumhurefe: “Hangi nedenle olursa olsun,insanların birbirlerini öldürmek zorunda oldukları dünyayı sevmiyorum ben.” ~Vedat Türkali~ #1EylülDünyaBarışGünü kutlu olsun✌️  “Yurtta BARIŞ dünyada BARIŞ” https://t.co/OLgEbACOJC',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 868403461523734529,
#   'created_at': '2019-09-01 08:32:19',
#   'date': '2019-09-01',
#   'id': 1168079123941646338,
#   'text': 'Barışın bile savaşla arandığı bir Dünya bu! #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 868403461523734529,
#   'created_at': '2019-09-01 08:32:19',
#   'date': '2019-09-01',
#   'id': 1168079123941646338,
#   'text': 'Barışın bile savaşla arandığı bir Dünya bu! #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 300308695,
#   'created_at': '2019-09-01 08:34:25',
#   'date': '2019-09-01',
#   'id': 1168079652390342661,
#   'text': '@mulkiyeliler Dunya Baris Gunu kutlu olsun.Savaslarin , catismalarin,terorun olmadigi bir dunya ozluyorum. Insanlarin ozgur, kardes ve refah icinde oldugu bir Dunya ozluyorum #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 300308695,
#   'created_at': '2019-09-01 08:34:25',
#   'date': '2019-09-01',
#   'id': 1168079652390342661,
#   'text': '@mulkiyeliler Dunya Baris Gunu kutlu olsun.Savaslarin , catismalarin,terorun olmadigi bir dunya ozluyorum. Insanlarin ozgur, kardes ve refah icinde oldugu bir Dunya ozluyorum #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 423569604,
#   'created_at': '2019-09-01 08:34:33',
#   'date': '2019-09-01',
#   'id': 1168079685957431296,
#   'text': 'Gülümsemenin dili, dini, ırkı yoktur. Tüm insanlar aynı dilde gülümser. Kimsenin gülüşü solmasın  #1EylülDünyaBarışGünü https://t.co/aB5vNOpd3r',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 423569604,
#   'created_at': '2019-09-01 08:34:33',
#   'date': '2019-09-01',
#   'id': 1168079685957431296,
#   'text': 'Gülümsemenin dili, dini, ırkı yoktur. Tüm insanlar aynı dilde gülümser. Kimsenin gülüşü solmasın  #1EylülDünyaBarışGünü https://t.co/aB5vNOpd3r',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 1080357410349502465,
#   'created_at': '2019-09-01 08:34:51',
#   'date': '2019-09-01',
#   'id': 1168079761475854336,
#   'text': "✓✓ ..Dünya Barış Gününe hazırlanan, Dünyayı Değiştirenler Serisinde; Fikir ve Devlet kurucusu, Dünya Barış Öncüsü Ulu Önder Gazi Mustafa Kemal Atatürk; Türk Ulusunun Övünç ve Gurur kaynağıdır!.  Atatürk'ün Fikir ve Işığ ile #1EylülDünyaBarışGünü  Kutlu olsun, Gerçek Barış olsun https://t.co/yQ5mWXl4Ss",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 1080357410349502465,
#   'created_at': '2019-09-01 08:34:51',
#   'date': '2019-09-01',
#   'id': 1168079761475854336,
#   'text': "✓✓ ..Dünya Barış Gününe hazırlanan, Dünyayı Değiştirenler Serisinde; Fikir ve Devlet kurucusu, Dünya Barış Öncüsü Ulu Önder Gazi Mustafa Kemal Atatürk; Türk Ulusunun Övünç ve Gurur kaynağıdır!.  Atatürk'ün Fikir ve Işığ ile #1EylülDünyaBarışGünü  Kutlu olsun, Gerçek Barış olsun https://t.co/yQ5mWXl4Ss",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 387101979,
#   'created_at': '2019-09-01 08:46:53',
#   'date': '2019-09-01',
#   'id': 1168082789750726656,
#   'text': 'RT @flz_gkbrk: Cennet nerede bilir misiniz ? Gülen gözlerde, Tatlı sözlerde, Mutlu yüzlerde, Ama en güzeli SEVGİ dolu yüreklerdedir. #1EylülDünyaBarışGünü https://t.co/y3iuwbooTD',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 387101979,
#   'created_at': '2019-09-01 08:46:53',
#   'date': '2019-09-01',
#   'id': 1168082789750726656,
#   'text': 'RT @flz_gkbrk: Cennet nerede bilir misiniz ? Gülen gözlerde, Tatlı sözlerde, Mutlu yüzlerde, Ama en güzeli SEVGİ dolu yüreklerdedir. #1EylülDünyaBarışGünü https://t.co/y3iuwbooTD',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 160965513,
#   'created_at': '2019-09-01 08:53:27',
#   'date': '2019-09-01',
#   'id': 1168084442289717249,
#   'text': 'RT @karga_kafasi: #1EylülDünyaBarışGünü "Bize her gün barış!" https://t.co/0U99sRfHkp',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 160965513,
#   'created_at': '2019-09-01 08:53:27',
#   'date': '2019-09-01',
#   'id': 1168084442289717249,
#   'text': 'RT @karga_kafasi: #1EylülDünyaBarışGünü "Bize her gün barış!" https://t.co/0U99sRfHkp',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1091049199498653696,
#   'created_at': '2019-09-01 09:08:43',
#   'date': '2019-09-01',
#   'id': 1168088284280569857,
#   'text': 'RT @ayhanbilgen: Barışı iktidardan talep etmeden önce toplumda inşa etmeliyiz. #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1091049199498653696,
#   'created_at': '2019-09-01 09:08:43',
#   'date': '2019-09-01',
#   'id': 1168088284280569857,
#   'text': 'RT @ayhanbilgen: Barışı iktidardan talep etmeden önce toplumda inşa etmeliyiz. #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 3038719018,
#   'created_at': '2019-09-01 09:10:13',
#   'date': '2019-09-01',
#   'id': 1168088661772005383,
#   'text': 'RT @Tekyumruk06: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir, barıştır."  #1EylülDünyaBarışGünü kutlu olsun, anlamlı olsun, daim olsun. https://t.co/NdVLiGBfaz',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 3038719018,
#   'created_at': '2019-09-01 09:10:13',
#   'date': '2019-09-01',
#   'id': 1168088661772005383,
#   'text': 'RT @Tekyumruk06: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir, barıştır."  #1EylülDünyaBarışGünü kutlu olsun, anlamlı olsun, daim olsun. https://t.co/NdVLiGBfaz',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 3038719018,
#   'created_at': '2019-09-01 09:12:35',
#   'date': '2019-09-01',
#   'id': 1168088661772005383,
#   'text': 'RT @Tekyumruk06: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir, barıştır."  #1EylülDünyaBarışGünü kutlu olsun, anlamlı olsun, daim olsun. https://t.co/NdVLiGBfaz',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 3038719018,
#   'created_at': '2019-09-01 09:12:35',
#   'date': '2019-09-01',
#   'id': 1168088661772005383,
#   'text': 'RT @Tekyumruk06: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir, barıştır."  #1EylülDünyaBarışGünü kutlu olsun, anlamlı olsun, daim olsun. https://t.co/NdVLiGBfaz',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 3038719018,
#   'created_at': '2019-09-01 09:12:35',
#   'date': '2019-09-01',
#   'id': 1168088661772005383,
#   'text': 'RT @Tekyumruk06: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir, barıştır."  #1EylülDünyaBarışGünü kutlu olsun, anlamlı olsun, daim olsun. https://t.co/NdVLiGBfaz',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 3038719018,
#   'created_at': '2019-09-01 09:12:35',
#   'date': '2019-09-01',
#   'id': 1168088661772005383,
#   'text': 'RT @Tekyumruk06: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir, barıştır."  #1EylülDünyaBarışGünü kutlu olsun, anlamlı olsun, daim olsun. https://t.co/NdVLiGBfaz',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 3038719018,
#   'created_at': '2019-09-01 09:12:35',
#   'date': '2019-09-01',
#   'id': 1168088661772005383,
#   'text': 'RT @Tekyumruk06: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir, barıştır."  #1EylülDünyaBarışGünü kutlu olsun, anlamlı olsun, daim olsun. https://t.co/NdVLiGBfaz',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 3038719018,
#   'created_at': '2019-09-01 09:12:35',
#   'date': '2019-09-01',
#   'id': 1168088661772005383,
#   'text': 'RT @Tekyumruk06: "Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir, barıştır."  #1EylülDünyaBarışGünü kutlu olsun, anlamlı olsun, daim olsun. https://t.co/NdVLiGBfaz',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 920245868757954561,
#   'created_at': '2019-09-01 09:18:39',
#   'date': '2019-09-01',
#   'id': 1168090784094150656,
#   'text': 'RT @ajansdreklam: Gökte bir yıldız kayarsa eğer,  Sen yıldızı tut çocuk..  Umut dile,  Sevgi dile,  BARIŞ dile.   / Can Yücel #1EylülDünyaBarışGünü https://t.co/JJ5ScecMGc',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 920245868757954561,
#   'created_at': '2019-09-01 09:18:39',
#   'date': '2019-09-01',
#   'id': 1168090784094150656,
#   'text': 'RT @ajansdreklam: Gökte bir yıldız kayarsa eğer,  Sen yıldızı tut çocuk..  Umut dile,  Sevgi dile,  BARIŞ dile.   / Can Yücel #1EylülDünyaBarışGünü https://t.co/JJ5ScecMGc',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 210229845,
#   'created_at': '2019-09-01 09:18:50',
#   'date': '2019-09-01',
#   'id': 1168090830227365889,
#   'text': 'RT @hakiskonf: #1EylülDünyaBarışGünü kutlu olsun https://t.co/sVmUPwGBLf',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 210229845,
#   'created_at': '2019-09-01 09:18:50',
#   'date': '2019-09-01',
#   'id': 1168090830227365889,
#   'text': 'RT @hakiskonf: #1EylülDünyaBarışGünü kutlu olsun https://t.co/sVmUPwGBLf',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1060543151595814912,
#   'created_at': '2019-09-01 09:21:08',
#   'date': '2019-09-01',
#   'id': 1168091409028661248,
#   'text': 'RT @bulutcanokuducu: "Yurtta sulh cihanda sulh." Çağlar aşma gücüne sahip bir Ata\'ya neler borçlu olduğumuzu yeniden hatırlayalım.  #1eylül  #DünyaBarışGünü #1EylülDünyaBarışGünü #YurttaSulhCihandaSulh #MustafaKemalATATURK #1EylülBarışMitingi #Pazar https://t.co/wsaMEgKQiZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1060543151595814912,
#   'created_at': '2019-09-01 09:21:08',
#   'date': '2019-09-01',
#   'id': 1168091409028661248,
#   'text': 'RT @bulutcanokuducu: "Yurtta sulh cihanda sulh." Çağlar aşma gücüne sahip bir Ata\'ya neler borçlu olduğumuzu yeniden hatırlayalım.  #1eylül  #DünyaBarışGünü #1EylülDünyaBarışGünü #YurttaSulhCihandaSulh #MustafaKemalATATURK #1EylülBarışMitingi #Pazar https://t.co/wsaMEgKQiZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1060543151595814912,
#   'created_at': '2019-09-01 09:24:10',
#   'date': '2019-09-01',
#   'id': 1168091409028661248,
#   'text': 'RT @bulutcanokuducu: "Yurtta sulh cihanda sulh." Çağlar aşma gücüne sahip bir Ata\'ya neler borçlu olduğumuzu yeniden hatırlayalım.  #1eylül  #DünyaBarışGünü #1EylülDünyaBarışGünü #YurttaSulhCihandaSulh #MustafaKemalATATURK #1EylülBarışMitingi #Pazar https://t.co/wsaMEgKQiZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 1060543151595814912,
#   'created_at': '2019-09-01 09:24:10',
#   'date': '2019-09-01',
#   'id': 1168091409028661248,
#   'text': 'RT @bulutcanokuducu: "Yurtta sulh cihanda sulh." Çağlar aşma gücüne sahip bir Ata\'ya neler borçlu olduğumuzu yeniden hatırlayalım.  #1eylül  #DünyaBarışGünü #1EylülDünyaBarışGünü #YurttaSulhCihandaSulh #MustafaKemalATATURK #1EylülBarışMitingi #Pazar https://t.co/wsaMEgKQiZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 1060543151595814912,
#   'created_at': '2019-09-01 09:24:10',
#   'date': '2019-09-01',
#   'id': 1168091409028661248,
#   'text': 'RT @bulutcanokuducu: "Yurtta sulh cihanda sulh." Çağlar aşma gücüne sahip bir Ata\'ya neler borçlu olduğumuzu yeniden hatırlayalım.  #1eylül  #DünyaBarışGünü #1EylülDünyaBarışGünü #YurttaSulhCihandaSulh #MustafaKemalATATURK #1EylülBarışMitingi #Pazar https://t.co/wsaMEgKQiZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 1060543151595814912,
#   'created_at': '2019-09-01 09:24:10',
#   'date': '2019-09-01',
#   'id': 1168091409028661248,
#   'text': 'RT @bulutcanokuducu: "Yurtta sulh cihanda sulh." Çağlar aşma gücüne sahip bir Ata\'ya neler borçlu olduğumuzu yeniden hatırlayalım.  #1eylül  #DünyaBarışGünü #1EylülDünyaBarışGünü #YurttaSulhCihandaSulh #MustafaKemalATATURK #1EylülBarışMitingi #Pazar https://t.co/wsaMEgKQiZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 1060543151595814912,
#   'created_at': '2019-09-01 09:24:10',
#   'date': '2019-09-01',
#   'id': 1168091409028661248,
#   'text': 'RT @bulutcanokuducu: "Yurtta sulh cihanda sulh." Çağlar aşma gücüne sahip bir Ata\'ya neler borçlu olduğumuzu yeniden hatırlayalım.  #1eylül  #DünyaBarışGünü #1EylülDünyaBarışGünü #YurttaSulhCihandaSulh #MustafaKemalATATURK #1EylülBarışMitingi #Pazar https://t.co/wsaMEgKQiZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'deletion'},
#  {'author_id': 1060543151595814912,
#   'created_at': '2019-09-01 09:24:10',
#   'date': '2019-09-01',
#   'id': 1168091409028661248,
#   'text': 'RT @bulutcanokuducu: "Yurtta sulh cihanda sulh." Çağlar aşma gücüne sahip bir Ata\'ya neler borçlu olduğumuzu yeniden hatırlayalım.  #1eylül  #DünyaBarışGünü #1EylülDünyaBarışGünü #YurttaSulhCihandaSulh #MustafaKemalATATURK #1EylülBarışMitingi #Pazar https://t.co/wsaMEgKQiZ',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'deletion'},
#  {'author_id': 2309922296,
#   'created_at': '2019-09-01 09:40:23',
#   'date': '2019-09-01',
#   'id': 1168096253479194625,
#   'text': '@benOzge_ @COUNTRY_Erturk @DENIZ_BA_RAN @cigdemgng @Neclazsel3 @Berfinim_Deniz @TC_BERFIN @capulcu_ihtiyar @BerfinYakamoz @SeherdoganD @zafGngr @zgrkc @BDSenol @HERSEYCOKGZELO3 @turkcemile66 @denizim48 @CENGPASAVLI @ArtukPolat @ayseucar5 @kadturay @Gezgin_Sadik @sevimbozkurt5 @62Fgn @DemSultan @yusufguney060 @OnbasiHalide @asenaasla @handemikk @Akif_olmak #1EylülDünyaBarışGünü kutlu olsun',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 2309922296,
#   'created_at': '2019-09-01 09:40:23',
#   'date': '2019-09-01',
#   'id': 1168096253479194625,
#   'text': '@benOzge_ @COUNTRY_Erturk @DENIZ_BA_RAN @cigdemgng @Neclazsel3 @Berfinim_Deniz @TC_BERFIN @capulcu_ihtiyar @BerfinYakamoz @SeherdoganD @zafGngr @zgrkc @BDSenol @HERSEYCOKGZELO3 @turkcemile66 @denizim48 @CENGPASAVLI @ArtukPolat @ayseucar5 @kadturay @Gezgin_Sadik @sevimbozkurt5 @62Fgn @DemSultan @yusufguney060 @OnbasiHalide @asenaasla @handemikk @Akif_olmak #1EylülDünyaBarışGünü kutlu olsun',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 863698434758410240,
#   'created_at': '2019-09-01 09:45:40',
#   'date': '2019-09-01',
#   'id': 1168097583044210689,
#   'text': 'RT @SLuleci: Yurtta Barış, Dünyada Barış #1EylülDünyaBarışGünü Kutlu Olsun https://t.co/871y0aTjW9',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 863698434758410240,
#   'created_at': '2019-09-01 09:45:40',
#   'date': '2019-09-01',
#   'id': 1168097583044210689,
#   'text': 'RT @SLuleci: Yurtta Barış, Dünyada Barış #1EylülDünyaBarışGünü Kutlu Olsun https://t.co/871y0aTjW9',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 165061762,
#   'created_at': '2019-09-01 09:48:07',
#   'date': '2019-09-01',
#   'id': 1168098199632060416,
#   'text': 'RT @ibrahimbuyukak: #1EylülDünyaBarışGünü kutlu olsun🙏 https://t.co/haIfE8szUn',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 165061762,
#   'created_at': '2019-09-01 09:48:07',
#   'date': '2019-09-01',
#   'id': 1168098199632060416,
#   'text': 'RT @ibrahimbuyukak: #1EylülDünyaBarışGünü kutlu olsun🙏 https://t.co/haIfE8szUn',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 715468818206822400,
#   'created_at': '2019-09-01 09:48:13',
#   'date': '2019-09-01',
#   'id': 1168098224806273024,
#   'text': 'RT @hizmetissendika: ARSLAN’DAN 1 EYLÜL DÜNYA BARIŞ GÜNÜ MESAJI  “ULUSLARARASI KURULUŞLAR KALICI BARIŞ İÇİN ROL OYNAMALIDIR” #1EylülDünyaBarışGünü  https://t.co/AZDyPKMFNb https://t.co/ihkPqSrNXr',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 715468818206822400,
#   'created_at': '2019-09-01 09:48:13',
#   'date': '2019-09-01',
#   'id': 1168098224806273024,
#   'text': 'RT @hizmetissendika: ARSLAN’DAN 1 EYLÜL DÜNYA BARIŞ GÜNÜ MESAJI  “ULUSLARARASI KURULUŞLAR KALICI BARIŞ İÇİN ROL OYNAMALIDIR” #1EylülDünyaBarışGünü  https://t.co/AZDyPKMFNb https://t.co/ihkPqSrNXr',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1139853398222802944,
#   'created_at': '2019-09-01 09:48:46',
#   'date': '2019-09-01',
#   'id': 1168098363218309123,
#   'text': 'RT @FatmaYalnkaya19: #1EylülDünyaBarışGünü yurtta barış, Dünya da barış.  🇹🇷🕊🕊  MUSTAFA KEMAL ATATÜRK https://t.co/Y1eiR1KxFd',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1139853398222802944,
#   'created_at': '2019-09-01 09:48:46',
#   'date': '2019-09-01',
#   'id': 1168098363218309123,
#   'text': 'RT @FatmaYalnkaya19: #1EylülDünyaBarışGünü yurtta barış, Dünya da barış.  🇹🇷🕊🕊  MUSTAFA KEMAL ATATÜRK https://t.co/Y1eiR1KxFd',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1165679531287568385,
#   'created_at': '2019-09-01 09:49:52',
#   'date': '2019-09-01',
#   'id': 1168098640008814592,
#   'text': 'RT @haydi_sesver: @vekilince Her Eylül yeni bir başlangıç Seç bir Eylül gel  Sıra SENDE Başkanım ... @vekilince  #LiderÖnünüGörendir  #1EylülDünyaBarışGünü https://t.co/bdRQp0KmEd',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1165679531287568385,
#   'created_at': '2019-09-01 09:49:52',
#   'date': '2019-09-01',
#   'id': 1168098640008814592,
#   'text': 'RT @haydi_sesver: @vekilince Her Eylül yeni bir başlangıç Seç bir Eylül gel  Sıra SENDE Başkanım ... @vekilince  #LiderÖnünüGörendir  #1EylülDünyaBarışGünü https://t.co/bdRQp0KmEd',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 882215643566800897,
#   'created_at': '2019-09-01 09:54:02',
#   'date': '2019-09-01',
#   'id': 1168099688597348352,
#   'text': 'RT @Uur18ugur: @mavism1907 Barış, bir annenin gülümseyişinden başka bir şey değildir Ve toprakta derin izler açan sabanların tek bir sözcüktür yazdıkları Barış  #1EylülDünyaBarışGünü https://t.co/8JJtFW980m',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 882215643566800897,
#   'created_at': '2019-09-01 09:54:02',
#   'date': '2019-09-01',
#   'id': 1168099688597348352,
#   'text': 'RT @Uur18ugur: @mavism1907 Barış, bir annenin gülümseyişinden başka bir şey değildir Ve toprakta derin izler açan sabanların tek bir sözcüktür yazdıkları Barış  #1EylülDünyaBarışGünü https://t.co/8JJtFW980m',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 573515495,
#   'created_at': '2019-09-01 09:58:51',
#   'date': '2019-09-01',
#   'id': 1168100900751233026,
#   'text': 'RT @DrKerimoglu: “Dağlar, insanlar ve hatta ölüm bile yorulduysa şimdi en güzel şiir barıştır.”  #YaşarKemal  Hep birlikte BARIŞ ve HUZUR içinde yaşayacağımız güzel günler diliyorum. #1EylülDünyaBarışGünü https://t.co/lphNLO2tR6',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 573515495,
#   'created_at': '2019-09-01 09:58:51',
#   'date': '2019-09-01',
#   'id': 1168100900751233026,
#   'text': 'RT @DrKerimoglu: “Dağlar, insanlar ve hatta ölüm bile yorulduysa şimdi en güzel şiir barıştır.”  #YaşarKemal  Hep birlikte BARIŞ ve HUZUR içinde yaşayacağımız güzel günler diliyorum. #1EylülDünyaBarışGünü https://t.co/lphNLO2tR6',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 4158566597,
#   'created_at': '2019-09-01 09:59:33',
#   'date': '2019-09-01',
#   'id': 1168101076907827200,
#   'text': '✓✓® Burası Türkiye Değil, Avustralya❗  Atatürk Anıtının Açılışını Yapan Türk Halkı Değil, Avustralya Halkı..!   Düşmanları Tarafından Bile Çok Sevilen Ve Saygı Duyulan Lider  Mustafa Kemal #Atatürk 🇹🇷  Haber İngiltere..  #1EylülDünyaBarışGünü 🇹🇷 https://t.co/VJdkWgghka',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 4158566597,
#   'created_at': '2019-09-01 09:59:33',
#   'date': '2019-09-01',
#   'id': 1168101076907827200,
#   'text': '✓✓® Burası Türkiye Değil, Avustralya❗  Atatürk Anıtının Açılışını Yapan Türk Halkı Değil, Avustralya Halkı..!   Düşmanları Tarafından Bile Çok Sevilen Ve Saygı Duyulan Lider  Mustafa Kemal #Atatürk 🇹🇷  Haber İngiltere..  #1EylülDünyaBarışGünü 🇹🇷 https://t.co/VJdkWgghka',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 1122549278264762369,
#   'created_at': '2019-09-01 10:04:54',
#   'date': '2019-09-01',
#   'id': 1168102423296131072,
#   'text': 'Bin yıldır kardeşçe yaşamış ve bin yıl daha kardeşçe yaşayacak Anadolu insanından tüm dünyaya; Dünya Barış Gününüz kutlu olsun.  #Atatürk #Eylül #1EylülDünyaBarışGünü #YurttaBarışDünyadaBarış #helloseptember #hosgeldıneylül #KYKZamlarınaHayır #WorldPeaceDay https://t.co/3BgOANcfvE',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 1122549278264762369,
#   'created_at': '2019-09-01 10:04:54',
#   'date': '2019-09-01',
#   'id': 1168102423296131072,
#   'text': 'Bin yıldır kardeşçe yaşamış ve bin yıl daha kardeşçe yaşayacak Anadolu insanından tüm dünyaya; Dünya Barış Gününüz kutlu olsun.  #Atatürk #Eylül #1EylülDünyaBarışGünü #YurttaBarışDünyadaBarış #helloseptember #hosgeldıneylül #KYKZamlarınaHayır #WorldPeaceDay https://t.co/3BgOANcfvE',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 1113390379137667072,
#   'created_at': '2019-09-01 10:06:40',
#   'date': '2019-09-01',
#   'id': 1168102867871424512,
#   'text': 'RT @ATAM_VATAN_: @vekilince #1EylülDünyaBarışGünü Sevdikçe Çoğalır Sevildikçe Özgür Olur Kenetlenip Sarıldıkça BAŞARIRSIN @vekilince 💖 SAYGILAR SELAMLAR SAYIN MUHARREM İNCE 🇹🇷 Herşeye  ve Herkese Rağmen Sarılmak GÜZELDİR DOSTÇA KARDEŞÇE ARKADAŞÇA VE SEVEREK☘️ https://t.co/T6AOOd68zN',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1113390379137667072,
#   'created_at': '2019-09-01 10:06:40',
#   'date': '2019-09-01',
#   'id': 1168102867871424512,
#   'text': 'RT @ATAM_VATAN_: @vekilince #1EylülDünyaBarışGünü Sevdikçe Çoğalır Sevildikçe Özgür Olur Kenetlenip Sarıldıkça BAŞARIRSIN @vekilince 💖 SAYGILAR SELAMLAR SAYIN MUHARREM İNCE 🇹🇷 Herşeye  ve Herkese Rağmen Sarılmak GÜZELDİR DOSTÇA KARDEŞÇE ARKADAŞÇA VE SEVEREK☘️ https://t.co/T6AOOd68zN',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 991402249250369538,
#   'created_at': '2019-09-01 10:07:08',
#   'date': '2019-09-01',
#   'id': 1168102985307774976,
#   'text': 'RT @TuranHancerli: “Sevginin gücü, güce olan sevgiyi yendiğinde, dünya barışı tanıyacak…“  Barışın, özgürlüğün ve adaletin egemen olacağı, ayrımcılığın son bulacağı; çocukların hep güldüğü, mutlu ve huzur dolu bir dünya dileğiyle.  #1EylülDünyaBarışGünü https://t.co/tuVcPCZwi6',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 991402249250369538,
#   'created_at': '2019-09-01 10:07:08',
#   'date': '2019-09-01',
#   'id': 1168102985307774976,
#   'text': 'RT @TuranHancerli: “Sevginin gücü, güce olan sevgiyi yendiğinde, dünya barışı tanıyacak…“  Barışın, özgürlüğün ve adaletin egemen olacağı, ayrımcılığın son bulacağı; çocukların hep güldüğü, mutlu ve huzur dolu bir dünya dileğiyle.  #1EylülDünyaBarışGünü https://t.co/tuVcPCZwi6',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1063319482091937792,
#   'created_at': '2019-09-01 10:10:18',
#   'date': '2019-09-01',
#   'id': 1168103782229655552,
#   'text': 'RT @sgdfsosyalmedya: 1 Eylül Dünya Barış gününde, barışı kazanacağımızı haykırarak Kartal’dayız. Kartal kayyumlara cevap veriyor; Kayyum sizin direniş bizim #Eylül #1EylülDünyaBarışGünü https://t.co/IIvVAquUfE',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1063319482091937792,
#   'created_at': '2019-09-01 10:10:18',
#   'date': '2019-09-01',
#   'id': 1168103782229655552,
# ...
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 4612113615,
#   'created_at': '2019-09-01 18:44:29',
#   'date': '2019-09-01',
#   'id': 1168233180694007808,
#   'text': "RT @HemmedAliAslan: Hapisteki bebeklerle barışın !  Khk'lilerle barışın ! Eyt'lilerle barışın !  Emekçilerle barışın !  Gençlerle barışın ! Öğrencilerle barışın !  Halkın iradesi ile barışın !  Kendinizle barışın ! Adaletle barışın !!!  #1EylülDünyaBarışGünü",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 727598890338402304,
#   'created_at': '2019-09-01 18:48:56',
#   'date': '2019-09-01',
#   'id': 1168234300573196289,
#   'text': 'RT @wilmakedi: Dünyada silah üretiminde milyarlarca dolar paranın döndüğü ve barış yanlısı olduğunu söyleyerek savaşmanın,   dünya barış günü olarak ilan etmenin mantığı olabilir mi?  #1EylülDünyaBarışGünü https://t.co/RkW5jXew7I',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 727598890338402304,
#   'created_at': '2019-09-01 18:48:56',
#   'date': '2019-09-01',
#   'id': 1168234300573196289,
#   'text': 'RT @wilmakedi: Dünyada silah üretiminde milyarlarca dolar paranın döndüğü ve barış yanlısı olduğunu söyleyerek savaşmanın,   dünya barış günü olarak ilan etmenin mantığı olabilir mi?  #1EylülDünyaBarışGünü https://t.co/RkW5jXew7I',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 727802397490327552,
#   'created_at': '2019-09-01 18:50:49',
#   'date': '2019-09-01',
#   'id': 1168234774563102720,
#   'text': 'RT @gokanzeybekCHP: #1EylülDünyaBarışGünü Kutlu Olsun https://t.co/lZPlZJ3trk',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 727802397490327552,
#   'created_at': '2019-09-01 18:50:49',
#   'date': '2019-09-01',
#   'id': 1168234774563102720,
#   'text': 'RT @gokanzeybekCHP: #1EylülDünyaBarışGünü Kutlu Olsun https://t.co/lZPlZJ3trk',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 3812806816,
#   'created_at': '2019-09-01 18:54:38',
#   'date': '2019-09-01',
#   'id': 1168235735025143810,
#   'text': 'RT @siyasidarbe14: Barış mutlak Barış Şartsız şurtsuz, amasız lakinsiz hemen şimdi Barış.  sömürüsüz, huzurun ve barışın olduğu güzel bir dünya umuduyla 1 Eylül Dünya Barış Günü kutlu olsun.  Rojbaş dostlar   Bugun de sana hasret @hdpdemirtas  #1EylülDünyaBarışGünü https://t.co/SGuVwWzj9u',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 3812806816,
#   'created_at': '2019-09-01 18:54:38',
#   'date': '2019-09-01',
#   'id': 1168235735025143810,
#   'text': 'RT @siyasidarbe14: Barış mutlak Barış Şartsız şurtsuz, amasız lakinsiz hemen şimdi Barış.  sömürüsüz, huzurun ve barışın olduğu güzel bir dünya umuduyla 1 Eylül Dünya Barış Günü kutlu olsun.  Rojbaş dostlar   Bugun de sana hasret @hdpdemirtas  #1EylülDünyaBarışGünü https://t.co/SGuVwWzj9u',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 892824089156571136,
#   'created_at': '2019-09-01 19:00:10',
#   'date': '2019-09-01',
#   'id': 1168237127563431936,
#   'text': 'RT @hulyakeskinq: @KemalistTim @ahlattas @basak2ee @NKKoksel @Cennet68204321 @mywayTurkey @KursatCoglu @mka_asigi @Aslican33 @_SerapErim #1EylülDünyaBarışGünü  Yurtta Barış,Dünyada Barış                     MUSTAFA KEMAL ATATÜRK https://t.co/33EEiL3XmD',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 892824089156571136,
#   'created_at': '2019-09-01 19:00:10',
#   'date': '2019-09-01',
#   'id': 1168237127563431936,
#   'text': 'RT @hulyakeskinq: @KemalistTim @ahlattas @basak2ee @NKKoksel @Cennet68204321 @mywayTurkey @KursatCoglu @mka_asigi @Aslican33 @_SerapErim #1EylülDünyaBarışGünü  Yurtta Barış,Dünyada Barış                     MUSTAFA KEMAL ATATÜRK https://t.co/33EEiL3XmD',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 3372541720,
#   'created_at': '2019-09-01 19:01:06',
#   'date': '2019-09-01',
#   'id': 1168237362440278016,
#   'text': 'RT @SelcukMizrakli: Böyle olur Amed’in barışı! #1EylülDünyaBarışGünü https://t.co/pMX7KIavwP',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 3372541720,
#   'created_at': '2019-09-01 19:01:06',
#   'date': '2019-09-01',
#   'id': 1168237362440278016,
#   'text': 'RT @SelcukMizrakli: Böyle olur Amed’in barışı! #1EylülDünyaBarışGünü https://t.co/pMX7KIavwP',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1166830619856384001,
#   'created_at': '2019-09-01 19:17:13',
#   'date': '2019-09-01',
#   'id': 1168241418307063809,
#   'text': 'RT @gula_dersim: BARIŞta ;  Herkes kendi teninin renginde türküler söyler , anasının öğrettiği dilde güler . Sarı saç siyaha , siyah ten beyaza karışır . Beyaz ırkın kibrinin camdan kalesi , bir fiskede yıkılır . / Türkan Elçi / #1EylülDünyaBarışGünü  🕊',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1166830619856384001,
#   'created_at': '2019-09-01 19:17:13',
#   'date': '2019-09-01',
#   'id': 1168241418307063809,
#   'text': 'RT @gula_dersim: BARIŞta ;  Herkes kendi teninin renginde türküler söyler , anasının öğrettiği dilde güler . Sarı saç siyaha , siyah ten beyaza karışır . Beyaz ırkın kibrinin camdan kalesi , bir fiskede yıkılır . / Türkan Elçi / #1EylülDünyaBarışGünü  🕊',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 3012651898,
#   'created_at': '2019-09-01 19:54:37',
#   'date': '2019-09-01',
#   'id': 1168250830337794049,
#   'text': "RT @azizaydinlikchp: Kadın Kolları Genel Başkanı Sayın Fatma KÖSE, PM Üyemiz Sayın Erbil AYDINLIK, İl Başkanımız Sayın Hayrettin CİDİR, Sivil Toplum Örgütlerinin çok değerli temsilcileri ile birlikte Şanlıurfa Topçu Meydanı'nda #1EylülDünyaBarışGünü 'nü kutladık... https://t.co/phaJI7Ulbn",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 3012651898,
#   'created_at': '2019-09-01 19:54:37',
#   'date': '2019-09-01',
#   'id': 1168250830337794049,
#   'text': "RT @azizaydinlikchp: Kadın Kolları Genel Başkanı Sayın Fatma KÖSE, PM Üyemiz Sayın Erbil AYDINLIK, İl Başkanımız Sayın Hayrettin CİDİR, Sivil Toplum Örgütlerinin çok değerli temsilcileri ile birlikte Şanlıurfa Topçu Meydanı'nda #1EylülDünyaBarışGünü 'nü kutladık... https://t.co/phaJI7Ulbn",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1061648223432048640,
#   'created_at': '2019-09-01 20:08:53',
#   'date': '2019-09-01',
#   'id': 1168254420666241025,
#   'text': 'RT @smyrna1923: Irkçılık ideolojik bir düşünce değil, Aksine psikolojik bir hastalıktır   #MalcomX  #1EylülDünyaBarışGünü #DünyaBarışGünü #Eylül https://t.co/mlv1tbznds',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1061648223432048640,
#   'created_at': '2019-09-01 20:08:53',
#   'date': '2019-09-01',
#   'id': 1168254420666241025,
#   'text': 'RT @smyrna1923: Irkçılık ideolojik bir düşünce değil, Aksine psikolojik bir hastalıktır   #MalcomX  #1EylülDünyaBarışGünü #DünyaBarışGünü #Eylül https://t.co/mlv1tbznds',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1128773878413705217,
#   'created_at': '2019-09-01 20:20:26',
#   'date': '2019-09-01',
#   'id': 1168257327323070465,
#   'text': 'RT @kemalsahin58: 🕊1 Eylül Dünya Barış Günü Kutlu Olsun. #1EylülDünyaBarışGünü https://t.co/bYYsu9tTJo',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1128773878413705217,
#   'created_at': '2019-09-01 20:20:26',
#   'date': '2019-09-01',
#   'id': 1168257327323070465,
#   'text': 'RT @kemalsahin58: 🕊1 Eylül Dünya Barış Günü Kutlu Olsun. #1EylülDünyaBarışGünü https://t.co/bYYsu9tTJo',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1059860106937020416,
#   'created_at': '2019-09-01 20:25:34',
#   'date': '2019-09-01',
#   'id': 1168258619156156417,
#   'text': 'RT @Atasoner____: ✓✓® Burası Türkiye Değil, Avustralya❗  Atatürk Anıtının Açılışını Yapan Türk Halkı Değil, Avustralya Halkı..!   Düşmanları Tarafından Bile Çok Sevilen Ve Saygı Duyulan Lider  Mustafa Kemal #Atatürk 🇹🇷  Haber İngiltere..  #1EylülDünyaBarışGünü 🇹🇷 https://t.co/VJdkWgghka',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1059860106937020416,
#   'created_at': '2019-09-01 20:25:34',
#   'date': '2019-09-01',
#   'id': 1168258619156156417,
#   'text': 'RT @Atasoner____: ✓✓® Burası Türkiye Değil, Avustralya❗  Atatürk Anıtının Açılışını Yapan Türk Halkı Değil, Avustralya Halkı..!   Düşmanları Tarafından Bile Çok Sevilen Ve Saygı Duyulan Lider  Mustafa Kemal #Atatürk 🇹🇷  Haber İngiltere..  #1EylülDünyaBarışGünü 🇹🇷 https://t.co/VJdkWgghka',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 66324559,
#   'created_at': '2019-09-01 20:49:57',
#   'date': '2019-09-01',
#   'id': 1168264755448098818,
#   'text': 'Hani kimsenin doğru dürüst tanımlayamadığı "Cumhurbaşkanlığı Hükumet Sistemi" denilen garabetin ülkeyi getirdiği yer, durum budur! #1EylülDünyaBarışGünü https://t.co/7wOOlJvSnX',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'tweet'},
#  {'author_id': 66324559,
#   'created_at': '2019-09-01 20:49:57',
#   'date': '2019-09-01',
#   'id': 1168264755448098818,
#   'text': 'Hani kimsenin doğru dürüst tanımlayamadığı "Cumhurbaşkanlığı Hükumet Sistemi" denilen garabetin ülkeyi getirdiği yer, durum budur! #1EylülDünyaBarışGünü https://t.co/7wOOlJvSnX',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'tweet'},
#  {'author_id': 314413532,
#   'created_at': '2019-09-01 20:50:31',
#   'date': '2019-09-01',
#   'id': 1168264898058608640,
#   'text': 'RT @ismail_kaya_63: Filistin’de bir duvara barış güvercini resmedilmiş; yalnız resimde önemli bir detay var, bu barış güvercini çelik yelekli. Çünkü namluların hedefi “BARIŞ”  #1EylülDünyaBarışGünü Kutlu olsun https://t.co/ayc1qrCErn',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 314413532,
#   'created_at': '2019-09-01 20:50:31',
#   'date': '2019-09-01',
#   'id': 1168264898058608640,
#   'text': 'RT @ismail_kaya_63: Filistin’de bir duvara barış güvercini resmedilmiş; yalnız resimde önemli bir detay var, bu barış güvercini çelik yelekli. Çünkü namluların hedefi “BARIŞ”  #1EylülDünyaBarışGünü Kutlu olsun https://t.co/ayc1qrCErn',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 527908112,
#   'created_at': '2019-09-01 20:58:19',
#   'date': '2019-09-01',
#   'id': 1168266860984446976,
#   'text': 'RT @rehavimehmet: Ne özel, ne anlamlı, ne gurur verici..  Can Yücel ‘ce bir eklemeyle belki: Mesele sevmek değil, kime sorsan seviyor zaten/ Önemli olan güzel sevmek/ Kırmadan, yormadan, acıtmadan sevmek...  #dünyabarışgünü #1EylülDünyaBarışGünü https://t.co/EaYRLU5aPe',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 527908112,
#   'created_at': '2019-09-01 20:58:19',
#   'date': '2019-09-01',
#   'id': 1168266860984446976,
#   'text': 'RT @rehavimehmet: Ne özel, ne anlamlı, ne gurur verici..  Can Yücel ‘ce bir eklemeyle belki: Mesele sevmek değil, kime sorsan seviyor zaten/ Önemli olan güzel sevmek/ Kırmadan, yormadan, acıtmadan sevmek...  #dünyabarışgünü #1EylülDünyaBarışGünü https://t.co/EaYRLU5aPe',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 840204423477497857,
#   'created_at': '2019-09-01 21:10:04',
#   'date': '2019-09-01',
#   'id': 1168269817947795456,
#   'text': 'RT @meminadiyaman_: KAYYIM ve DARBE sözcükleri yasakmış ! Halkın iradesine el koyuyormuş ! Yasaklasanızda, elkoysanızda halk ayaktadır, iradesine sahiptir.  Gidici olan faşist iktidardır. İşte halk, işte Amed, işte #1EylülDünyaBarışGünü #Eylül https://t.co/6WzWb4Ifnh',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 840204423477497857,
#   'created_at': '2019-09-01 21:10:04',
#   'date': '2019-09-01',
#   'id': 1168269817947795456,
#   'text': 'RT @meminadiyaman_: KAYYIM ve DARBE sözcükleri yasakmış ! Halkın iradesine el koyuyormuş ! Yasaklasanızda, elkoysanızda halk ayaktadır, iradesine sahiptir.  Gidici olan faşist iktidardır. İşte halk, işte Amed, işte #1EylülDünyaBarışGünü #Eylül https://t.co/6WzWb4Ifnh',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1142592501045481472,
#   'created_at': '2019-09-01 21:25:13',
#   'date': '2019-09-01',
#   'id': 1168273630565928960,
#   'text': 'RT @FerhatEncu: Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir barıştır. (Yaşar Kemal)  #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1142592501045481472,
#   'created_at': '2019-09-01 21:25:13',
#   'date': '2019-09-01',
#   'id': 1168273630565928960,
#   'text': 'RT @FerhatEncu: Dağlar, insanlar ve hatta ölüm bile yorulduysa, şimdi en güzel şiir barıştır. (Yaşar Kemal)  #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 957395691134910465,
#   'created_at': '2019-09-01 22:16:59',
#   'date': '2019-09-01',
#   'id': 1168286658070032384,
#   'text': "RT @gokhanyukselist: Zafer Bayramı Etkinliklerimizin son günü olan Dünya Barış Günü'nde Feridun Düzağaç sevilen şarkıları ile birlikte Kartallı komşularımızla buluştu. Teşekkürler Kartal! 🇹🇷 #BüyükAilemKartal #1EylülDünyaBarışGünü https://t.co/dl2KJVDzPu",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 957395691134910465,
#   'created_at': '2019-09-01 22:16:59',
#   'date': '2019-09-01',
#   'id': 1168286658070032384,
#   'text': "RT @gokhanyukselist: Zafer Bayramı Etkinliklerimizin son günü olan Dünya Barış Günü'nde Feridun Düzağaç sevilen şarkıları ile birlikte Kartallı komşularımızla buluştu. Teşekkürler Kartal! 🇹🇷 #BüyükAilemKartal #1EylülDünyaBarışGünü https://t.co/dl2KJVDzPu",
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'},
#  {'author_id': 1113494987021459457,
#   'created_at': '2019-09-01 23:19:57',
#   'date': '2019-09-01',
#   'id': 1168302504184074240,
#   'text': 'RT @inisiyatifAmed: "Savaşta; yaşamın kutsallığını, kişinin yegâne varlık olduğunu samimiyet ve cesaretle savunanın,  ölmenin ve öldürmenin karşısında kat’i surette duranın sesi, bir mezarın ışığı kadardır. Kurşunun gölgesinde barışın sesi, kendi topraklarına mültecidir."  #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-02',
#   'tweet_type': 'retweet'},
#  {'author_id': 1113494987021459457,
#   'created_at': '2019-09-01 23:19:57',
#   'date': '2019-09-01',
#   'id': 1168302504184074240,
#   'text': 'RT @inisiyatifAmed: "Savaşta; yaşamın kutsallığını, kişinin yegâne varlık olduğunu samimiyet ve cesaretle savunanın,  ölmenin ve öldürmenin karşısında kat’i surette duranın sesi, bir mezarın ışığı kadardır. Kurşunun gölgesinde barışın sesi, kendi topraklarına mültecidir."  #1EylülDünyaBarışGünü',
#   'trend': '#1EylülDünyaBarışGünü',
#   'trend_date': '2019-09-01',
#   'tweet_type': 'retweet'}]

# %%
import sys
# !{sys.executable} -m pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 8.7 MB/s eta 0:00:01
# Installing collected packages: emoji
# Successfully installed emoji-1.2.0
