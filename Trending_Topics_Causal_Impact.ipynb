# %% [markdown]
# # Trending Topics Event Study
# - How much does going trending increase engagement?
#
# Broadly, the steps:
#
# 1. Infer exact time of trending based on trending data
# 2. RD estimate of causal effect
#
# ### Causal Model
# Assume that there is no external event triggering engagement. Then, engagement with the hashtag comes from a) exposure to original use before trending and b) exposure through trending topics page
#
# $Y_{i,t} = \alpha + \lambda_{RD} Trend_{i,t} + \beta_1 Exposed_{i,t} + \beta_2 t $

# %%
import preprocessing
from config import TRENDS_DIR
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import tqdm
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, date, timedelta
from config import TWITTER_DATA_DIR
import pickle
import statsmodels.formula.api as smf
import graphviz as gr
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
g = gr.Digraph(format='png')
g.edge("Trending Topics", "Hashtag Engagement")
g.edge("External Event", "Hashtag Engagement")
g.edge("Follower Network Exposure", "Hashtag Engagement")
g

# %%
g = gr.Digraph(format='png')
g.edge("Trending Topics", "Hashtag Engagement")
g.edge("Follower Network Exposure", "Hashtag Engagement")
g

# %%
def get_trend_behavior(ht):
    '''Takes a hashtag and compiles all trend date about it
    Currently just returns the beginning and end of the trending status, but can do more potentially
    '''
    res = [] 
    for entry in os.scandir(TRENDS_DIR):
        # crude filtering for date csv names 
        if entry.path[-7] == '-':
            df = pd.read_csv(entry, header=None,
                            names=['hashtag', 'place', 
                                   'level', 'day', 
                                   'time', 'volume', 'nan'])
            df['hashtag'] = df.hashtag.apply(lambda x: x.replace('#','').lower())
            try:
                df['datetime'] = pd.to_datetime(df.day + df.time, format='%Y-%m-%d%H:%M')
            except:
                print('error with hashtag', ht)
                return df
            temp = df.query(f'hashtag == "{ht}"')
            if len(temp) > 0:
                res.append(temp)
    if len(res) > 0:
        return pd.concat(res)
    else:
        print(ht, 'did not appear to trend')
        return pd.DataFrame()

# %%
campaigns = preprocessing.load_campaign()

# %%
hashtag = 'jharkhandwithmodi'
tweets = campaigns[hashtag]

# %%
with open(os.path.join(TWITTER_DATA_DIR, 'exposure_results.pkl'), 'rb') as f:
    exposures = pickle.load(f)

# %%
def build_df(hashtag, tweet_dict, time_bin='5Min', 
            normalize_time=False):
    # returns timeseries and inferred trending time
    for t_id, tweet in tweet_dict.items():
        tweet['adj_date'] = tweet['date'] + timedelta(hours=5, minutes=30)
        if tweet['retweet_from'] == '':
            if tweet['template'] != '':
                tweet['type'] = 'template'
            else:
                tweet['type'] = 'regular'
        else:
            if tweet['template'] != '':
                tweet['type'] = 'template_retweet'
            else:
                tweet['type'] = 'regular_retweet'
    
        t_exp, n_exp, _ = exposures[hashtag][tweet['username']]
        tweet['template_exposure'] = t_exp
        tweet['normal_exposure'] = n_exp
        tweet['total_exposure'] = t_exp + n_exp
                
    df = pd.DataFrame.from_dict(tweet_dict).transpose()
    df.index = df['adj_date']
        
    trending_data = pd.read_csv(os.path.join(TRENDS_DIR, hashtag+'.csv'), parse_dates=['datetime'])
  
    start = trending_data.datetime.min() + timedelta(hours=5, minutes=30)
    end = trending_data.datetime.max() + timedelta(hours=5, minutes=30)

    min_date = start - timedelta(hours=6)
    max_date = end + timedelta(hours=6)

    colors = ["red","orange",'black','grey']
    types = ['template', 'template_retweet', 'regular', 'regular_retweet']

    series_list = []
    for t in types:
        temp = df[df.type == t] # only use regular tweets
        temp = temp.resample(time_bin).count().username.loc[min_date:max_date]
        series_list.append(temp)
    temp = df[df.type == 'regular'] # only use regular tweets
    series_list.append(temp[temp.total_exposure > 0].resample(time_bin).count().username.loc[min_date:max_date])
    temp = temp[temp.total_exposure == 0].resample(time_bin).count().username.loc[min_date:max_date]
    series_list.append(temp)
    
    new_df = pd.DataFrame(series_list).T
    new_df.columns=[*types, 'zero_exposure_regular', 'nonzero_exposure_regular']
    new_df['total_engagement'] = new_df[types].sum(axis=1)
    new_df['rt_engagement'] = new_df[['regular_retweet', 'template_retweet']].sum(axis=1)
    
    def find_jump(x, start):
        # takes a ts and finds the spike within the start period
        diffed = x.diff()
        for i in range(10):
            candidate = diffed.idxmax()
            if candidate >= start-timedelta(hours=1, minutes=5) and candidate < start:
                return candidate 
            else: # zero out the candidate
                diffed[candidate] = 0
        # no spike found in trending range
        return start - timedelta(hours=1, minutes=5)
    
    exact_trending_loc = find_jump(temp, start)
    
    if normalize_time:
        new_df.index = new_df.index - exact_trending_loc
        new_df.index = new_df.index.map(lambda x: int(x.total_seconds() / 60))
        exact_trending_loc = 0

    new_df['time'] = new_df.index
    new_df['time_i'] = range(len(new_df))
    new_df['time_i2'] = new_df['time_i']*new_df['time_i']

    return new_df, exact_trending_loc

# %%
def plot_trending_ts(df, exact_trending_loc, cols=['zero_exposure_regular', 'total_engagement']):
    # takes a df and plots the time series with some acoutrements
    fig = plt.figure(figsize=(14,9))

    trending_data = pd.read_csv(os.path.join(TRENDS_DIR, hashtag+'.csv'), parse_dates=['datetime'])
  
    start = trending_data.datetime.min() + timedelta(hours=5, minutes=30)
    end = trending_data.datetime.max() + timedelta(hours=5, minutes=30)

    min_date = start - timedelta(hours=6)
    max_date = end + timedelta(hours=6)
    for i, col in enumerate(cols):
        ax = plt.subplot(2, 1, i+1)
        temp = df[col]
        ax.scatter(temp.index, temp, label='Zero Exposure Tweets')

        ax.axvline(exact_trending_loc, color='r', ls='--', label='Inferred Trending Time')
        _, max_hist_level = ax.get_ylim()
        ax.plot([start - timedelta(hours=1), start], [max_hist_level*1.1]*2, '|--', color='black', alpha=1, 
                 label='Resolution Error') 
        ax.plot([start, end], [max_hist_level]*2, '-', color='black', alpha=1) 
        ax.plot([start, end], [max_hist_level]*2, '|', color='black') 
        ax.text(start + (end-start)/2, max_hist_level/1.1, f'#{hashtag} trending', fontsize=12, horizontalalignment='center')
        ax.set_xlabel('Time', fontsize=18)
        ax.set_ylabel('Tweet volume', fontsize=16)
        ax.set_title(col)
        import matplotlib.dates as mdates
        hours = mdates.HourLocator() 
        minutes  = mdates.MinuteLocator(byminute=range(0,61,15))
        ax.xaxis.set_major_locator(hours)
        ax.xaxis.set_minor_locator(minutes)
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
        #ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
        ax.grid(True)
        ax.grid(True, 'minor')
        
        
    fig.autofmt_xdate()
#     handles, labels = plt.gca().get_legend_handles_labels()
#     by_label = dict(zip(labels, handles))
#     plt.legend(by_label.values(), by_label.keys())
#     plt.legend()
    fig.suptitle(f'#{hashtag} Tweets Over Time')
#     plt.tight_layout()    
#     plt.show()

# %%
def run_statistics(data, thresh, 
                   model_fit_args=dict(cov_type='HAC',cov_kwds={'maxlags':1})):
    
    results = []
    def simple_table_to_df(tab, prefix):
        df = pd.read_html(tab.as_html(), index_col=0, header=0)[0]
        return pd.concat({prefix: df}, names=['Trial'])
    
    rdd_df = data.assign(threshold=(data.time > thresh).astype(int))
    i_thresh = data.time_i[data.time == thresh].values[0]
    
    # data effects around trending status
    rdd_df = rdd_df.iloc[i_thresh-20:i_thresh+40]
    
    model = smf.wls("regular~time_i*threshold+nonzero_exposure_regular", rdd_df).fit(**model_fit_args)
    results.append(simple_table_to_df(model.summary().tables[1], 'Tweets w/ cov'))

    #     ax = rdd_df.plot.scatter(x="time_i", y="regular", color="C0")
#     rdd_df.assign(predictions=model.fittedvalues).plot(x="time_i", y="predictions", ax=ax, color="C1")
#     plt.title("Regression Discontinuity");

    
    def kernel(R, c, h):
        indicator = (np.abs(R-c) <= h).astype(float)
        return indicator * (1 - np.abs(R-c)/h)

#     model = smf.wls("total_engagement~time_i*threshold", rdd_df,
#                    weights=kernel(data['time_i'], c=i_thresh, h=18)).fit(**model_fit_args)
#     results.append(simple_table_to_df(model.summary().tables[1], 'Weighted Total Engagement'))
    
    model = smf.wls("regular~time_i*threshold", rdd_df).fit(**model_fit_args)
    results.append(simple_table_to_df(model.summary().tables[1], 'Tweets'))
    
    model = smf.wls("total_engagement~time_i*threshold", rdd_df).fit(**model_fit_args)
    results.append(simple_table_to_df(model.summary().tables[1], 'Total Engagement'))
    
    model = smf.wls("zero_exposure_regular~time_i*threshold", rdd_df).fit(**model_fit_args)
    results.append(simple_table_to_df(model.summary().tables[1], 'Zero Exposure Tweets'))
    
    res_df = pd.concat(results)
    def highlight_significant(s):
        res = 'background-color: yellow' if s.z >= 1.96 else ''
        return [res for x in s] 
    display(res_df.style.apply(highlight_significant, axis=1))
    return res_df

# %%
def run_statistics_2(data, thresh, 
                   model_fit_args=dict(cov_type='HAC',cov_kwds={'maxlags':1})):
    
    def simple_table_to_df(tab, prefix):
        df = pd.read_html(tab.as_html(), index_col=0, header=0)[0]
        return pd.concat({prefix: df}, names=['Trial'])
    
    rdd_df = data.assign(threshold=(data.time > thresh).astype(int))
    i_thresh = data.time_i[data.time == thresh].values[0]
    
    # data effects around trending status
    rdd_df = rdd_df.iloc[i_thresh-12:i_thresh+12]
    
    model = smf.wls("regular~time_i*threshold+nonzero_exposure_regular", rdd_df).fit(**model_fit_args)
    res_df = simple_table_to_df(model.summary().tables[1], 'New Tweets')
    def highlight_significant(s):
        res = 'background-color: yellow' if s.z >= 1.96 else ''
        return [res for x in s] 

    display(res_df.style.apply(highlight_significant, axis=1))
    return res_df

# %%
res = run_statistics(*build_df(hashtag, tweets))
# Out:
# <style  type="text/css" >
#     #T_369aac48_543a_11eb_b460_000af7bd8fberow4_col0 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow4_col1 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow4_col2 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow4_col3 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow4_col4 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow4_col5 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow7_col0 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow7_col1 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow7_col2 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow7_col3 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow7_col4 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow7_col5 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow10_col0 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow10_col1 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow10_col2 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow10_col3 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow10_col4 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow10_col5 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow11_col0 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow11_col1 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow11_col2 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow11_col3 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow11_col4 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow11_col5 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow15_col0 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow15_col1 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow15_col2 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow15_col3 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow15_col4 {
#             background-color:  yellow;
#         }    #T_369aac48_543a_11eb_b460_000af7bd8fberow15_col5 {
#             background-color:  yellow;
#         }</style><table id="T_369aac48_543a_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_369aac48_543a_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>Tweets w/ cov</th>
#                         <th id="T_369aac48_543a_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >-3.505700</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >4.023000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >-0.871000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.384000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-11.391000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >4.379000</td>
#             </tr>
#             <tr>
#                                 <th id="T_369aac48_543a_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >0.084500</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.086000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >0.978000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.328000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >-0.085000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.254000</td>
#             </tr>
#             <tr>
#                                 <th id="T_369aac48_543a_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >11.056400</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >7.463000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >1.481000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.138000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >-3.571000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >25.684000</td>
#             </tr>
#             <tr>
#                                 <th id="T_369aac48_543a_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >-0.080200</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.118000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >-0.682000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.495000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-0.311000</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >0.150000</td>
#             </tr>
#             <tr>
#                                 <th id="T_369aac48_543a_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >1.203400</td>
#                         <td id="T_369aac48_543a_11eb_b460_000af7bd8

# %%
meta_res = []
for hashtag, tweet_dict in campaigns.items():
    try:
        res = run_statistics_2(*build_df(hashtag, tweet_dict))
        meta_res.append(pd.concat({hashtag: res}, names=['Hashtag']))
    except: 
        print(hashtag, ' did not work')
# Out:
# <style  type="text/css" >
#     #T_d639b474_544e_11eb_b460_000af7bd8fberow1_col0 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow1_col1 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow1_col2 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow1_col3 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow1_col4 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow1_col5 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow2_col0 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow2_col1 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow2_col2 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow2_col3 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow2_col4 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow2_col5 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow4_col0 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow4_col1 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow4_col2 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow4_col3 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow4_col4 {
#             background-color:  yellow;
#         }    #T_d639b474_544e_11eb_b460_000af7bd8fberow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_d639b474_544e_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d639b474_544e_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_d639b474_544e_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >-17.532700</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >8.650000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >-2.027000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.043000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-34.486000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >-0.579000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d639b474_544e_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >0.349800</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.171000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >2.042000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.041000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >0.014000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.685000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d639b474_544e_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >58.694000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >26.296000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >2.232000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.026000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >7.154000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >110.234000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d639b474_544e_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >-0.872500</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.421000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >-2.074000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.038000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-1.697000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >-0.048000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d639b474_544e_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >1.051000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.201000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >5.219000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >0.656000</td>
#                         <td id="T_d639b474_544e_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >1.446000</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_d6562988_544e_11eb_b460_000af7bd8fberow1_col0 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow1_col1 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow1_col2 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow1_col3 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow1_col4 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow1_col5 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow2_col0 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow2_col1 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow2_col2 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow2_col3 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow2_col4 {
#             background-color:  yellow;
#         }    #T_d6562988_544e_11eb_b460_000af7bd8fberow2_col5 {
#             background-color:  yellow;
#         }</style><table id="T_d6562988_544e_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6562988_544e_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_d6562988_544e_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >-6.358200</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >1.817000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >-3.499000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-9.920000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >-2.797000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d6562988_544e_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >0.881100</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.201000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >4.384000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >0.487000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >1.275000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d6562988_544e_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >19.336600</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >6.974000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >2.773000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.006000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >5.668000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >33.006000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d6562988_544e_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >-1.300600</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.275000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >-4.735000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-1.839000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >-0.762000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d6562988_544e_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >0.761400</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.577000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >1.320000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.187000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >-0.369000</td>
#                         <td id="T_d6562988_544e_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >1.892000</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_d905d098_544e_11eb_b460_000af7bd8fberow1_col0 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow1_col1 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow1_col2 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow1_col3 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow1_col4 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow1_col5 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow2_col0 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow2_col1 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow2_col2 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow2_col3 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow2_col4 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow2_col5 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow4_col0 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow4_col1 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow4_col2 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow4_col3 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow4_col4 {
#             background-color:  yellow;
#         }    #T_d905d098_544e_11eb_b460_000af7bd8fberow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_d905d098_544e_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d905d098_544e_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_d905d098_544e_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >-160.174800</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >44.696000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >-3.584000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-247.778000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >-72.572000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d905d098_544e_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >2.801900</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.751000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >3.730000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >1.329000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >4.274000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d905d098_544e_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >328.066900</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >140.190000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >2.340000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.019000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >53.299000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >602.835000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d905d098_544e_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >-4.325000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >1.887000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >-2.292000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.022000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-8.023000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >-0.627000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d905d098_544e_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >1.198800</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.581000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >2.063000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.039000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >0.060000</td>
#                         <td id="T_d905d098_544e_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >2.338000</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_d948121e_544e_11eb_b460_000af7bd8fberow1_col0 {
#             background-color:  yellow;
#         }    #T_d948121e_544e_11eb_b460_000af7bd8fberow1_col1 {
#             background-color:  yellow;
#         }    #T_d948121e_544e_11eb_b460_000af7bd8fberow1_col2 {
#             background-color:  yellow;
#         }    #T_d948121e_544e_11eb_b460_000af7bd8fberow1_col3 {
#             background-color:  yellow;
#         }    #T_d948121e_544e_11eb_b460_000af7bd8fberow1_col4 {
#             background-color:  yellow;
#         }    #T_d948121e_544e_11eb_b460_000af7bd8fberow1_col5 {
#             background-color:  yellow;
#         }</style><table id="T_d948121e_544e_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d948121e_544e_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_d948121e_544e_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >-9.354800</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >5.622000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >-1.664000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.096000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-20.374000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >1.665000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d948121e_544e_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >0.224900</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.109000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >2.066000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.039000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >0.012000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.438000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d948121e_544e_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >-22.710800</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >20.767000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >-1.094000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.274000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >-63.414000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >17.993000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d948121e_544e_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >0.365000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.327000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >1.115000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.265000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-0.277000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >1.007000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d948121e_544e_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >0.295600</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.646000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >0.457000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.647000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >-0.971000</td>
#                         <td id="T_d948121e_544e_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >1.563000</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col0 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col1 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col2 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col3 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col4 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col5 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col0 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col1 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col2 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col3 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col4 {
#             background-color:  yellow;
#         }    #T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_d96b78b2_544e_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d96b78b2_544e_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_d96b78b2_544e_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >0.224300</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >1.206000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >0.186000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.852000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-2.139000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >2.588000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d96b78b2_544e_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >-0.002200</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.027000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >-0.078000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.937000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >-0.056000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.052000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d96b78b2_544e_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >-23.102200</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >5.748000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >-4.019000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >-34.368000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >-11.836000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d96b78b2_544e_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >0.434600</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.098000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >4.419000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >0.242000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >0.627000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d96b78b2_544e_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >1.398600</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.469000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >2.984000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.003000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >0.480000</td>
#                         <td id="T_d96b78b2_544e_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >2.317000</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_d9ba16c0_544e_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d9ba16c0_544e_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_d9ba16c0_544e_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >-0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >0.000001</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >-0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >1.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-0.000001</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >0.000001</td>
#             </tr>
#             <tr>
#                                 <th id="T_d9ba16c0_544e_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >-0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >-0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >1.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >-0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d9ba16c0_544e_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >0.272700</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >2.562000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >0.106000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.915000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >-4.749000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >5.294000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d9ba16c0_544e_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >-0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.041000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >-0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-0.080000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >0.080000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d9ba16c0_544e_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >nan</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >0.000000</td>
#                         <td id="T_d9ba16c0_544e_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >0.000000</td>
#             </tr>
#     </tbody></table>
# timesofrahul  did not work
# threadsofexcellence  did not work
# msmetextilesconclave  did not work
# <style  type="text/css" >
# </style><table id="T_da3ce24e_544e_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da3ce24e_544e_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_da3ce24e_544e_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >-2.813300</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >1.842000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >-1.528000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.127000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-6.423000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >0.796000</td>
#             </tr>
#             <tr>
#                                 <th id="T_da3ce24e_544e_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >0.050500</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.033000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >1.531000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.126000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >-0.014000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.115000</td>
#             </tr>
#             <tr>
#                                 <th id="T_da3ce24e_544e_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >8.362200</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >10.952000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >0.763000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.445000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >-13.104000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >29.829000</td>
#             </tr>
#             <tr>
#                                 <th id="T_da3ce24e_544e_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >-0.099600</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.154000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >-0.648000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.517000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-0.401000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >0.202000</td>
#             </tr>
#             <tr>
#                                 <th id="T_da3ce24e_544e_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >0.467000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.343000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >1.361000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.174000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >-0.206000</td>
#                         <td id="T_da3ce24e_544e_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >1.140000</td>
#             </tr>
#     </tbody></table>
# म्हारा_वोट_भाजपा_को  did not work
# <style  type="text/css" >
#     #T_dd565898_544e_11eb_b460_000af7bd8fberow2_col0 {
#             background-color:  yellow;
#         }    #T_dd565898_544e_11eb_b460_000af7bd8fberow2_col1 {
#             background-color:  yellow;
#         }    #T_dd565898_544e_11eb_b460_000af7bd8fberow2_col2 {
#             background-color:  yellow;
#         }    #T_dd565898_544e_11eb_b460_000af7bd8fberow2_col3 {
#             background-color:  yellow;
#         }    #T_dd565898_544e_11eb_b460_000af7bd8fberow2_col4 {
#             background-color:  yellow;
#         }    #T_dd565898_544e_11eb_b460_000af7bd8fberow2_col5 {
#             background-color:  yellow;
#         }</style><table id="T_dd565898_544e_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd565898_544e_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_dd565898_544e_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_dd565898_544e_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >-12.047600</td>
#                         <td id="T_dd565898_544e_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >49.008000</td>
#                         <td id="T_dd565898_544e_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >-0.246000</td>
#                         <td id="T_dd565898_544e_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.806000</td>
#                         <td id="T_dd565898_544e_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-108.102000</td>
#                         <td id="T_dd565898_544e_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >84.007000</td>
#             </tr>
#             <tr>
#                                 <th id="T_dd565898_544e_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_dd565898_544e_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >0.842200</td>
#                         <td id="T_dd565898_544e_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.977000</td>
# ...
#             </tr>
#             <tr>
#                                 <th id="T_03c001b4_544f_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >-0.165500</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.534000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >-0.310000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.757000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >-1.212000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.881000</td>
#             </tr>
#             <tr>
#                                 <th id="T_03c001b4_544f_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >233.950800</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >91.222000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >2.565000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.010000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >55.159000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >412.742000</td>
#             </tr>
#             <tr>
#                                 <th id="T_03c001b4_544f_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >-3.001200</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >1.207000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >-2.486000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.013000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-5.368000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >-0.635000</td>
#             </tr>
#             <tr>
#                                 <th id="T_03c001b4_544f_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >0.261500</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.851000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >0.307000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.759000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >-1.406000</td>
#                         <td id="T_03c001b4_544f_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >1.929000</td>
#             </tr>
#     </tbody></table>
# armedforcesflagday  did not work
# nris4modi  did not work
# modifiedtextiles  did not work
# <style  type="text/css" >
# </style><table id="T_13c63cd6_544f_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13c63cd6_544f_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_13c63cd6_544f_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >0.796500</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >2.316000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >0.344000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.731000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >-3.743000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >5.336000</td>
#             </tr>
#             <tr>
#                                 <th id="T_13c63cd6_544f_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >0.001300</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.051000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >0.025000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.980000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >-0.098000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.101000</td>
#             </tr>
#             <tr>
#                                 <th id="T_13c63cd6_544f_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >-0.949300</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >10.763000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >-0.088000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.930000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >-22.044000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >20.145000</td>
#             </tr>
#             <tr>
#                                 <th id="T_13c63cd6_544f_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >0.058900</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.163000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >0.361000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.718000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >-0.261000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >0.378000</td>
#             </tr>
#             <tr>
#                                 <th id="T_13c63cd6_544f_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >0.974300</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.595000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >1.637000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.102000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >-0.192000</td>
#                         <td id="T_13c63cd6_544f_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >2.141000</td>
#             </tr>
#     </tbody></table>
# modifiedjobs  did not work
# <style  type="text/css" >
#     #T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col0 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col1 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col2 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col3 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col4 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col5 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col0 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col1 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col2 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col3 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col4 {
#             background-color:  yellow;
#         }    #T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col5 {
#             background-color:  yellow;
#         }</style><table id="T_14e0b33a_544f_11eb_b460_000af7bd8fbe" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr>    <tr>        <th class="index_name level0" >Trial</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14e0b33a_544f_11eb_b460_000af7bd8fbelevel0_row0" class="row_heading level0 row0" rowspan=5>New Tweets</th>
#                         <th id="T_14e0b33a_544f_11eb_b460_000af7bd8fbelevel1_row0" class="row_heading level1 row0" >Intercept</th>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col0" class="data row0 col0" >14.606900</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col1" class="data row0 col1" >6.941000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col2" class="data row0 col2" >2.104000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col3" class="data row0 col3" >0.035000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col4" class="data row0 col4" >1.002000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow0_col5" class="data row0 col5" >28.212000</td>
#             </tr>
#             <tr>
#                                 <th id="T_14e0b33a_544f_11eb_b460_000af7bd8fbelevel1_row1" class="row_heading level1 row1" >time_i</th>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow1_col0" class="data row1 col0" >-0.154700</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow1_col1" class="data row1 col1" >0.141000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow1_col2" class="data row1 col2" >-1.099000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow1_col3" class="data row1 col3" >0.272000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow1_col4" class="data row1 col4" >-0.431000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow1_col5" class="data row1 col5" >0.121000</td>
#             </tr>
#             <tr>
#                                 <th id="T_14e0b33a_544f_11eb_b460_000af7bd8fbelevel1_row2" class="row_heading level1 row2" >threshold</th>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow2_col0" class="data row2 col0" >-35.318700</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow2_col1" class="data row2 col1" >9.420000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow2_col2" class="data row2 col2" >-3.749000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow2_col4" class="data row2 col4" >-53.781000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow2_col5" class="data row2 col5" >-16.856000</td>
#             </tr>
#             <tr>
#                                 <th id="T_14e0b33a_544f_11eb_b460_000af7bd8fbelevel1_row3" class="row_heading level1 row3" >time_i:threshold</th>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col0" class="data row3 col0" >0.553800</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col1" class="data row3 col1" >0.170000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col2" class="data row3 col2" >3.260000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col3" class="data row3 col3" >0.001000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col4" class="data row3 col4" >0.221000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow3_col5" class="data row3 col5" >0.887000</td>
#             </tr>
#             <tr>
#                                 <th id="T_14e0b33a_544f_11eb_b460_000af7bd8fbelevel1_row4" class="row_heading level1 row4" >nonzero_exposure_regular</th>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow4_col0" class="data row4 col0" >0.649600</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow4_col1" class="data row4 col1" >0.470000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow4_col2" class="data row4 col2" >1.381000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow4_col3" class="data row4 col3" >0.167000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow4_col4" class="data row4 col4" >-0.272000</td>
#                         <td id="T_14e0b33a_544f_11eb_b460_000af7bd8fberow4_col5" class="data row4 col5" >1.571000</td>
#             </tr>
#     </tbody></table>

# %%
df
# Out:
#                                                           coef  std err  \
# Hashtag           Trial
# jharkhandwithmodi New Tweets Intercept                -17.5327    8.650
#                              time_i                     0.3498    0.171
#                              threshold                 58.6940   26.296
#                              time_i:threshold          -0.8725    0.421
#                              nonzero_exposure_regular   1.0510    0.201
# ...                                                        ...      ...
# gappupappu        New Tweets Intercept                 14.6069    6.941
#                              time_i                    -0.1547    0.141
#                              threshold                -35.3187    9.420
#                              time_i:threshold           0.5538    0.170
#                              nonzero_exposure_regular   0.6496    0.470
#
#                                                            z  P>|z|  [0.025  \
# Hashtag           Trial
# jharkhandwithmodi New Tweets Intercept                -2.027  0.043 -34.486
#                              time_i                    2.042  0.041   0.014
#                              threshold                 2.232  0.026   7.154
#                              time_i:threshold         -2.074  0.038  -1.697
#                              nonzero_exposure_regular  5.219  0.000   0.656
# ...                                                      ...    ...     ...
# gappupappu        New Tweets Intercept                 2.104  0.035   1.002
#                              time_i                   -1.099  0.272  -0.431
#                              threshold                -3.749  0.000 -53.781
#                              time_i:threshold          3.260  0.001   0.221
#                              nonzero_exposure_regular  1.381  0.167  -0.272
#
#                                                         0.975]       Trial  \
# Hashtag           Trial
# jharkhandwithmodi New Tweets Intercept                  -0.579  New Tweets
#                              time_i                      0.685  New Tweets
#                              threshold                 110.234  New Tweets
#                              time_i:threshold           -0.048  New Tweets
#                              nonzero_exposure_regular    1.446  New Tweets
# ...                                                        ...         ...
# gappupappu        New Tweets Intercept                  28.212  New Tweets
#                              time_i                      0.121  New Tweets
#                              threshold                 -16.856  New Tweets
#                              time_i:threshold            0.887  New Tweets
#                              nonzero_exposure_regular    1.571  New Tweets
#
#                                                                        Variable  \
# Hashtag           Trial
# jharkhandwithmodi New Tweets Intercept                                Intercept
#                              time_i                                      time_i
#                              threshold                                threshold
#                              time_i:threshold                  time_i:threshold
#                              nonzero_exposure_regular  nonzero_exposure_regular
# ...                                                                         ...
# gappupappu        New Tweets Intercept                                Intercept
#                              time_i                                      time_i
#                              threshold                                threshold
#                              time_i:threshold                  time_i:threshold
#                              nonzero_exposure_regular  nonzero_exposure_regular
#
#                                                                  Hashtag
# Hashtag           Trial
# jharkhandwithmodi New Tweets Intercept                 jharkhandwithmodi
#                              time_i                    jharkhandwithmodi
#                              threshold                 jharkhandwithmodi
#                              time_i:threshold          jharkhandwithmodi
#                              nonzero_exposure_regular  jharkhandwithmodi
# ...                                                                  ...
# gappupappu        New Tweets Intercept                        gappupappu
#                              time_i                           gappupappu
#                              threshold                        gappupappu
#                              time_i:threshold                 gappupappu
#                              nonzero_exposure_regular         gappupappu
#
# [220 rows x 9 columns]

# %%
df = pd.concat(meta_res)
df['Trial'] = df.index.get_level_values(1)
df['Variable'] = df.index.get_level_values(2)
df['Hashtag'] = df.index.get_level_values(0)

sns.boxplot(x='z', y='Variable', data=df)
plt.grid(True)
plt.title('Significance of Regression Coefficients')
plt.xlabel('Z score')
plt.ylabel('Model Parameter')
plt.axvline(2, color='grey', ls='--')
plt.axvline(-2, color='grey', ls='--')

# %%
df = pd.concat(meta_res)
df['Trial'] = df.index.get_level_values(1)
df['Variable'] = df.index.get_level_values(2)
df['Hashtag'] = df.index.get_level_values(0)

sns.boxplot(x='coef', y='Variable', data=df)
plt.grid(True)
plt.title('Coefficient Effect Sizes')
plt.xlabel('Coefficient')
plt.ylabel('Model Parameter')
# Out:
# Text(0, 0.5, 'Model Parameter')

# %%
import seaborn as sns

# %%
def meta_analysis(df):
    idx = pd.IndexSlice
    df['Trial'] = df.index.get_level_values(1)
    df['Variable'] = df.index.get_level_values(2)
    df['Hashtag'] = df.index.get_level_values(0)
    
    temp = df.loc[idx[:, :, ['threshold']], :] # ['threshold']], :]
    sns.boxplot(x='coef', y='Trial', data=temp)
    plt.grid(True)
    plt.title('Trending Topics Effect Size')
    plt.xlabel('Coefficient')
    plt.ylabel('Model')

# %%
meta_analysis(pd.concat(meta_res))

# %% [markdown]
# ## TODO
# - analyze entire panel
# - add logs
# - sensitivity to bin size
# -

# %% [markdown]
# ## Combining All Hashtags and Normalizing Time
#
# $Y_{iht} = \gamma_{h} + \lambda_t + \beta D_{ht} + \epsilon_{iht}$

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    try:
        temp, _ = build_df(hashtag, tweet_dict, normalize_time=True)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
    except Exception as e:
        print(hashtag, 'did not work')
        
panel_df = pd.concat(dfs)
panel_df
# Out:
# bogibeelbridge did not work
# hooghly_chalo did not work
# goodgovernanceday did not work
# congressframedamitshah did not work
# mainbhichowkidar did not work
# congressagainstnationalsecurity did not work
# bjpvijaysankalpbikerally did not work
# bjpkamaljyoti did not work
# modiagain2019 did not work
# armedforcesflagday did not work
# nris4modi did not work

# %%
query.hashtag = pd.Categorical(query.hashtag).codes

# %%
pd.get_dummies(query,'hashtag')
# Out:
#           template  template_retweet  regular  regular_retweet  \
# adj_date
# -55            4.0               NaN      1.0              0.0
# -50            1.0               NaN      0.0              0.0
# -45            0.0               NaN      0.0              0.0
# -40            0.0               NaN      0.0              0.0
# -35            0.0               NaN      1.0              0.0
# ...            ...               ...      ...              ...
#  75            0.0               0.0      8.0             18.0
#  80            0.0               0.0     13.0             13.0
#  85            0.0               0.0      7.0              9.0
#  90            0.0               0.0     11.0             12.0
#  95            0.0               0.0      3.0             20.0
#
#           zero_exposure_regular  nonzero_exposure_regular  total_engagement  \
# adj_date
# -55                         0.0                       1.0               5.0
# -50                         0.0                       0.0               1.0
# -45                         0.0                       0.0               0.0
# -40                         0.0                       0.0               0.0
# -35                         0.0                       1.0               1.0
# ...                         ...                       ...               ...
#  75                         8.0                       0.0              26.0
#  80                        13.0                       0.0              26.0
#  85                         6.0                       1.0              16.0
#  90                        11.0                       0.0              23.0
#  95                         1.0                       2.0              23.0
#
#           rt_engagement  time  time_i  ...  hashtag_threadsofexcellence  \
# adj_date                               ...
# -55                 0.0   -55      48  ...                            0
# -50                 0.0   -50      49  ...                            0
# -45                 0.0   -45      50  ...                            0
# -40                 0.0   -40      51  ...                            0
# -35                 0.0   -35      52  ...                            0
# ...                 ...   ...     ...  ...                          ...
#  75                18.0    75      74  ...                            0
#  80                13.0    80      75  ...                            0
#  85                 9.0    85      76  ...                            0
#  90                12.0    90      77  ...                            0
#  95                20.0    95      78  ...                            0
#
#           hashtag_timesofrahul  hashtag_urban_नक्सली_केजरीवाल  \
# adj_date
# -55                          0                              0
# -50                          0                              0
# -45                          0                              0
# -40                          0                              0
# -35                          0                              0
# ...                        ...                            ...
#  75                          0                              0
#  80                          0                              0
#  85                          0                              0
#  90                          0                              0
#  95                          0                              0
#
#           hashtag_yuvakemannkibaat  hashtag_zamanatke1000din  \
# adj_date
# -55                              0                         0
# -50                              0                         0
# -45                              0                         0
# -40                              0                         0
# -35                              0                         0
# ...                            ...                       ...
#  75                              0                         0
#  80                              0                         0
#  85                              0                         0
#  90                              0                         0
#  95                              0                         0
#
#           hashtag_आदर्शघोटाला_संघर्ष_यात्रा  hashtag_उत्तरप्रदेश_विजय_संकल्प  \
# adj_date
# -55                                       0                                0
# -50                                       0                                0
# -45                                       0                                0
# -40                                       0                                0
# -35                                       0                                0
# ...                                     ...                              ...
#  75                                       0                                0
#  80                                       0                                0
#  85                                       0                                0
#  90                                       0                                0
#  95                                       0                                0
#
#           hashtag_भारत_माता_की_जय  hashtag_म्हारा_वोट_भाजपा_को  \
# adj_date
# -55                             0                            0
# -50                             0                            0
# -45                             0                            0
# -40                             0                            0
# -35                             0                            0
# ...                           ...                          ...
#  75                             0                            0
#  80                             0                            0
#  85                             0                            0
#  90                             0                            0
#  95                             0                            0
#
#           hashtag_लक्ष्य_हमारा_मोदी_दोबारा
# adj_date
# -55                                      0
# -50                                      0
# -45                                      0
# -40                                      0
# -35                                      0
# ...                                    ...
#  75                                      0
#  80                                      0
#  85                                      0
#  90                                      0
#  95                                      0
#
# [1859 rows x 76 columns]

# %%
64*30
# Out:
# 1920

# %%
len(panel_df.hashtag.unique())
# Out:
# 64

# %%
panel_df.query('time > -60 & time < 100').fillna(0)
# Out:
#           template  template_retweet  regular  regular_retweet  \
# adj_date
# -55            4.0               0.0      1.0              0.0
# -50            1.0               0.0      0.0              0.0
# -45            0.0               0.0      0.0              0.0
# -40            0.0               0.0      0.0              0.0
# -35            0.0               0.0      1.0              0.0
# ...            ...               ...      ...              ...
#  75            0.0               0.0      8.0             18.0
#  80            0.0               0.0     13.0             13.0
#  85            0.0               0.0      7.0              9.0
#  90            0.0               0.0     11.0             12.0
#  95            0.0               0.0      3.0             20.0
#
#           zero_exposure_regular  nonzero_exposure_regular  total_engagement  \
# adj_date
# -55                         0.0                       1.0               5.0
# -50                         0.0                       0.0               1.0
# -45                         0.0                       0.0               0.0
# -40                         0.0                       0.0               0.0
# -35                         0.0                       1.0               1.0
# ...                         ...                       ...               ...
#  75                         8.0                       0.0              26.0
#  80                        13.0                       0.0              26.0
#  85                         6.0                       1.0              16.0
#  90                        11.0                       0.0              23.0
#  95                         1.0                       2.0              23.0
#
#           rt_engagement  time  time_i  time_i2  threshold            hashtag
# adj_date
# -55                 0.0   -55      48     2304          0  jharkhandwithmodi
# -50                 0.0   -50      49     2401          0  jharkhandwithmodi
# -45                 0.0   -45      50     2500          0  jharkhandwithmodi
# -40                 0.0   -40      51     2601          0  jharkhandwithmodi
# -35                 0.0   -35      52     2704          0  jharkhandwithmodi
# ...                 ...   ...     ...      ...        ...                ...
#  75                18.0    75      74     5476          1         gappupappu
#  80                13.0    80      75     5625          1         gappupappu
#  85                 9.0    85      76     5776          1         gappupappu
#  90                12.0    90      77     5929          1         gappupappu
#  95                20.0    95      78     6084          1         gappupappu
#
# [1859 rows x 13 columns]

# %%
query = panel_df.query('time > -60 & time < 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + C(hashtag) + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
# Out:
#                             coef  std err      z  P>|z|  [0.025  0.975]
# Intercept                 0.4053    1.909  0.212  0.832  -3.336   4.147
# time                      0.1209    0.039  3.062  0.002   0.044   0.198
# threshold                 4.0796    1.840  2.217  0.027   0.473   7.686
# time:threshold           -0.1522    0.064 -2.384  0.017  -0.277  -0.027
# nonzero_exposure_regular  2.5394    0.444  5.713  0.000   1.668   3.410

# %%
panel_df
# Out:
#           template  template_retweet  regular  regular_retweet  \
# adj_date
# -295           NaN               NaN      0.0              0.0
# -290           NaN               NaN      0.0              0.0
# -285           NaN               NaN      0.0              0.0
# -280           NaN               NaN      0.0              0.0
# -275           NaN               NaN      0.0              0.0
# ...            ...               ...      ...              ...
#  945           NaN               0.0      1.0              6.0
#  950           NaN               0.0      4.0              3.0
#  955           NaN               0.0      1.0              2.0
#  960           NaN               0.0      3.0              1.0
#  965           NaN               0.0      3.0              1.0
#
#           zero_exposure_regular  nonzero_exposure_regular  total_engagement  \
# adj_date
# -295                        NaN                       0.0               0.0
# -290                        NaN                       0.0               0.0
# -285                        NaN                       0.0               0.0
# -280                        NaN                       0.0               0.0
# -275                        NaN                       0.0               0.0
# ...                         ...                       ...               ...
#  945                        1.0                       0.0               7.0
#  950                        3.0                       1.0               7.0
#  955                        1.0                       0.0               3.0
#  960                        3.0                       0.0               4.0
#  965                        3.0                       0.0               4.0
#
#           rt_engagement  time  time_i  time_i2  threshold            hashtag
# adj_date
# -295                0.0  -295       0        0          0  jharkhandwithmodi
# -290                0.0  -290       1        1          0  jharkhandwithmodi
# -285                0.0  -285       2        4          0  jharkhandwithmodi
# -280                0.0  -280       3        9          0  jharkhandwithmodi
# -275                0.0  -275       4       16          0  jharkhandwithmodi
# ...                 ...   ...     ...      ...        ...                ...
#  945                6.0   945     248    61504          1         gappupappu
#  950                3.0   950     249    62001          1         gappupappu
#  955                2.0   955     250    62500          1         gappupappu
#  960                1.0   960     251    63001          1         gappupappu
#  965                1.0   965     252    63504          1         gappupappu
#
# [59074 rows x 13 columns]

# %%
query = panel_df.query('time > -60 & time < 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + C(hashtag) + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
mod.summary()

# %%
query = panel_df.query('time > -60 & time < 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + C(hashtag) + nonzero_exposure_regular", data=query).fit(
    cov_type='HAC',cov_kwds={'maxlags':1})
mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                regular   R-squared:                       0.717
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     22.27
# Date:                Mon, 11 Jan 2021   Prob (F-statistic):          7.88e-169
# Time:                        15:15:55   Log-Likelihood:                -5188.5
# No. Observations:                1347   AIC:                         1.051e+04
# Df Residuals:                    1279   BIC:                         1.087e+04
# Df Model:                          67
# Covariance Type:                  HAC
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.4053      1.445      0.280      0.779      -2.427       3.238
# C(hashtag)[T.1]             11.3350      2.582      4.391      0.000       6.275      16.395
# C(hashtag)[T.2]              2.0640      1.346      1.533      0.125      -0.575       4.703
# C(hashtag)[T.3]              1.5154      1.639      0.924      0.355      -1.698       4.729
# C(hashtag)[T.4]             28.6981      4.504      6.371      0.000      19.870      37.526
# C(hashtag)[T.5]              7.2965      1.819      4.011      0.000       3.731      10.862
# C(hashtag)[T.6]              0.0948      1.481      0.064      0.949      -2.808       2.998
# C(hashtag)[T.7]              1.9834      1.603      1.237      0.216      -1.159       5.126
# C(hashtag)[T.8]              5.6624      1.629      3.476      0.001       2.469       8.855
# C(hashtag)[T.9]             -1.1223      1.831     -0.613      0.540      -4.711       2.466
# C(hashtag)[T.10]            -0.6327      1.822     -0.347      0.728      -4.204       2.938
# C(hashtag)[T.11]            -3.4677      1.281     -2.706      0.007      -5.979      -0.956
# C(hashtag)[T.12]            -1.1939      1.464     -0.816      0.415      -4.063       1.675
# C(hashtag)[T.13]             6.9267      1.968      3.520      0.000       3.069      10.784
# C(hashtag)[T.14]            -3.1721      4.231     -0.750      0.453     -11.464       5.120
# C(hashtag)[T.15]             0.1178      1.569      0.075      0.940      -2.957       3.192
# C(hashtag)[T.16]             4.4699      2.073      2.156      0.031       0.406       8.534
# C(hashtag)[T.17]             3.4553      1.681      2.055      0.040       0.160       6.750
# C(hashtag)[T.18]             7.4026      1.620      4.570      0.000       4.228      10.577
# C(hashtag)[T.19]             0.1612      1.705      0.095      0.925      -3.181       3.504
# C(hashtag)[T.20]            19.2375      6.740      2.854      0.004       6.028      32.447
# C(hashtag)[T.21]             4.3747      2.096      2.088      0.037       0.268       8.482
# C(hashtag)[T.22]            17.3390      3.314      5.231      0.000      10.843      23.835
# C(hashtag)[T.23]             1.4382      1.670      0.861      0.389      -1.835       4.711
# C(hashtag)[T.24]             2.4255      1.481      1.638      0.101      -0.477       5.328
# C(hashtag)[T.25]             5.6599      2.767      2.046      0.041       0.237      11.083
# C(hashtag)[T.26]            13.7801      3.660      3.765      0.000       6.606      20.954
# C(hashtag)[T.27]             0.5726      1.353      0.423      0.672      -2.079       3.224
# C(hashtag)[T.28]            22.0277      4.550      4.841      0.000      13.110      30.946
# C(hashtag)[T.29]            -0.0420      1.485     -0.028      0.977      -2.952       2.869
# C(hashtag)[T.30]             0.0601      2.783      0.022      0.983      -5.394       5.514
# C(hashtag)[T.31]            -0.2873      2.351     -0.122      0.903      -4.895       4.321
# C(hashtag)[T.32]            22.9246      4.321      5.306      0.000      14.456      31.393
# C(hashtag)[T.33]             0.7721      1.591      0.485      0.627      -2.345       3.889
# C(hashtag)[T.34]            11.1602      3.156      3.537      0.000       4.976      17.345
# C(hashtag)[T.35]            15.5305      4.823      3.220      0.001       6.077      24.984
# C(hashtag)[T.36]            24.5537      7.417      3.310      0.001      10.017      39.091
# C(hashtag)[T.37]            -0.5847      1.680     -0.348      0.728      -3.877       2.707
# C(hashtag)[T.38]            18.8607      3.501      5.388      0.000      11.999      25.722
# C(hashtag)[T.39]             8.3507      2.558      3.265      0.001       3.337      13.364
# C(hashtag)[T.40]             3.0527      1.698      1.798      0.072      -0.275       6.381
# C(hashtag)[T.41]            -5.4915      1.757     -3.126      0.002      -8.934      -2.049
# C(hashtag)[T.42]            -0.8036      1.504     -0.534      0.593      -3.752       2.145
# C(hashtag)[T.43]             1.6052      2.095      0.766      0.444      -2.501       5.711
# C(hashtag)[T.44]             4.3181      2.325      1.857      0.063      -0.239       8.875
# C(hashtag)[T.45]             4.8253      2.587      1.865      0.062      -0.245       9.896
# C(hashtag)[T.46]            -1.9531      1.380     -1.416      0.157      -4.657       0.751
# C(hashtag)[T.47]             4.3741      2.527      1.731      0.084      -0.580       9.328
# C(hashtag)[T.48]             6.0777      1.709      3.557      0.000       2.729       9.426
# C(hashtag)[T.49]             0.3918      1.546      0.253      0.800      -2.638       3.422
# C(hashtag)[T.50]             1.8217      2.848      0.640      0.522      -3.759       7.403
# C(hashtag)[T.51]             1.3718      1.761      0.779      0.436      -2.080       4.823
# C(hashtag)[T.52]             2.8906      1.399      2.067      0.039       0.149       5.632
# C(hashtag)[T.53]             0.4592      1.655      0.277      0.781      -2.785       3.704
# C(hashtag)[T.54]            -1.6805      1.558     -1.078      0.281      -4.735       1.374
# C(hashtag)[T.55]             3.1215      1.379      2.264      0.024       0.419       5.824
# C(hashtag)[T.56]            10.2261      1.921      5.322      0.000       6.460      13.992
# C(hashtag)[T.57]             2.0171      1.843      1.095      0.274      -1.595       5.629
# C(hashtag)[T.58]             8.0573      2.133      3.778      0.000       3.877      12.238
# C(hashtag)[T.59]            -2.8610      1.461     -1.958      0.050      -5.725       0.003
# C(hashtag)[T.60]            19.0396      3.631      5.243      0.000      11.922      26.157
# C(hashtag)[T.61]             9.7107      3.617      2.685      0.007       2.622      16.800
# C(hashtag)[T.62]            16.2154      5.860      2.767      0.006       4.729      27.702
# C(hashtag)[T.63]            53.1200     14.058      3.779      0.000      25.566      80.674
# time                         0.1209      0.031      3.918      0.000       0.060       0.181
# threshold                    4.0796      1.461      2.792      0.005       1.216       6.943
# time:threshold              -0.1522      0.045     -3.373      0.001      -0.241      -0.064
# nonzero_exposure_regular     2.5394      0.196     12.960      0.000       2.155       2.923
# ==============================================================================
# Omnibus:                      320.831   Durbin-Watson:                   0.817
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4290.905
# Skew:                           0.715   Prob(JB):                         0.00
# Kurtosis:                      11.626   Cond. No.                     2.37e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# [2] The condition number is large, 2.37e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
len(exposures.keys())
# Out:
# 68

# %%
x.columns
# Out:
# Index(['template', 'template_retweet', 'regular', 'regular_retweet',
#        'zero_exposure_regular', 'nonzero_exposure_regular', 'time', 'time_i',
#        'time_i2', 'total_engagement', 'rt_engagement'],
#       dtype='object')

# %%
def plot_all_event_study(quantiles=(.1,.99), time_bin='5Min'):
    # plot everything
    fig, axs = plt.subplots(2, 1, figsize=(14,9))
    for hashtag, tweet_dict in campaigns.items():
        try:
            temp, _ = build_df(hashtag, tweet_dict, normalize_time=True)
            axs[0].plot(temp.index, temp.zero_exposure_regular,
                    alpha=.4)
            axs[1].plot(temp.index, temp.total_engagement, alpha=.4)

        except Exception as e:
            print(hashtag, 'did not work')
            print(e)

    axs[1].set_xlabel('Minutes Since Trending', fontsize=18)
    axs[0].set_ylabel('Tweet volume', fontsize=16)
    axs[1].set_ylabel('Tweet volume', fontsize=16)
    axs[0].set_xlim(-100, 200)
    axs[1].set_xlim(-100, 200)
    axs[0].set_title('Zero Exposure Tweets')
    axs[1].set_title('Total Engagement')
    axs[0].grid()
    axs[1].grid()

# %%
plot_all_event_study()
# Out:
# bogibeelbridge did not work
# 'bogibeelbridge'
# hooghly_chalo did not work
# 'datetime' is not in list
# goodgovernanceday did not work
# 'goodgovernanceday'
# congressframedamitshah did not work
# 'datetime' is not in list
# mainbhichowkidar did not work
# 'mainbhichowkidar'
# congressagainstnationalsecurity did not work
# 'datetime' is not in list
# bjpvijaysankalpbikerally did not work
# 'bjpvijaysankalpbikerally'
# bjpkamaljyoti did not work
# 'bjpkamaljyoti'
# modiagain2019 did not work
# 'modiagain2019'
# armedforcesflagday did not work
# 'armedforcesflagday'
# nris4modi did not work
# 'datetime' is not in list

# %%
import sys
# !conda install --yes --prefix {sys.prefix} -c conda-forge jinja2
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /home/jschless/.conda/envs/gt:
#
# The following NEW packages will be INSTALLED:
#
#     jinja2:     2.11.2-pyh9f0ad1d_0  conda-forge
#     markupsafe: 1.1.1-py38h497a2fe_3 conda-forge
#
# markupsafe-1.1 100% |################################| Time: 0:00:00 139.12 kB/s
# jinja2-2.11.2- 100% |################################| Time: 0:00:00  19.24 MB/s
