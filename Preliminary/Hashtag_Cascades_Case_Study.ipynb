# %% [markdown]
# So, we have a list of tweets using a particular hashtag. We need to use time and follower relationships

# %%
import preprocessing, os, gzip
from config import FOLLOWER_DATA_DIR
import graph_tool.all as gt
from tqdm import tqdm
from statsmodels.distributions.empirical_distribution import ECDF
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates

# %%
campaigns = preprocessing.load_campaign()

# %%
hashtag = 'jharkhandwithmodi'
tweets = campaigns[hashtag]

# %%
len(tweets)
# Out:
# 13908

# %% [markdown]
# Steps
# 1. Sort tweets
# 2. Go through tweets in reverse order and pick the most recent tweet as the cause if it they are connected

# %% [markdown]
# #### Preload following relationships

# %%
followers_dict = {}
for tweet in tqdm(tweets.values()):
    user = tweet['username']
    file_name = os.path.join(FOLLOWER_DATA_DIR, user + '.gz')
    if os.path.isfile(file_name):
        f = gzip.open(file_name, 'rb')
        followers = [x.split('\t')[1] for x in f.read().decode().strip().split('\n')]
        followers_dict[user] = set(followers)
    else:
        followers_dict[user] = None
# Out:
# 100%|██████████| 13908/13908 [06:53<00:00, 33.64it/s]

# %%
edge_list = []
sorted_tweets = sorted(tweets.values(), key=lambda x: x['date'])[::-1]
for i in tqdm(range(len(sorted_tweets))):
    child = sorted_tweets[i]
    for j in range(i, len(sorted_tweets)):
        #print(sorted_tweets[j]['id'])
        if sorted_tweets[j]['username'] in followers_dict[child['username']]:
            edge_list.append((sorted_tweets[j]['id'], sorted_tweets[i]['id']))
            break
# Out:
#   0%|          | 0/13908 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-1d97c7640946> in <module>
#       5     for j in range(i, len(sorted_tweets)):
#       6         #print(sorted_tweets[j]['id'])
# ----> 7         if sorted_tweets[j]['username'] in followers_dict[child['username']]:
#       8             edge_list.append((sorted_tweets[j]['id'], sorted_tweets[i]['id']))
#       9             break
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
len(edge_list)

# %% [markdown]
# ## Constructing Cascade

# %%
child_to_parent = {j:i for i,j in edge_list}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3eda388ce3d5> in <module>
# ----> 1 child_to_parent = {j:i for i,j in edge_list}
#
# NameError: name 'edge_list' is not defined

# %%
g = gt.Graph()
#vprop_tweet = g.add_vertex_property('object')
tweet_id_to_vertex = {}
for t in sorted_tweets:
    v = g.add_vertex()
    tweet_id_to_vertex[t['id']] = v
translated_edge_list = [(tweet_id_to_vertex[i], tweet_id_to_vertex[j]) for i,j in edge_list]
g.add_edge_list(translated_edge_list)

# %%
g

# %%
gt.label_components(g, directed=False)[0].a

# %% [markdown]
# ## What do I want to learn?
# 1. Create the same histogram for number of descendents.
# 2. Look at the number of exposures before participating (template and otherwise).

# %% [markdown]
# ## Looking into amount of exposure before participation

# %%
results = {} #username -> (# template, # non-template)
sorted_tweets = sorted(tweets.values(), key=lambda x: x['date'])[::-1]
for i in tqdm(range(len(sorted_tweets))):
    child = sorted_tweets[i]
    n_temp, n_norm = 0, 0
    for j in range(i, len(sorted_tweets)):
        #print(sorted_tweets[j]['id'])
        followers = followers_dict[child['username']]
        if followers is None:
            followers = set()
        if sorted_tweets[j]['username'] in followers:
            if sorted_tweets[j]['template'] != '':
                n_temp += 1
            else:
                n_norm += 1
    results[child['username']] = (n_temp, n_norm)
# Out:
# 100%|██████████| 13908/13908 [00:27<00:00, 509.40it/s]

# %%
results

# %%
temps, norms = zip(*list(results.values()))

# %%
import matplotlib.pyplot as plt, seaborn as sns

# %%
len([x for x,y in followers_dict.items() if y is not None])

# %%
len(sorted_tweets)

# %%
len(followers_dict.items())

# %% [markdown]
# ## Results removing people without follower data

# %%
len([x for x in tweets.values() if followers_dict[x['username']] is not None])

# %%
len(tweets.values())

# %%
x = set()
x.add(2)
x.add(4)
x
# Out:
# {2, 4}

# %%
results = {} #username -> (# template, # non-template)
sorted_tweets = sorted(tweets.values(), key=lambda x: x['date'])[::-1]
#sorted_tweets = [x for x in sorted_tweets if followers_dict[x['username']] is not None]
for i in tqdm(range(len(sorted_tweets))):
    child = sorted_tweets[i]
    n_temp, n_norm = 0, 0
    temp_exposers = set()

    for j in range(i, len(sorted_tweets)):
        #print(sorted_tweets[j]['id'])
        followers = followers_dict[sorted_tweets[j]['username']]
        if followers is None:
            followers = set()
        if child['username'] in followers:
            if sorted_tweets[j]['template'] != '':
                n_temp += 1
                temp_exposers.add(sorted_tweets[j]['username'])
            else:
                n_norm += 1
    results[child['username']] = (n_temp, n_norm, child['date'], child['username'], temp_exposers)
# Out:
# 100%|██████████| 13908/13908 [00:30<00:00, 462.50it/s]

# %%
temps, norms, dates, users, exposer_sets = zip(*list(results.values()))

# %% [markdown]
# ## Where do Vertical Lines Come From

# %%
from collections import defaultdict

# %%
temp_counts = defaultdict(list)
for temp_count, user in zip(temps, exposer_sets):
    temp_counts[temp_count].append(user)

# %%
sorted_temp_counts = sorted(temp_counts.items(), key=lambda x: -len(x[1]))

# %%
[x for x,y in sorted_temp_counts[:10]]
# Out:
# [0, 146, 4, 1, 54, 7, 5, 151, 158, 6]

# %%
temp_counts[146]
# Out:
# [{'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'},
#  {'bjp4jharkhand'}]

# %%
set.intersection(*temp_counts[54])
# Out:
# {'vandana63956451'}

# %%
set.intersection(*temp_counts[158])
# Out:
# {'bjp4jharkhand'}

# %%
set.intersection(*temp_counts[151])
# Out:
# {'bjp4jharkhand'}

# %%
set.intersection(*temp_counts[146])
# Out:
# {'bjp4jharkhand'}

# %%
# 146 seems to be very common, who is the common denominator
int_set = followers_dict[temp_counts[146][0]]
for x in temp_counts[146][1:]:
    int_set = int_set.intersection(followers_dict[x])
# Out:
# working
# error with user manojpo58166346
# error with user sahdevmahato
# error with user bhaskarbjp1
# working
# error with user mlgaurav
# working
# working
# error with user bhardwajd977
# working
# working
# error with user thesmartbokaro
# working
# working
# error with user hemantbjp3
# working
# working
# error with user priyawartkumar8
# error with user sanjayg79530411
# working
# error with user belalzahid
# error with user vishalskumarpa1
# error with user birendrasingh_2
# error with user abhaymishra09
# error with user dtatawala
# working
# working
# error with user akhileshmbjp
# working
# error with user shubhamrajbjp
# error with user singhsaheb123
# error with user pawan072015
# working
# error with user dasgupta_sujay
# working
# working
# working
# error with user bjp4siliguri
# working
# working
# working
# working
# error with user maassaw
# error with user bishwan49924717
# working
# working
# working
# working
# error with user abishekshukla22
# error with user arvindbrar3
# error with user iampawansingh26
# error with user ompraka13500322
# error with user ajaykr_ranchi
# error with user ritikthesniper
# error with user deepam_banerjee
# working
# error with user gautamsinghbjp
# working
# working
# error with user krpandeykumar
# error with user jharkhand1989
# working
# working
# error with user bjp4goa
# error with user bjp4lakshadweep
# working
# working
# working
# working
# working
# working
# working
# error with user reddypremendar
# working
# working
# working
# error with user bjp4jnk
# error with user bjp4manipur
# error with user bjp4meghalaya
# error with user bjp4mizoram
# working
# error with user gourav_jais
# error with user bjp4puducherry
# working
# error with user sharananu1
# error with user bjp4bengal
# error with user bjp4ann
# working
# error with user anmolmathur_
# error with user kamlesh41934211
# error with user bjp4lohardaga
# error with user bjpodishalive
# error with user pallawabhishek
# working
# error with user gurendranath
# error with user shivaanshkumar
# working
# error with user vivekanandshree
# error with user shishupalvarsh2
# working
# error with user bimalghara5
# working
# error with user ramsaw1
# error with user manishkrsharma_
# error with user yadavamit99
# error with user annudubey11
# working
# error with user munnasingh6
# error with user anamikaminz
# error with user aajadpanday
# working
# error with user nikhilsaw6
# error with user alappuzhanet
# error with user chandan80959735
# error with user capankaj1985
# error with user internetyodha
# error with user tanusrikundu
# working
# error with user nandinisaw
# error with user vidyasa78159430
# working
# working
# error with user prit_mishra
# error with user prajwalpu1
# error with user nikhily55
# working
# working
# error with user gopepushpita
# working
# working
# error with user rishibalas
# error with user rv473devil
# error with user satyaprakashmla
# working
# error with user humshfar
# error with user adab_arpit
# error with user sanjayk18797634
# error with user pratibh07008958
# working
# working
# error with user gafs2018
# error with user sherbah46958042
# working
# working
# error with user punterrrrr1
# error with user shashidelhibjp
# error with user bjp4khadakwasla
# working
# working
# error with user jammulajaganna2
# error with user ambalalmali14
# error with user vinaykumarroy9

# %%
plt.hist(temps, bins=50)
# Out:
# (array([1.546e+03, 9.900e+01, 1.400e+01, 2.960e+02, 5.200e+01, 5.300e+01,
#         9.000e+00, 2.600e+01, 1.300e+01, 1.200e+01, 6.000e+00, 8.000e+00,
#         5.000e+00, 1.000e+00, 1.100e+01, 5.000e+00, 3.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 3.000e+00, 6.000e+00, 3.000e+00, 1.000e+00,
#         2.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 2.000e+00,
#         2.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([   0.,   42.,   84.,  126.,  168.,  210.,  252.,  294.,  336.,
#          378.,  420.,  462.,  504.,  546.,  588.,  630.,  672.,  714.,
#          756.,  798.,  840.,  882.,  924.,  966., 1008., 1050., 1092.,
#         1134., 1176., 1218., 1260., 1302., 1344., 1386., 1428., 1470.,
#         1512., 1554., 1596., 1638., 1680., 1722., 1764., 1806., 1848.,
#         1890., 1932., 1974., 2016., 2058., 2100.]),
#  <BarContainer object of 50 artists>)

# %%
plt.hist(dates, bins=80)
plt.xticks(rotation=90)
plt.title('Tweets by Time')
# Out:
# Text(0.5, 1.0, 'Tweets by Time')

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.ylim([0, 750])
plt.xlim([0, 750])
plt.show()
# plt.xscale('log')
# plt.yscale('log')

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')

plt.ylim([0, 250])
plt.xlim([0, 250])
plt.show()

# %%
plt.scatter(temps, norms)
plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.ylim([0, 50])
plt.xlim([0, 50])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

# %%
plt.hist([temps, norms], stacked=True, log=True, bins=20, label=['template', 'non-template'])
plt.legend()
plt.xlabel('# exposures')
plt.ylabel('count')
plt.title('Total Exposures by Tweet Type')
# Out:
# Text(0.5, 1.0, 'Total Exposures by Tweet Type')

# %% [markdown]
# ## Examining Second Half of Tweets

# %%
begin, end = datetime(2019,9,1), datetime(2019,9, 13) #month of september
filtered_results = [(x,y,z) for x,y,z in zip(temps, norms, dates) if z > begin and z < end]
f_temps, f_norms, f_dates = zip(*filtered_results)

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 500])
plt.ylim([0, 500])

plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
plt.hist([f_temps, f_norms], stacked=True, log=True, bins=20, label=['template', 'non-template'])
plt.legend()
plt.xlabel('# exposures')
plt.ylabel('count')
plt.title('Total Exposures by Tweet Type')
# Out:
# Text(0.5, 1.0, 'Total Exposures by Tweet Type')

# %%
ecdf = ECDF(f_temps)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of template exposure before using hashtag')
plt.xlabel('# of template exposures')
# Out:
# Text(0.5, 0, '# of template exposures')

# %%
ecdf = ECDF(f_norms)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of non-template exposure before using hashtag')
plt.xlabel('# of non-template exposures')
# Out:
# Text(0.5, 0, '# of non-template exposures')

# %%
ecdf = ECDF([x+y for x,y in zip(f_temps,f_norms)])
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of total exposure before using hashtag')
plt.xlabel('# of exposures')
# Out:
# Text(0.5, 0, '# of exposures')

# %% [markdown]
# ## Examining First Half of Tweets

# %%
begin, end = datetime(2019,2,10), datetime(2019,2,20) #month of february
filtered_results = [(x,y,z) for x,y,z in zip(temps, norms, dates) if z > begin and z < end]
f_temps, f_norms, f_dates = zip(*filtered_results)

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 500])
plt.ylim([0, 500])

plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
plt.hist([f_temps, f_norms], stacked=True, log=True, bins=20, label=['template', 'non-template'])
plt.legend()
plt.xlabel('# exposures')
plt.ylabel('count')
plt.title('Total Exposures by Tweet Type')
# Out:
# Text(0.5, 1.0, 'Total Exposures by Tweet Type')

# %%
ecdf = ECDF(f_temps)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of template exposure before using hashtag')
plt.xlabel('# of template exposures')
# Out:
# Text(0.5, 0, '# of template exposures')

# %%
ecdf = ECDF(f_norms)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of non-template exposure before using hashtag')
plt.xlabel('# of non-template exposures')
# Out:
# Text(0.5, 0, '# of non-template exposures')

# %%
ecdf = ECDF([x+y for x,y in zip(f_temps,f_norms)])
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of total exposure before using hashtag')
plt.xlabel('# of exposures')
# Out:
# Text(0.5, 0, '# of exposures')

# %% [markdown]
# # Only looking at non-template tweets

# %%
results = {} #username -> (# template, # non-template)
sorted_tweets = sorted(tweets.values(), key=lambda x: x['date'])[::-1]
#sorted_tweets = [x for x in sorted_tweets if followers_dict[x['username']] is not None]
for i in tqdm(range(len(sorted_tweets))):
    child = sorted_tweets[i]
    n_temp, n_norm = 0, 0
    for j in range(i, len(sorted_tweets)):
        #print(sorted_tweets[j]['id'])
        followers = followers_dict[sorted_tweets[j]['username']]
        if followers is None:
            followers = set()
        if child['username'] in followers:
            if sorted_tweets[j]['template'] != '':
                n_temp += 1
            else:
                n_norm += 1
    if child['template'] == '':
        results[child['username']] = (n_temp, n_norm, child['date'])
# Out:
# 100%|██████████| 13908/13908 [00:33<00:00, 421.09it/s]

# %%
temps, norms, dates = zip(*list(results.values()))

# %%
plt.hist(dates, bins=80)
plt.xticks(rotation=90)
plt.title('Tweets by Time')
# Out:
# Text(0.5, 1.0, 'Tweets by Time')

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.ylim([0, 750])
plt.xlim([0, 750])
plt.show()
# plt.xscale('log')
# plt.yscale('log')

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')

plt.ylim([0, 250])
plt.xlim([0, 250])
plt.show()

# %%
plt.scatter(temps, norms)
plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.ylim([0, 50])
plt.xlim([0, 50])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

# %%
plt.hist([temps, norms], stacked=True, log=True, bins=20, label=['template', 'non-template'])
plt.legend()
plt.xlabel('# exposures')
plt.ylabel('count')
plt.title('Total Exposures by Tweet Type')
# Out:
# Text(0.5, 1.0, 'Total Exposures by Tweet Type')

# %% [markdown]
# ## Examining Second Half of Tweets

# %%
begin, end = datetime(2019,9,1), datetime(2019,9, 13) #month of september
filtered_results = [(x,y,z) for x,y,z in zip(temps, norms, dates) if z > begin and z < end]
f_temps, f_norms, f_dates = zip(*filtered_results)

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 500])
plt.ylim([0, 500])

plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
plt.hist([f_temps, f_norms], stacked=True, log=True, bins=20, label=['template', 'non-template'])
plt.legend()
plt.xlabel('# exposures')
plt.ylabel('count')
plt.title('Total Exposures by Tweet Type')
# Out:
# Text(0.5, 1.0, 'Total Exposures by Tweet Type')

# %%
ecdf = ECDF(f_temps)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of template exposure before using hashtag')
plt.xlabel('# of template exposures')
# Out:
# Text(0.5, 0, '# of template exposures')

# %%
ecdf = ECDF(f_norms)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of non-template exposure before using hashtag')
plt.xlabel('# of non-template exposures')
# Out:
# Text(0.5, 0, '# of non-template exposures')

# %%
ecdf = ECDF([x+y for x,y in zip(f_temps,f_norms)])
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of total exposure before using hashtag')
plt.xlabel('# of exposures')
# Out:
# Text(0.5, 0, '# of exposures')

# %% [markdown]
# ## Examining First Half of Tweets

# %%
begin, end = datetime(2019,2,10), datetime(2019,2,20) #month of february
filtered_results = [(x,y,z) for x,y,z in zip(temps, norms, dates) if z > begin and z < end]
f_temps, f_norms, f_dates = zip(*filtered_results)

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 500])
plt.ylim([0, 500])

plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
plt.hist([f_temps, f_norms], stacked=True, log=True, bins=20, label=['template', 'non-template'])
plt.legend()
plt.xlabel('# exposures')
plt.ylabel('count')
plt.title('Total Exposures by Tweet Type')
# Out:
# Text(0.5, 1.0, 'Total Exposures by Tweet Type')

# %%
ecdf = ECDF(f_temps)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of template exposure before using hashtag')
plt.xlabel('# of template exposures')
# Out:
# Text(0.5, 0, '# of template exposures')

# %%
ecdf = ECDF(f_norms)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of non-template exposure before using hashtag')
plt.xlabel('# of non-template exposures')
# Out:
# Text(0.5, 0, '# of non-template exposures')

# %%
ecdf = ECDF([x+y for x,y in zip(f_temps,f_norms)])
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of total exposure before using hashtag')
plt.xlabel('# of exposures')
# Out:
# Text(0.5, 0, '# of exposures')

# %% [markdown]
# # Distribution of Template Tweets

# %%
results = {} #username -> (# template, # non-template)
sorted_tweets = sorted(tweets.values(), key=lambda x: x['date'])[::-1]
#sorted_tweets = [x for x in sorted_tweets if followers_dict[x['username']] is not None]
for i in tqdm(range(len(sorted_tweets))):
    child = sorted_tweets[i]
    n_temp, n_norm = 0, 0
    for j in range(i, len(sorted_tweets)):
        #print(sorted_tweets[j]['id'])
        followers = followers_dict[sorted_tweets[j]['username']]
        if followers is None:
            followers = set()
        if child['username'] in followers:
            if sorted_tweets[j]['template'] != '':
                n_temp += 1
            else:
                n_norm += 1
    if child['template'] != '':
        results[child['username']] = (n_temp, n_norm, child['date'])
# Out:
# 100%|██████████| 13908/13908 [00:33<00:00, 416.32it/s]

# %%
temps, norms, dates = zip(*list(results.values()))

# %%
plt.hist(dates, bins=80)
plt.xticks(rotation=90)
plt.title('Tweets by Time')
# Out:
# Text(0.5, 1.0, 'Tweets by Time')

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.ylim([0, 750])
plt.xlim([0, 750])
plt.show()
# plt.xscale('log')
# plt.yscale('log')

# %%
t = [mdates.date2num(d) for d in dates]

fig, ax = plt.subplots()
sc = ax.scatter(temps, norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')

plt.ylim([0, 250])
plt.xlim([0, 250])
plt.show()

# %%
plt.scatter(temps, norms)
plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.ylim([0, 50])
plt.xlim([0, 50])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

# %%
plt.hist([temps, norms], stacked=True, log=True, bins=20, label=['template', 'non-template'])
plt.legend()
plt.xlabel('# exposures')
plt.ylabel('count')
plt.title('Total Exposures by Tweet Type')
# Out:
# Text(0.5, 1.0, 'Total Exposures by Tweet Type')

# %% [markdown]
# ## Examining Second Half of Tweets
# There were none

# %% [markdown]
# ## Examining First Half of Tweets

# %%
begin, end = datetime(2019,2,10), datetime(2019,2,20) #month of february
filtered_results = [(x,y,z) for x,y,z in zip(temps, norms, dates) if z > begin and z < end]
f_temps, f_norms, f_dates = zip(*filtered_results)

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
t = [mdates.date2num(d) for d in f_dates]

fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=t)

loc = mdates.AutoDateLocator()
fig.colorbar(sc, ticks=loc,
                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 500])
plt.ylim([0, 500])

plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')

plt.show()

# %%
plt.hist([f_temps, f_norms], stacked=True, log=True, bins=20, label=['template', 'non-template'])
plt.legend()
plt.xlabel('# exposures')
plt.ylabel('count')
plt.title('Total Exposures by Tweet Type')
# Out:
# Text(0.5, 1.0, 'Total Exposures by Tweet Type')

# %%
ecdf = ECDF(f_temps)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of template exposure before using hashtag')
plt.xlabel('# of template exposures')
# Out:
# Text(0.5, 0, '# of template exposures')

# %%
ecdf = ECDF(f_norms)
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of non-template exposure before using hashtag')
plt.xlabel('# of non-template exposures')
# Out:
# Text(0.5, 0, '# of non-template exposures')

# %%
ecdf = ECDF([x+y for x,y in zip(f_temps,f_norms)])
plt.plot(ecdf.x, ecdf.y)
plt.xscale('log')
plt.title('Empirical cdf of total exposure before using hashtag')
plt.xlabel('# of exposures')
# Out:
# Text(0.5, 0, '# of exposures')

# %% [markdown]
# ## Who are the second wave non-template tweeters?

# %%
sorted_tweets = sorted(tweets.values(), key=lambda x: x['date'])[::-1]
begin, end = datetime(2019,9,1), datetime(2019,9, 13) #month of september]
filtered_tweets = [t for t in tweets.values() if t['date'] >= begin and t['date'] <= end]

# %%
user_df = preprocessing.load_user_data()
user_df.head()
# Out:
#              templates  template_retweets  tweets  retweets  campaigns  \
# 4bhi9                0                  0       4        27          0
# advrayadav           0                  0       0        14          0
# deepsethi01         13                 40      23       195          4
# desh_bhkt            0                  0      24        33          0
# devendrapai          0                  0      12         7          0
#
#                              id                        location  \
# 4bhi9                       NaN                             NaN
# advrayadav             68160779   uttar pradesh & delhi , india
# deepsethi01  773812588228534272                  kota,rajasthan
# desh_bhkt            1465206535  dabru dabru dabru.hahahaha.com
# devendrapai            53862134                    amchi mumbai
#
#                                                    description followers  \
# 4bhi9                                                      NaN       NaN
# advrayadav   advocate supreme court of india, national pres...     11560
# deepsethi01  loksabha vice coordinator bjp .blessed to be f...      1680
# desh_bhkt    make fun of life before it starts making fun o...     23672
# devendrapai  course director at rmp's @iidlpgp. swayamsevak...      7398
#
#             friends statuses               type  \
# 4bhi9           NaN      NaN  6_non-participant
# advrayadav    12591    24663  6_non-participant
# deepsethi01     923    72646         2_official
# desh_bhkt       135   116912  6_non-participant
# devendrapai     990    45891  6_non-participant
#
#                                                new_description  \
# 4bhi9                                                     None
# advrayadav                                                None
# deepsethi01  Loksabha Vice Coordinator BJP .\n\nBlessed to ...
# desh_bhkt                                                 None
# devendrapai                                               None
#
#                                                           temp group
# 4bhi9                                          non-participant     0
# advrayadav                                     non-participant     0
# deepsethi01   loksabha vice coordin bjp bless to be follow ...   3-5
# desh_bhkt                                      non-participant     0
# devendrapai                                    non-participant     0

# %%
import numpy as np

# %%
users = np.unique([t['username'] for t in filtered_tweets])
user_types = [user_df.type.get(u, 'Unknown') for u in users]

# %%
import pandas as pd

# %%
counts = pd.Series(user_types).value_counts()
normed = [x/sum(counts) for x in counts]

# %%
# Out:
# ['black', 'g', 'b', 'r', 'orange', 'pink']

# %%
plt.pie(normed, labels=counts.index, colors=[color_map[x] for x in counts.index])
plt.title('User Breakdown of Second Wave Participants')
# Out:
# Text(0.5, 1.0, 'User Breakdown of Second Wave Participants')

# %% [markdown]
# ## Who are the first wave non-template tweeters?

# %%
sorted_tweets = sorted(tweets.values(), key=lambda x: x['date'])[::-1]
begin, end = datetime(2019,2,10), datetime(2019,2,20) #month of february
filtered_tweets = [t for t in tweets.values() if t['date'] >= begin and t['date'] <= end and t['template'] == '']

# %%
users = np.unique([t['username'] for t in filtered_tweets])
user_types = [user_df.type.get(u, 'Unknown') for u in users]

# %%
import pandas as pd

# %%
counts = pd.Series(user_types).value_counts()
normed = [x/sum(counts) for x in counts]

# %%
plt.pie(normed, labels=counts.index, colors=[color_map[x] for x in counts.index])
plt.title('User Breakdown of First Wave Participants')
# Out:
# Text(0.5, 1.0, 'User Breakdown of First Wave Participants')

# %% [markdown]
# ## Plotting Breakdown Colored by User Type

# %%
color_map = {
    '1_itcell': 'b',
    '2_official': 'orange',
    '3_fan': 'g',
    '4_other': 'r',
    '5_deleted': 'm',
    '6_non-participant': 'black',
    'Unknown': 'pink'
}

# %%
results = {} #username -> (# template, # non-template)
sorted_tweets = sorted(tweets.values(), key=lambda x: x['date'])[::-1]
#sorted_tweets = [x for x in sorted_tweets if followers_dict[x['username']] is not None]
for i in tqdm(range(len(sorted_tweets))):
    child = sorted_tweets[i]
    n_temp, n_norm = 0, 0
    for j in range(i, len(sorted_tweets)):
        #print(sorted_tweets[j]['id'])
        followers = followers_dict[sorted_tweets[j]['username']]
        if followers is None:
            followers = set()
        if child['username'] in followers:
            if sorted_tweets[j]['template'] != '':
                n_temp += 1
            else:
                n_norm += 1
    results[child['username']] = (n_temp, n_norm, child['date'], child['username'])
# Out:
# 100%|██████████| 13908/13908 [00:33<00:00, 419.77it/s]

# %%
temps, norms, dates, usernames = zip(*list(results.values()))

# %%
begin, end = datetime(2019,9,1), datetime(2019,9, 13) #month of september
filtered_results = [(x,y,z, a) for x,y,z,a in zip(temps, norms, dates, usernames) if z > begin and z < end]
f_temps, f_norms, f_dates, f_usernames = zip(*filtered_results)

# %%
#t = [mdates.date2num(d) for d in f_dates]
cs = [color_map[user_df.type.get(u, 'Unknown')] for u in f_usernames] 
fig, ax = plt.subplots()
sc = ax.scatter(f_temps, f_norms, c=cs)

#loc = mdates.AutoDateLocator()
#fig.colorbar(sc, ticks=loc,
#                 format=mdates.AutoDateFormatter(loc))

plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 4000])
plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
legend_elems = [Line2D([0], [0], marker='o', label=key, markerfacecolor=value, markersize=10) for key,value in color_map.items()]

plt.legend(handles=legend_elems)
plt.show()

# %%
#t = [mdates.date2num(d) for d in f_dates]
cs = [color_map[user_df.type.get(u, 'Unknown')] for u in f_usernames] 
fig, ax = plt.subplots(figsize=(10,10))
sc = ax.scatter(f_temps, f_norms, c=cs)

#loc = mdates.AutoDateLocator()
#fig.colorbar(sc, ticks=loc,
#                 format=mdates.AutoDateFormatter(loc))


plt.title('User exposure before first hashtag use')
plt.xlabel('# of template tweet exposures')
plt.ylabel('# of non-template tweet exposures')
plt.xlim([0, 500])
plt.ylim([0, 500])

plt.plot([0,4000],[0,4000],'-')
# plt.xscale('log')
# plt.yscale('log')
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
legend_elems = [Line2D([0], [0], marker='o', label=key, markerfacecolor=value, markersize=10) for key,value in color_map.items()]

plt.legend(handles=legend_elems)
plt.show()
