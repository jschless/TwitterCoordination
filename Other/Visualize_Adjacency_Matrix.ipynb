# %%
from imports import *
import network_plots

# %%
g = network_plots.load_follower_network()

# %%
import graph_tool.all as gt

# %%
adj = gt.adjacency(g)

# %%
adj
# Out:
# <115597x115597 sparse matrix of type '<class 'numpy.float64'>'
# 	with 24051663 stored elements in Compressed Sparse Row format>

# %%
blocks = gt.minimize_blockmodel_dl(g, verbose=True)

# %%
mtrx_dict = adj.todok()
xy = np.array(list(mtrx_dict.keys()))
vals = np.array(list(mtrx_dict.values()))
        
# create a scatter plot
plt.scatter(xy[:,0], xy[:,1], s=.00001)
