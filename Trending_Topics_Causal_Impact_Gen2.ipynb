# %%
import preprocessing
from config import TRENDS_DIR
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import tqdm
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, date, timedelta
from config import TWITTER_DATA_DIR
import pickle
import seaborn as sns
import statsmodels.formula.api as smf
import graphviz as gr
import warnings
from tqdm.notebook import tqdm
import numpy as np
from trending import build_df, get_trend_behavior
warnings.filterwarnings('ignore')
import trending

# %%
campaigns = preprocessing.load_campaign()

# %%
hashtag = 'jharkhandwithmodi'
tweets = campaigns[hashtag]

# %%
with open(os.path.join(TWITTER_DATA_DIR, 'exposure_results.pkl'), 'rb') as f:
    exposures = pickle.load(f)

# %% [markdown]
# ## Combining All Hashtags and Normalizing Time
#
# $Y_{iht} = \gamma_{h} + \lambda_t + \beta D_{ht} + \epsilon_{iht}$

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='5Min',
                          cutoff_choice='best', include_missing=False)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
        
panel_df = pd.concat(dfs)

# %%
panel_df

# %%
stata_df = panel_df.copy()
stata_df['hashtag'] = pd.Categorical(stata_df.hashtag).codes
stata_df.to_stata(os.path.join(TWITTER_DATA_DIR, 'optimal_panel.dta'))

# %% [markdown]
# ## Plot All with Confidence Intervals

# %%
panel_df
# Out:
#           template  template_retweet  regular  regular_retweet  \
# adj_date
# -290           0.0               0.0      0.0              0.0
# -285           0.0               0.0      0.0              0.0
# -280           0.0               0.0      0.0              0.0
# -275           0.0               0.0      0.0              0.0
# -270           0.0               0.0      0.0              0.0
# ...            ...               ...      ...              ...
#  880           0.0               0.0      1.0              3.0
#  885           0.0               0.0      3.0              1.0
#  890           0.0               0.0      1.0              2.0
#  895           0.0               0.0      2.0              0.0
#  900           0.0               0.0      1.0              0.0
#
#           nonzero_exposure_regular  zero_exposure_regular  total_engagement  \
# adj_date
# -290                           0.0                    0.0               0.0
# -285                           0.0                    0.0               0.0
# -280                           0.0                    0.0               0.0
# -275                           0.0                    0.0               0.0
# -270                           0.0                    0.0               0.0
# ...                            ...                    ...               ...
#  880                           1.0                    0.0               4.0
#  885                           2.0                    1.0               4.0
#  890                           1.0                    0.0               3.0
#  895                           2.0                    0.0               2.0
#  900                           1.0                    0.0               1.0
#
#           rt_engagement            hashtag  time  time_i  time_i2  \
# adj_date
# -290                0.0  jharkhandwithmodi  -290       0        0
# -285                0.0  jharkhandwithmodi  -285       1        1
# -280                0.0  jharkhandwithmodi  -280       2        4
# -275                0.0  jharkhandwithmodi  -275       3        9
# -270                0.0  jharkhandwithmodi  -270       4       16
# ...                 ...                ...   ...     ...      ...
#  880                3.0         gappupappu   880     248    61504
#  885                1.0         gappupappu   885     249    62001
#  890                2.0         gappupappu   890     250    62500
#  895                0.0         gappupappu   895     251    63001
#  900                0.0         gappupappu   900     252    63504
#
#               trending_start  inferred_trending_start  threshold
# adj_date
# -290     2019-02-17 15:30:00                        0          0
# -285     2019-02-17 15:30:00                        0          0
# -280     2019-02-17 15:30:00                        0          0
# -275     2019-02-17 15:30:00                        0          0
# -270     2019-02-17 15:30:00                        0          0
# ...                      ...                      ...        ...
#  880     2018-10-11 23:30:00                        0          1
#  885     2018-10-11 23:30:00                        0          1
#  890     2018-10-11 23:30:00                        0          1
#  895     2018-10-11 23:30:00                        0          1
#  900     2018-10-11 23:30:00                        0          1
#
# [58838 rows x 15 columns]

# %%
stata_check = panel_df.copy()
stata_check = stata_check.query('time >= -60 & time <= 60')
stata_check['new_time'] = stata_check.time + 60
stata_check.hashtag = pd.Categorical(stata_check.hashtag).codes
stata_check = stata_check.dropna()

# %%
stata_check.query('threshold == 1')
# Out:
#           template  template_retweet  regular  regular_retweet  \
# adj_date
# 5             38.0               1.0     15.0              2.0
# 10            46.0               0.0     18.0              3.0
# 15           107.0              21.0     13.0             26.0
# 20           128.0               9.0     16.0              7.0
# 25            90.0              65.0     10.0             25.0
# ...            ...               ...      ...              ...
# 40             0.0               0.0      0.0              5.0
# 45             0.0               0.0      0.0              2.0
# 50             0.0               1.0      0.0              3.0
# 55             0.0               0.0      0.0              2.0
# 60             0.0               0.0      1.0              3.0
#
#           nonzero_exposure_regular  zero_exposure_regular  total_engagement  \
# adj_date
# 5                              3.0                   12.0              56.0
# 10                             8.0                   10.0              67.0
# 15                            13.0                    0.0             167.0
# 20                            14.0                    2.0             160.0
# 25                             9.0                    1.0             190.0
# ...                            ...                    ...               ...
# 40                             0.0                    0.0               5.0
# 45                             0.0                    0.0               2.0
# 50                             0.0                    0.0               4.0
# 55                             0.0                    0.0               2.0
# 60                             1.0                    0.0               4.0
#
#           rt_engagement  hashtag  time  time_i  time_i2      trending_start  \
# adj_date
# 5                   3.0       23     5      59     3481 2019-02-17 15:30:00
# 10                  3.0       23    10      60     3600 2019-02-17 15:30:00
# 15                 47.0       23    15      61     3721 2019-02-17 15:30:00
# 20                 16.0       23    20      62     3844 2019-02-17 15:30:00
# 25                 90.0       23    25      63     3969 2019-02-17 15:30:00
# ...                 ...      ...   ...     ...      ...                 ...
# 40                  5.0       17    40      80     6400 2018-10-11 23:30:00
# 45                  2.0       17    45      81     6561 2018-10-11 23:30:00
# 50                  4.0       17    50      82     6724 2018-10-11 23:30:00
# 55                  2.0       17    55      83     6889 2018-10-11 23:30:00
# 60                  3.0       17    60      84     7056 2018-10-11 23:30:00
#
#           inferred_trending_start  threshold  new_time
# adj_date
# 5                               0          1        65
# 10                              0          1        70
# 15                              0          1        75
# 20                              0          1        80
# 25                              0          1        85
# ...                           ...        ...       ...
# 40                              0          1       100
# 45                              0          1       105
# 50                              0          1       110
# 55                              0          1       115
# 60                              0          1       120
#
# [768 rows x 16 columns]

# %%
stata_check.groupby('time').regular.mean().plot()
stata_check.groupby('new_time').regular.mean().plot()
plt.legend()

# %%
time = list(range(-60,61,1))
dummy = [1 if t > 0 else 0 for t in time]
y = list(np.random.normal(0, 1, len(time)))
transformed_time = [t + 60 for t in time]

df = pd.DataFrame(zip(time, dummy, y, transformed_time),
                 columns=['Time', 'Treatment', 'Outcome', 'Time_plus_60'])

# %%
mod = smf.ols("Outcome ~ Treatment*Time", data=df).fit()
print(pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0].to_markdown())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-114-21ecc16f79c0> in <module>
#       1 mod = smf.ols("Outcome ~ Treatment*Time", data=df).fit()
# ----> 2 print(pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0].to_markdown())
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/pandas/core/frame.py in to_markdown(self, buf, mode, **kwargs)
#    2015         kwargs.setdefault("headers", "keys")
#    2016         kwargs.setdefault("tablefmt", "pipe")
# -> 2017         tabulate = import_optional_dependency("tabulate")
#    2018         result = tabulate.tabulate(self, **kwargs)
#    2019         if buf is None:
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/pandas/compat/_optional.py in import_optional_dependency(name, extra, raise_on_missing, on_version)
#      90     except ImportError:
#      91         if raise_on_missing:
# ---> 92             raise ImportError(msg) from None
#      93         else:
#      94             return None
#
# ImportError: Missing optional dependency 'tabulate'.  Use pip or conda to install tabulate.

# %%
mod = smf.ols("Outcome ~ Treatment*Time_plus_60", data=df).fit()
print(pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0].to_markdown())
# Out:
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.2206      0.252      0.875      0.383      -0.279       0.720
# Treatment                  0.0213      0.729      0.029      0.977      -1.423       1.466
# Time_plus_60              -0.0072      0.007     -0.997      0.321      -0.022       0.007
# Treatment:Time_plus_60     0.0070      0.010      0.671      0.504      -0.014       0.028
# ==========================================================================================

# %%
plt.scatter(stata_check.time, stata_check.regular)

# %%
mod = smf.ols("regular ~ time*threshold + nonzero_exposure_regular", data=stata_check).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_dca325a4_61c1_11eb_b9c0_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dca325a4_61c1_11eb_b9c0_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow0_col0" class="data row0 col0" >0.389100</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow0_col1" class="data row0 col1" >0.232000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow0_col2" class="data row0 col2" >1.675000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow0_col3" class="data row0 col3" >0.094000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow0_col4" class="data row0 col4" >-0.066000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow0_col5" class="data row0 col5" >0.844000</td>
#             </tr>
#             <tr>
#                         <th id="T_dca325a4_61c1_11eb_b9c0_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow1_col0" class="data row1 col0" >-0.000100</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow1_col1" class="data row1 col1" >0.009000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow1_col2" class="data row1 col2" >-0.015000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow1_col3" class="data row1 col3" >0.988000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow1_col4" class="data row1 col4" >-0.018000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow1_col5" class="data row1 col5" >0.018000</td>
#             </tr>
#             <tr>
#                         <th id="T_dca325a4_61c1_11eb_b9c0_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col0" class="data row2 col0" >1.876800</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col1" class="data row2 col1" >0.366000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col2" class="data row2 col2" >5.126000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col4" class="data row2 col4" >1.159000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow2_col5" class="data row2 col5" >2.594000</td>
#             </tr>
#             <tr>
#                         <th id="T_dca325a4_61c1_11eb_b9c0_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col0" class="data row3 col0" >-0.035400</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col1" class="data row3 col1" >0.013000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col2" class="data row3 col2" >-2.768000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col3" class="data row3 col3" >0.006000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col4" class="data row3 col4" >-0.060000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow3_col5" class="data row3 col5" >-0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_dca325a4_61c1_11eb_b9c0_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col0" class="data row4 col0" >1.082700</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col1" class="data row4 col1" >0.010000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col2" class="data row4 col2" >103.917000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col4" class="data row4 col4" >1.062000</td>
#                         <td id="T_dca325a4_61c1_11eb_b9c0_000af7c1116arow4_col5" class="data row4 col5" >1.103000</td>
#             </tr>
#     </tbody></table>
# 63

# %%
mod = smf.ols("regular ~ new_time*threshold + nonzero_exposure_regular", data=stata_check).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_d824909e_61c1_11eb_b9c0_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d824909e_61c1_11eb_b9c0_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow0_col0" class="data row0 col0" >0.397700</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow0_col1" class="data row0 col1" >0.373000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow0_col2" class="data row0 col2" >1.065000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow0_col3" class="data row0 col3" >0.287000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow0_col4" class="data row0 col4" >-0.334000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow0_col5" class="data row0 col5" >1.129000</td>
#             </tr>
#             <tr>
#                         <th id="T_d824909e_61c1_11eb_b9c0_000af7c1116alevel0_row1" class="row_heading level0 row1" >new_time</th>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow1_col0" class="data row1 col0" >-0.000100</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow1_col1" class="data row1 col1" >0.009000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow1_col2" class="data row1 col2" >-0.015000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow1_col3" class="data row1 col3" >0.988000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow1_col4" class="data row1 col4" >-0.018000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow1_col5" class="data row1 col5" >0.018000</td>
#             </tr>
#             <tr>
#                         <th id="T_d824909e_61c1_11eb_b9c0_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col0" class="data row2 col0" >4.000300</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col1" class="data row2 col1" >0.986000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col2" class="data row2 col2" >4.056000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col4" class="data row2 col4" >2.067000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow2_col5" class="data row2 col5" >5.933000</td>
#             </tr>
#             <tr>
#                         <th id="T_d824909e_61c1_11eb_b9c0_000af7c1116alevel0_row3" class="row_heading level0 row3" >new_time:threshold</th>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col0" class="data row3 col0" >-0.035400</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col1" class="data row3 col1" >0.013000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col2" class="data row3 col2" >-2.768000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col3" class="data row3 col3" >0.006000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col4" class="data row3 col4" >-0.060000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow3_col5" class="data row3 col5" >-0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_d824909e_61c1_11eb_b9c0_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col0" class="data row4 col0" >1.082700</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col1" class="data row4 col1" >0.010000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col2" class="data row4 col2" >103.917000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col4" class="data row4 col4" >1.062000</td>
#                         <td id="T_d824909e_61c1_11eb_b9c0_000af7c1116arow4_col5" class="data row4 col5" >1.103000</td>
#             </tr>
#     </tbody></table>
# 63

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow0_col0" class="data row0 col0" >0.389100</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow0_col1" class="data row0 col1" >0.232000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow0_col2" class="data row0 col2" >1.675000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow0_col3" class="data row0 col3" >0.094000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow0_col4" class="data row0 col4" >-0.066000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow0_col5" class="data row0 col5" >0.844000</td>
#             </tr>
#             <tr>
#                         <th id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow1_col0" class="data row1 col0" >-0.000100</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow1_col1" class="data row1 col1" >0.009000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow1_col2" class="data row1 col2" >-0.015000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow1_col3" class="data row1 col3" >0.988000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow1_col4" class="data row1 col4" >-0.018000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow1_col5" class="data row1 col5" >0.018000</td>
#             </tr>
#             <tr>
#                         <th id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col0" class="data row2 col0" >1.876800</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col1" class="data row2 col1" >0.366000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col2" class="data row2 col2" >5.126000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col4" class="data row2 col4" >1.159000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow2_col5" class="data row2 col5" >2.594000</td>
#             </tr>
#             <tr>
#                         <th id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col0" class="data row3 col0" >-0.035400</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col1" class="data row3 col1" >0.013000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col2" class="data row3 col2" >-2.768000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col3" class="data row3 col3" >0.006000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col4" class="data row3 col4" >-0.060000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow3_col5" class="data row3 col5" >-0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col0" class="data row4 col0" >1.082700</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col1" class="data row4 col1" >0.010000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col2" class="data row4 col2" >103.917000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col4" class="data row4 col4" >1.062000</td>
#                         <td id="T_9defe7d6_61bf_11eb_b9c0_000af7c1116arow4_col5" class="data row4 col5" >1.103000</td>
#             </tr>
#     </tbody></table>
# 63

# %%
plot_event_study(panel_df, quantiles=(.1,.9), title='New Tweets w/o Exposure')
plt.show()
plot_event_study(panel_df, cat='regular', quantiles=(.1,.9), title='All New Tweets')
plt.show()
plot_event_study(panel_df, cat='total_engagement', quantiles=(.1,.9))

# %% [markdown]
# # More Modeling
# Dean suggestions:
# 1. Run a random effects model to get a more general effect
# 2. Assume every possible trending time and average results
# 3. Do more research and see what methods are out there

# %% [markdown]
# ## Fixed Effect Model

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + C(hashtag) + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.076400</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.223000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >0.344000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.731000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.360000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.513000</td>
#             </tr>
#             <tr>
#                         <th id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.000800</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.010000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.079000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.937000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.019000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.021000</td>
#             </tr>
#             <tr>
#                         <th id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.978100</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.374000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >5.285000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >1.245000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >2.712000</td>
#             </tr>
#             <tr>
#                         <th id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.037400</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.014000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-2.615000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.009000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.065000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.009000</td>
#             </tr>
#             <tr>
#                         <th id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.074200</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.014000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >74.650000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.046000</td>
#                         <td id="T_7f1bd422_5fea_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.102000</td>
#             </tr>
#     </tbody></table>
# 63

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_86314f26_5fea_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86314f26_5fea_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.389100</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.232000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.675000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.094000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.066000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.844000</td>
#             </tr>
#             <tr>
#                         <th id="T_86314f26_5fea_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >-0.000100</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.009000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >-0.015000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.988000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.018000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.018000</td>
#             </tr>
#             <tr>
#                         <th id="T_86314f26_5fea_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.876800</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.366000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >5.126000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >1.159000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >2.594000</td>
#             </tr>
#             <tr>
#                         <th id="T_86314f26_5fea_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.035400</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.013000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-2.768000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.006000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.060000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_86314f26_5fea_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.082700</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.010000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >103.917000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.062000</td>
#                         <td id="T_86314f26_5fea_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.103000</td>
#             </tr>
#     </tbody></table>
# 63

# %% [markdown]
# ### Including Quadratic Function

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time_i*threshold + threshold*time_i2 + C(hashtag) + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']} )
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# ax = query.plot.scatter(x="time_i", y="regular", color="C0")
# query.assign(predictions=mod.fittedvalues).plot(x="time_i", y="predictions", ax=ax, color="C1")
# plt.title("Regression Discontinuity");
# Out:
# <style  type="text/css" >
#     #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col0 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col1 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col2 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col3 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col4 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col5 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow6_col0 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow6_col1 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow6_col2 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow6_col3 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow6_col4 {
#             background-color:  yellow;
#         }    #T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow6_col5 {
#             background-color:  yellow;
#         }</style><table id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >7.903800</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >1.956000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >4.040000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >4.070000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >11.738000</td>
#             </tr>
#             <tr>
#                         <th id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time_i</th>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >-0.193900</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.069000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >-2.829000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.005000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.328000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >-0.060000</td>
#             </tr>
#             <tr>
#                         <th id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >2.500400</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.790000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >3.165000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.002000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.952000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >4.049000</td>
#             </tr>
#             <tr>
#                         <th id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time_i:threshold</th>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >0.051200</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.072000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >0.713000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.476000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.090000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.192000</td>
#             </tr>
#             <tr>
#                         <th id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >time_i2</th>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >0.000900</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.001000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >1.287000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.198000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >-0.000000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >0.002000</td>
#             </tr>
#             <tr>
#                         <th id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116alevel0_row5" class="row_heading level0 row5" >threshold:time_i2</th>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow5_col0" class="data row5 col0" >-0.000800</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow5_col1" class="data row5 col1" >0.001000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow5_col2" class="data row5 col2" >-0.914000</td>
#                         <td id="T_3c775b04_5fe6_11eb_a1cb_000af7c1116arow5_col3" class="data row5 col3" >0
# 63

# %% [markdown]
# ## Random Effects
# Interestingly enough, the fixed effects aren't doing anything"

# %%
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
#temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.423</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.206</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >2.047</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.041</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.018</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.827</td>
#             </tr>
#             <tr>
#                         <th id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.000</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.086</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.932</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.009</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.010</td>
#             </tr>
#             <tr>
#                         <th id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.945</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.249</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >7.822</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >1.458</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >2.432</td>
#             </tr>
#             <tr>
#                         <th id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.037</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-5.165</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.000</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.051</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.023</td>
#             </tr>
#             <tr>
#                         <th id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.077</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >218.318</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.067</td>
#                         <td id="T_8b3c1884_5fea_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.087</td>
#             </tr>
#     </tbody></table>
# 63

# %% [markdown]
# ## Cumulative Stuff
# Let's transform the df to be cumulative

# %%
df, _ = build_df(hashtag, tweets, exposures, normalize_time=True, time_bin='5Min', 
                 cutoff_choice='earliest', include_missing=False, cumulative=True)

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='5Min',
                          cutoff_choice='best', include_missing=False, cumulative=True)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
        
panel_df = pd.concat(dfs)

# %%
trending.plot_event_study(panel_df, quantiles=(.1,.9), title='New Tweets w/o Exposure')
plt.show()
trending.plot_event_study(panel_df, cat='regular', quantiles=(.1,.9), title='All New Tweets')
plt.show()
trending.plot_event_study(panel_df, cat='total_engagement', quantiles=(.1,.9))

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
#temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col0 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col1 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col2 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col3 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col4 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col5 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_3bd212aa_6187_11eb_b9c0_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3bd212aa_6187_11eb_b9c0_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col0" class="data row0 col0" >6.115</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col1" class="data row0 col1" >2.102</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col2" class="data row0 col2" >2.908</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col3" class="data row0 col3" >0.004</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col4" class="data row0 col4" >1.994</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow0_col5" class="data row0 col5" >10.235</td>
#             </tr>
#             <tr>
#                         <th id="T_3bd212aa_6187_11eb_b9c0_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col0" class="data row1 col0" >0.057</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col1" class="data row1 col1" >0.019</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col2" class="data row1 col2" >2.903</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col3" class="data row1 col3" >0.004</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col4" class="data row1 col4" >0.018</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow1_col5" class="data row1 col5" >0.095</td>
#             </tr>
#             <tr>
#                         <th id="T_3bd212aa_6187_11eb_b9c0_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col0" class="data row2 col0" >4.913</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col1" class="data row2 col1" >0.960</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col2" class="data row2 col2" >5.119</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col4" class="data row2 col4" >3.032</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow2_col5" class="data row2 col5" >6.793</td>
#             </tr>
#             <tr>
#                         <th id="T_3bd212aa_6187_11eb_b9c0_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col0" class="data row3 col0" >0.064</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col1" class="data row3 col1" >0.028</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col2" class="data row3 col2" >2.325</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col3" class="data row3 col3" >0.020</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col4" class="data row3 col4" >0.010</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow3_col5" class="data row3 col5" >0.119</td>
#             </tr>
#             <tr>
#                         <th id="T_3bd212aa_6187_11eb_b9c0_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col0" class="data row4 col0" >1.091</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col1" class="data row4 col1" >0.003</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col2" class="data row4 col2" >401.723</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col4" class="data row4 col4" >1.086</td>
#                         <td id="T_3bd212aa_6187_11eb_b9c0_000af7c1116arow4_col5" class="data row4 col5" >1.096</td>
#             </tr>
#     </tbody></table>
# लक्ष्य_हमारा_मोदी_दोबारा

# %% [markdown]
# ### Aside, use the stupid event study methodology

# %%
ht_df = panel_df.query(f'hashtag == "jharkhandwithmodi"')
estimation_period = ht_df.query('time >= -60 & time <= 0 ').fillna(0)
# regression is regular ~ nonzero_exposure_regular
mod = smf.ols('regular ~ nonzero_exposure_regular', data=estimation_period)
mod.fit()

# %% [markdown]
# ## Choosing Random Start Times

# %%
import random

# %%
cached_dfs = [] 
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        cached_dfs.append(
            trending.build_df(hashtag, tweet_dict, exposures, normalize_time=True, 
                              time_bin='5Min', cutoff_choice='best', cache=True)
        )

# %%
'{:.2e}'.format(12 ** 64)
# Out:
# '1.17e+69'

# %%
meta_res = []
for i in tqdm(range(1000)):
    dfs = []
    for new_df, temp, start in cached_dfs:
        chosen = False
        while not chosen:
            trend_time = random.choice(range(13))
            temp, _ = trending.build_df_cached(new_df.copy(), temp.copy(), start, normalize_time=True, 
                                               time_bin='5Min', cutoff_choice=trend_time)
            temp = temp.assign(threshold=(temp.time > 0).astype(int))
            temp['hashtag'] = hashtag
            temp['trend_time'] = trend_time
            dfs.append(temp)
            chosen=True
#             except Exception as e:
#                 print('failed for', hashtag, 'time', trend_time, 'with error', e)        

    panel_df = pd.concat(dfs)
    query = panel_df.query('time >= -60 & time <= 60').fillna(0)
    mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
    #temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
    temp_df = mod.summary().tables[1].drop('Group Var')
    temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
    #trending.highlight_reg_output(temp_df)
    #print(query.hashtag.max())
    meta_res.append(pd.concat({i: temp_df}, names=['trial']))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
meta_df = pd.concat(meta_res)

# %%
meta_df['Trial'] = meta_df.index.get_level_values(0)
meta_df['Variable'] = meta_df.index.get_level_values(1)
meta_df = meta_df.astype({'Coef.': 'float', 'z': 'float'})

# %%
sns.boxplot(x='Coef.', y='Variable', data=meta_df, orient='h')
plt.grid(True)
plt.title('Coefficient Effect Sizes')
plt.xlabel('Coefficient')
plt.ylabel('Model Parameter')
# Out:
# Text(0, 0.5, 'Model Parameter')

# %%
plt.hist(meta_df.query('Variable == "threshold"').z)
# Out:
# (array([  2.,  18.,  66., 140., 186., 236., 192., 112.,  35.,  13.]),
#  array([-3.53  , -2.7708, -2.0116, -1.2524, -0.4932,  0.266 ,  1.0252,
#          1.7844,  2.5436,  3.3028,  4.062 ]),
#  <BarContainer object of 10 artists>)

# %%
meta_df.groupby('Variable')['Coef.'].mean()
# Out:
# Variable
# Intercept                   1.151678
# nonzero_exposure_regular    1.144246
# threshold                   0.193288
# time                        0.012043
# time:threshold             -0.007028
# Name: Coef., dtype: float64

# %%
plt.scatter(x='z', y='Coef.', data=meta_df.query('Variable == "threshold"'))
plt.grid()

# %%
sns.boxplot(x='z', y='Variable', data=meta_df.query('Variable != "nonzero_exposure_regular"'), orient='h')
plt.grid(True)
plt.title('Z Scores')
plt.xlabel('Coefficient')
plt.ylabel('Model Parameter')
# Out:
# Text(0, 0.5, 'Model Parameter')

# %% [markdown]
# ## Averaging Over All Possible Times
# With 5 minute intervals, there are 12 possible trending times. There are 63 different models. There are thus 750
# different combinations. No it's 12^63. Too many.
#
# I think this could work... I have a panel with all 12 possible series for each hashtag.

# %%
dfs = []
for hashtag, tweet_dict in tqdm(campaigns.items()):
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        for trend_time in range(13):
            try:
                temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='5Min',
                          cutoff_choice=trend_time)
                temp = temp.assign(threshold=(temp.time > 0).astype(int))
                temp['hashtag'] = hashtag
                temp['trend_time'] = trend_time
                dfs.append(temp)
            except:
                print('failed for', hashtag, 'time', trend_time, 'with error', e)        
        
panel_df = pd.concat(dfs)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=75.0), HTML(value='')))

# %%
panel_df.to_pickle(os.path.join(TWITTER_DATA_DIR, 'full_panel.pkl'))

# %%
stata_df = panel_df.copy()
stata_df['hashtag'] = pd.Categorical(stata_df.hashtag).codes
stata_df.to_stata(os.path.join(TWITTER_DATA_DIR, 'full_panel.dta'))

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
# Out:
# <style  type="text/css" >
#     #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col0 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col1 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col2 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col3 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col4 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col5 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_f4014e62_5f58_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4014e62_5f58_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >1.159400</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.235000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >4.926000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.698000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >1.621000</td>
#             </tr>
#             <tr>
#                         <th id="T_f4014e62_5f58_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.012200</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >2.257000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.024000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >0.002000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.023000</td>
#             </tr>
#             <tr>
#                         <th id="T_f4014e62_5f58_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >0.201700</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.108000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >1.864000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.062000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >-0.010000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >0.414000</td>
#             </tr>
#             <tr>
#                         <th id="T_f4014e62_5f58_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.007700</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.008000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-0.966000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.334000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.023000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.008000</td>
#             </tr>
#             <tr>
#                         <th id="T_f4014e62_5f58_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.144200</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.015000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >74.977000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.114000</td>
#                         <td id="T_f4014e62_5f58_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.174000</td>
#             </tr>
#     </tbody></table>

# %%
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
#temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col0 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col1 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col2 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col3 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col4 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col5 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_043a4932_5f59_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_043a4932_5f59_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >1.198</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.189</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >6.342</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.000</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.828</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >1.568</td>
#             </tr>
#             <tr>
#                         <th id="T_043a4932_5f59_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.009</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.002</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >4.861</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.000</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >0.006</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.013</td>
#             </tr>
#             <tr>
#                         <th id="T_043a4932_5f59_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >0.194</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.096</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >2.016</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.044</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.005</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >0.382</td>
#             </tr>
#             <tr>
#                         <th id="T_043a4932_5f59_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.005</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.003</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-1.961</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.050</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.011</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.000</td>
#             </tr>
#             <tr>
#                         <th id="T_043a4932_5f59_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.144</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.002</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >611.978</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.140</td>
#                         <td id="T_043a4932_5f59_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.148</td>
#             </tr>
#     </tbody></table>
# 63

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
# convert hashtags to numeric
query.hashtag = pd.Categorical(query.hashtag).codes
query = query.dropna()
mod = smf.ols("regular ~ time*threshold + nonzero_exposure_regular", data=query).fit(cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = pd.read_html(mod.summary().tables[1].as_html(), index_col=0, header=0)[0]
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
# Out:
# <style  type="text/css" >
#     #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col0 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col1 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col2 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col3 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col4 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col5 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_2e2eeb12_5c25_11eb_8087_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >coef</th>        <th class="col_heading level0 col1" >std err</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e2eeb12_5c25_11eb_8087_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col0" class="data row0 col0" >1.159400</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col1" class="data row0 col1" >0.235000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col2" class="data row0 col2" >4.926000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col4" class="data row0 col4" >0.698000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow0_col5" class="data row0 col5" >1.621000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e2eeb12_5c25_11eb_8087_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col0" class="data row1 col0" >0.012200</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col1" class="data row1 col1" >0.005000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col2" class="data row1 col2" >2.257000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col3" class="data row1 col3" >0.024000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col4" class="data row1 col4" >0.002000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow1_col5" class="data row1 col5" >0.023000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e2eeb12_5c25_11eb_8087_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow2_col0" class="data row2 col0" >0.201700</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow2_col1" class="data row2 col1" >0.108000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow2_col2" class="data row2 col2" >1.864000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow2_col3" class="data row2 col3" >0.062000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow2_col4" class="data row2 col4" >-0.010000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow2_col5" class="data row2 col5" >0.414000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e2eeb12_5c25_11eb_8087_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow3_col0" class="data row3 col0" >-0.007700</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow3_col1" class="data row3 col1" >0.008000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow3_col2" class="data row3 col2" >-0.966000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow3_col3" class="data row3 col3" >0.334000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow3_col4" class="data row3 col4" >-0.023000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow3_col5" class="data row3 col5" >0.008000</td>
#             </tr>
#             <tr>
#                         <th id="T_2e2eeb12_5c25_11eb_8087_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col0" class="data row4 col0" >1.144200</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col1" class="data row4 col1" >0.015000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col2" class="data row4 col2" >74.977000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col3" class="data row4 col3" >0.000000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col4" class="data row4 col4" >1.114000</td>
#                         <td id="T_2e2eeb12_5c25_11eb_8087_000af7c1116arow4_col5" class="data row4 col5" >1.174000</td>
#             </tr>
#     </tbody></table>

# %%
panel_df
# Out:
#           template  template_retweet  regular  regular_retweet  \
# adj_date
# -295           0.0               0.0      0.0              0.0
# -290           0.0               0.0      0.0              0.0
# -285           0.0               0.0      0.0              0.0
# -280           0.0               0.0      0.0              0.0
# -275           0.0               0.0      0.0              0.0
# ...            ...               ...      ...              ...
#  885           0.0               0.0      1.0              6.0
#  890           0.0               0.0      4.0              3.0
#  895           0.0               0.0      1.0              2.0
#  900           0.0               0.0      3.0              1.0
#  905           0.0               0.0      3.0              1.0
#
#           nonzero_exposure_regular  zero_exposure_regular  total_engagement  \
# adj_date
# -295                           0.0                    0.0               0.0
# -290                           0.0                    0.0               0.0
# -285                           0.0                    0.0               0.0
# -280                           0.0                    0.0               0.0
# -275                           0.0                    0.0               0.0
# ...                            ...                    ...               ...
#  885                           1.0                    0.0               7.0
#  890                           3.0                    1.0               7.0
#  895                           1.0                    0.0               3.0
#  900                           3.0                    0.0               4.0
#  905                           3.0                    0.0               4.0
#
#           rt_engagement            hashtag  time  time_i  time_i2  \
# adj_date
# -295                0.0  jharkhandwithmodi  -295       0        0
# -290                0.0  jharkhandwithmodi  -290       1        1
# -285                0.0  jharkhandwithmodi  -285       2        4
# -280                0.0  jharkhandwithmodi  -280       3        9
# -275                0.0  jharkhandwithmodi  -275       4       16
# ...                 ...                ...   ...     ...      ...
#  885                6.0         gappupappu   885     248    61504
#  890                3.0         gappupappu   890     249    62001
#  895                2.0         gappupappu   895     250    62500
#  900                1.0         gappupappu   900     251    63001
#  905                1.0         gappupappu   905     252    63504
#
#               trending_start  inferred_trending_start  threshold  trend_time
# adj_date
# -295     2019-02-17 15:30:00                        0          0           0
# -290     2019-02-17 15:30:00                        0          0           0
# -285     2019-02-17 15:30:00                        0          0           0
# -280     2019-02-17 15:30:00                        0          0           0
# -275     2019-02-17 15:30:00                        0          0           0
# ...                      ...                      ...        ...         ...
#  885     2018-10-11 23:30:00                        0          1          12
#  890     2018-10-11 23:30:00                        0          1          12
#  895     2018-10-11 23:30:00                        0          1          12
#  900     2018-10-11 23:30:00                        0          1          12
#  905     2018-10-11 23:30:00                        0          1          12
#
# [767962 rows x 16 columns]

# %%
meta_res = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        for trend_time in range(13):
            try:
                res = trending.run_statistics(
                    *build_df(hashtag, tweet_dict, exposures,
                              time_bin='5Min', cutoff_choice=trend_time), 
                    periods=(12,12))
                meta_res.append(pd.concat({(hashtag, trend_time): res}, names=['Hashtag', 'trend_index']))
            except Exception as e:
                print('failed for', hashtag, 'time', trend_time, 'with error', e)
# Out:
# Not enough periods in df, running on model from  2019-02-09 17:00:00 to 2019-02-09 18:20:00
# Not enough periods in df, running on model from  2019-02-09 17:00:00 to 2019-02-09 18:25:00
# Not enough periods in df, running on model from  2019-02-09 17:00:00 to 2019-02-09 18:30:00
# Not enough periods in df, running on model from  2019-02-09 17:00:00 to 2019-02-09 18:35:00
# Not enough periods in df, running on model from  2019-02-09 17:00:00 to 2019-02-09 18:40:00
# Not enough periods in df, running on model from  2019-02-09 17:00:00 to 2019-02-09 18:45:00
# Not enough periods in df, running on model from  2019-02-09 17:00:00 to 2019-02-09 18:50:00
# failed for timesofrahul time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for timesofrahul time 1 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 09:30:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 09:35:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 09:40:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 09:45:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 09:50:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 09:55:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 10:00:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 10:05:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 10:10:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 10:15:00
# Not enough periods in df, running on model from  2019-04-22 08:35:00 to 2019-04-22 10:20:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 18:20:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 18:25:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 18:30:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 18:35:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 18:40:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 18:45:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 18:50:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 18:55:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 19:00:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 19:05:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 19:10:00
# Not enough periods in df, running on model from  2019-01-06 17:25:00 to 2019-01-06 19:15:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 12:20:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 12:25:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 12:30:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 12:35:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 12:40:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 12:45:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 12:50:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 12:55:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 13:00:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 13:05:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 13:10:00
# Not enough periods in df, running on model from  2019-02-13 11:25:00 to 2019-02-13 13:15:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 11:20:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 11:25:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 11:30:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 11:35:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 11:40:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 11:45:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 11:50:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 11:55:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 12:00:00
# Not enough periods in df, running on model from  2018-12-05 10:15:00 to 2018-12-05 12:05:00
# Not enough periods in df, running on model from  2018-09-07 16:40:00 to 2018-09-07 18:20:00
# Not enough periods in df, running on model from  2018-09-07 16:40:00 to 2018-09-07 18:25:00
# Not enough periods in df, running on model from  2018-09-07 16:40:00 to 2018-09-07 18:30:00
# failed for congressinsultsairforce time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for congressinsultsairforce time 1 with error index 0 is out of bounds for axis 0 with size 0
# failed for congressinsultsairforce time 2 with error index 0 is out of bounds for axis 0 with size 0
# failed for congressinsultsairforce time 3 with error index 0 is out of bounds for axis 0 with size 0
# failed for congressinsultsairforce time 4 with error index 0 is out of bounds for axis 0 with size 0
# failed for congressinsultsairforce time 5 with error index 0 is out of bounds for axis 0 with size 0
# failed for congressinsultsairforce time 6 with error index 0 is out of bounds for axis 0 with size 0
# failed for congressinsultsairforce time 7 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2018-12-20 19:05:00 to 2018-12-20 20:00:00
# Not enough periods in df, running on model from  2018-12-20 19:05:00 to 2018-12-20 20:05:00
# Not enough periods in df, running on model from  2018-12-20 19:05:00 to 2018-12-20 20:10:00
# Not enough periods in df, running on model from  2018-12-20 19:05:00 to 2018-12-20 20:15:00
# Not enough periods in df, running on model from  2018-12-20 19:05:00 to 2018-12-20 20:20:00
# failed for congressdefencescams time 0 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 10:25:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 10:30:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 10:35:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 10:40:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 10:45:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 10:50:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 10:55:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 11:00:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 11:05:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 11:10:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 11:15:00
# Not enough periods in df, running on model from  2018-10-17 09:30:00 to 2018-10-17 11:20:00
# failed for namowithtraders time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for namowithtraders time 1 with error index 0 is out of bounds for axis 0 with size 0
# failed for namowithtraders time 2 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 16:35:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 16:40:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 16:45:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 16:50:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 16:55:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 17:00:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 17:05:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 17:10:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 17:15:00
# Not enough periods in df, running on model from  2019-04-19 15:40:00 to 2019-04-19 17:20:00
# failed for indiabolemodidobara time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for indiabolemodidobara time 1 with error index 0 is out of bounds for axis 0 with size 0
# failed for indiabolemodidobara time 2 with error index 0 is out of bounds for axis 0 with size 0
# failed for indiabolemodidobara time 3 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 11:40:00
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 11:45:00
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 11:50:00
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 11:55:00
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 12:00:00
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 12:05:00
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 12:10:00
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 12:15:00
# Not enough periods in df, running on model from  2019-04-17 10:45:00 to 2019-04-17 12:20:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 21:20:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 21:25:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 21:30:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 21:35:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 21:40:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 21:45:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 21:50:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 21:55:00
# Not enough periods in df, running on model from  2019-03-13 20:10:00 to 2019-03-13 22:00:00
# failed for zamanatke1000din time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for zamanatke1000din time 1 with error index 0 is out of bounds for axis 0 with size 0
# failed for zamanatke1000din time 2 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 15:35:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 15:40:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 15:45:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 15:50:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 15:55:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 16:00:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 16:05:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 16:10:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 16:15:00
# Not enough periods in df, running on model from  2018-09-14 14:40:00 to 2018-09-14 16:20:00
# failed for आदर्शघोटाला_संघर्ष_यात्रा time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for आदर्शघोटाला_संघर्ष_यात्रा time 1 with error index 0 is out of bounds for axis 0 with size 0
# failed for आदर्शघोटाला_संघर्ष_यात्रा time 2 with error index 0 is out of bounds for axis 0 with size 0
# failed for आदर्शघोटाला_संघर्ष_यात्रा time 3 with error index 0 is out of bounds for axis 0 with size 0
# failed for आदर्शघोटाला_संघर्ष_यात्रा time 4 with error index 0 is out of bounds for axis 0 with size 0
# failed for आदर्शघोटाला_संघर्ष_यात्रा time 5 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2018-09-06 12:55:00 to 2018-09-06 13:50:00
# Not enough periods in df, running on model from  2018-09-06 12:55:00 to 2018-09-06 13:55:00
# Not enough periods in df, running on model from  2018-09-06 12:55:00 to 2018-09-06 14:00:00
# Not enough periods in df, running on model from  2018-09-06 12:55:00 to 2018-09-06 14:05:00
# Not enough periods in df, running on model from  2018-09-06 12:55:00 to 2018-09-06 14:10:00
# Not enough periods in df, running on model from  2018-09-06 12:55:00 to 2018-09-06 14:15:00
# Not enough periods in df, running on model from  2018-09-06 12:55:00 to 2018-09-06 14:20:00
# Not enough periods in df, running on model from  2019-02-23 14:05:00 to 2019-02-23 15:20:00
# Not enough periods in df, running on model from  2019-02-23 14:05:00 to 2019-02-23 15:25:00
# Not enough periods in df, running on model from  2019-02-23 14:05:00 to 2019-02-23 15:30:00
# Not enough periods in df, running on model from  2019-02-23 14:05:00 to 2019-02-23 15:35:00
# Not enough periods in df, running on model from  2019-02-23 14:05:00 to 2019-02-23 15:40:00
# Not enough periods in df, running on model from  2019-02-23 14:05:00 to 2019-02-23 15:45:00
# Not enough periods in df, running on model from  2019-02-23 14:05:00 to 2019-02-23 15:50:00
# Not enough periods in df, running on model from  2019-02-23 14:05:00 to 2019-02-23 15:55:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 10:20:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 10:25:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 10:30:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 10:35:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 10:40:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 10:45:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 10:50:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 10:55:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 11:00:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 11:05:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 11:10:00
# Not enough periods in df, running on model from  2019-03-13 09:25:00 to 2019-03-13 11:15:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 16:20:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 16:25:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 16:30:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 16:35:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 16:40:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 16:45:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 16:50:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 16:55:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 17:00:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 17:05:00
# Not enough periods in df, running on model from  2018-10-14 15:20:00 to 2018-10-14 17:10:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 10:20:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 10:25:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 10:30:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 10:35:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 10:40:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 10:45:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 10:50:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 10:55:00
# Not enough periods in df, running on model from  2018-11-15 09:10:00 to 2018-11-15 11:00:00
# Not enough periods in df, running on model from  2019-02-17 17:05:00 to 2019-02-17 18:20:00
# Not enough periods in df, running on model from  2019-02-17 17:05:00 to 2019-02-17 18:25:00
# Not enough periods in df, running on model from  2019-02-17 17:05:00 to 2019-02-17 18:30:00
# Not enough periods in df, running on model from  2019-02-17 17:05:00 to 2019-02-17 18:35:00
# Not enough periods in df, running on model from  2019-02-17 17:05:00 to 2019-02-17 18:40:00
# Not enough periods in df, running on model from  2019-02-17 17:05:00 to 2019-02-17 18:45:00
# Not enough periods in df, running on model from  2019-02-17 17:05:00 to 2019-02-17 18:50:00
# Not enough periods in df, running on model from  2019-02-17 17:05:00 to 2019-02-17 18:55:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 12:20:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 12:25:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 12:30:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 12:35:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 12:40:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 12:45:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 12:50:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 12:55:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 13:00:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 13:05:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 13:10:00
# Not enough periods in df, running on model from  2019-02-01 11:25:00 to 2019-02-01 13:15:00
# failed for congresseurofighterscandal time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for congresseurofighterscandal time 1 with error index 0 is out of bounds for axis 0 with size 0
# failed for congresseurofighterscandal time 2 with error index 0 is out of bounds for axis 0 with size 0
# failed for congresseurofighterscandal time 3 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 09:40:00
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 09:45:00
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 09:50:00
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 09:55:00
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 10:00:00
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 10:05:00
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 10:10:00
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 10:15:00
# Not enough periods in df, running on model from  2019-01-08 08:45:00 to 2019-01-08 10:20:00
# Not enough periods in df, running on model from  2019-01-10 10:45:00 to 2019-01-10 12:20:00
# Not enough periods in df, running on model from  2019-01-10 10:45:00 to 2019-01-10 12:25:00
# Not enough periods in df, running on model from  2019-01-10 10:45:00 to 2019-01-10 12:30:00
# Not enough periods in df, running on model from  2019-01-10 10:45:00 to 2019-01-10 12:35:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 16:20:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 16:25:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 16:30:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 16:35:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 16:40:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 16:45:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 16:50:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 16:55:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 17:00:00
# Not enough periods in df, running on model from  2019-02-24 15:15:00 to 2019-02-24 17:05:00
# failed for modifiedtextiles time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedtextiles time 1 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedtextiles time 2 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedtextiles time 3 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedtextiles time 4 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedtextiles time 5 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2019-01-22 14:55:00 to 2019-01-22 15:50:00
# Not enough periods in df, running on model from  2019-01-22 14:55:00 to 2019-01-22 15:55:00
# Not enough periods in df, running on model from  2019-01-22 14:55:00 to 2019-01-22 16:00:00
# Not enough periods in df, running on model from  2019-01-22 14:55:00 to 2019-01-22 16:05:00
# Not enough periods in df, running on model from  2019-01-22 14:55:00 to 2019-01-22 16:10:00
# Not enough periods in df, running on model from  2019-01-22 14:55:00 to 2019-01-22 16:15:00
# Not enough periods in df, running on model from  2019-01-22 14:55:00 to 2019-01-22 16:20:00
# failed for modifiedjobs time 0 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedjobs time 1 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedjobs time 2 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedjobs time 3 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedjobs time 4 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedjobs time 5 with error index 0 is out of bounds for axis 0 with size 0
# failed for modifiedjobs time 6 with error index 0 is out of bounds for axis 0 with size 0
# Not enough periods in df, running on model from  2019-03-09 15:00:00 to 2019-03-09 15:55:00
# Not enough periods in df, running on model from  2019-03-09 15:00:00 to 2019-03-09 16:00:00
# Not enough periods in df, running on model from  2019-03-09 15:00:00 to 2019-03-09 16:05:00
# Not enough periods in df, running on model from  2019-03-09 15:00:00 to 2019-03-09 16:10:00
# Not enough periods in df, running on model from  2019-03-09 15:00:00 to 2019-03-09 16:15:00
# Not enough periods in df, running on model from  2019-03-09 15:00:00 to 2019-03-09 16:20:00

# %%
meta_df = pd.concat(meta_res)

# %%
import math

# %%
meta_df['inv_var'] = 1/((meta_df['std err']*math.sqrt(24))**2)
meta_df['coef*var'] = meta_df.coef * meta_df.inv_var

# %%
meta_df
# Out:
#                                                                       coef  \
# Hashtag           trend_index Trial
# jharkhandwithmodi 0           New Tweets Intercept                -22.6559
#                                          time_i                     0.4528
#                                          threshold                 51.7126
#                                          time_i:threshold          -0.8775
#                                          nonzero_exposure_regular   1.0380
# ...                                                                    ...
# gappupappu        12          New Tweets Intercept                  5.4483
#                                          time_i                    -0.0580
#                                          threshold                 10.2778
#                                          time_i:threshold          -0.1326
#                                          nonzero_exposure_regular   0.8838
#
#                                                                    std err  \
# Hashtag           trend_index Trial
# jharkhandwithmodi 0           New Tweets Intercept                  15.526
#                                          time_i                      0.306
#                                          threshold                  33.090
#                                          time_i:threshold            0.552
#                                          nonzero_exposure_regular    0.136
# ...                                                                    ...
# gappupappu        12          New Tweets Intercept                   4.803
#                                          time_i                      0.074
#                                          threshold                   8.534
#                                          time_i:threshold            0.119
#                                          nonzero_exposure_regular    0.040
#
#                                                                         z  \
# Hashtag           trend_index Trial
# jharkhandwithmodi 0           New Tweets Intercept                 -1.459
#                                          time_i                     1.482
#                                          threshold                  1.563
#                                          time_i:threshold          -1.590
#                                          nonzero_exposure_regular   7.627
# ...                                                                   ...
# gappupappu        12          New Tweets Intercept                  1.134
#                                          time_i                    -0.780
#                                          threshold                  1.204
#                                          time_i:threshold          -1.111
#                                          nonzero_exposure_regular  22.327
#
#                                                                    P>|z|  \
# Hashtag           trend_index Trial
# jharkhandwithmodi 0           New Tweets Intercept                 0.144
#                                          time_i                    0.138
#                                          threshold                 0.118
#                                          time_i:threshold          0.112
#                                          nonzero_exposure_regular  0.000
# ...                                                                  ...
# gappupappu        12          New Tweets Intercept                 0.257
#                                          time_i                    0.435
#                                          threshold                 0.228
#                                          time_i:threshold          0.266
#                                          nonzero_exposure_regular  0.000
#
#                                                                    [0.025  \
# Hashtag           trend_index Trial
# jharkhandwithmodi 0           New Tweets Intercept                -53.085
#                                          time_i                    -0.146
#                                          threshold                -13.142
#                                          time_i:threshold          -1.959
#                                          nonzero_exposure_regular   0.771
# ...                                                                   ...
# gappupappu        12          New Tweets Intercept                 -3.965
#                                          time_i                    -0.204
#                                          threshold                 -6.449
#                                          time_i:threshold          -0.366
#                                          nonzero_exposure_regular   0.806
#
#                                                                     0.975]  \
# Hashtag           trend_index Trial
# jharkhandwithmodi 0           New Tweets Intercept                   7.774
#                                          time_i                      1.052
#                                          threshold                 116.567
#                                          time_i:threshold            0.204
#                                          nonzero_exposure_regular    1.305
# ...                                                                    ...
# gappupappu        12          New Tweets Intercept                  14.861
#                                          time_i                      0.088
#                                          threshold                  27.004
#                                          time_i:threshold            0.101
#                                          nonzero_exposure_regular    0.961
#
#                                                                             var  \
# Hashtag           trend_index Trial
# jharkhandwithmodi 0           New Tweets Intercept                  5785.360224
#                                          time_i                        2.247264
#                                          threshold                 26278.754400
#                                          time_i:threshold              7.312896
#                                          nonzero_exposure_regular      0.443904
# ...                                                                         ...
# gappupappu        12          New Tweets Intercept                   553.651416
#                                          time_i                        0.131424
#                                          threshold                  1747.899744
#                                          time_i:threshold              0.339864
#                                          nonzero_exposure_regular      0.038400
#
#                                                                      inv_var
# Hashtag           trend_index Trial
# jharkhandwithmodi 0           New Tweets Intercept                  0.000173
#                                          time_i                     0.444986
#                                          threshold                  0.000038
#                                          time_i:threshold           0.136745
#                                          nonzero_exposure_regular   2.252739
# ...                                                                      ...
# gappupappu        12          New Tweets Intercept                  0.001806
#                                          time_i                     7.608960
#                                          threshold                  0.000572
#                                          time_i:threshold           2.942353
#                                          nonzero_exposure_regular  26.041667
#
# [3940 rows x 8 columns]

# %%
meta_df.reset_index().groupby(['level_3']).mean()
# Out:
#                           trend_index      coef    std err             z  \
# level_3
# Intercept                     6.21066 -2.672001   5.266818  2.381547e+12
# nonzero_exposure_regular      6.21066  1.119723   0.111057  1.569362e+13
# threshold                     6.21066  4.730780  14.088571  1.756244e-01
# time_i                        6.21066  0.057998   0.186726  1.378866e+11
# time_i:threshold              6.21066 -0.035307   0.335624 -1.276523e-01
#
#                              P>|z|     [0.025     0.975]           var  \
# level_3
# Intercept                 0.310671 -13.067312   7.578302   2459.527279
# nonzero_exposure_regular  0.000363   0.902047   1.337396      0.535593
# threshold                 0.286274 -22.882310  32.343878  12180.082154
# time_i                    0.299361  -0.308366   0.423581      3.096773
# time_i:threshold          0.268717  -0.693132   0.622528      7.503441
#
#                                inv_var      coef*var
# level_3
# Intercept                 1.090633e+26  2.052679e+25
# nonzero_exposure_regular  3.397812e+27  3.397812e+27
# threshold                 1.795757e+25  1.804576e+10
# time_i                    1.504762e+29  3.104067e+23
# time_i:threshold          7.221820e+28 -1.668730e+12

# %% [markdown]
# ### What happened with hashtags that didn't trend?

# %%
for hashtag, tweet_dict in campaigns.items():
    if hashtag in preprocessing.never_trended:
        print(hashtag)
        time_bin = '5Min'
        for t_id, tweet in tweet_dict.items():
            tweet['adj_date'] = tweet['date'] + timedelta(hours=5, minutes=30)
            if tweet['retweet_from'] == '':
                if tweet['template'] != '':
                    tweet['type'] = 'template'
                else:
                    tweet['type'] = 'regular'
            else:
                if tweet['template'] != '':
                    tweet['type'] = 'template_retweet'
                else:
                    tweet['type'] = 'regular_retweet'

            t_exp, n_exp, _ = exposures[hashtag][tweet['username']]
            tweet['template_exposure'] = t_exp
            tweet['normal_exposure'] = n_exp
            tweet['total_exposure'] = t_exp + n_exp

        df = pd.DataFrame.from_dict(tweet_dict).transpose()
        df.index = df['adj_date']
        colors = ["red","orange",'black','grey']
        types = ['template', 'template_retweet', 'regular', 'regular_retweet']

        series_list = []
        for t in types:
            temp = df[df.type == t] # only use regular tweets
            temp = temp.resample(time_bin).count().username
            series_list.append(temp)
        temp = df[df.type == 'regular'] # only use regular tweets
        series_list.append(temp[temp.total_exposure > 0].resample(time_bin).count().username)

        temp = temp[temp.total_exposure == 0].resample(time_bin).count().username
        series_list.append(temp)

        new_df = pd.DataFrame(series_list).T
        new_df.columns=[*types, 'nonzero_exposure_regular', 'zero_exposure_regular']
        new_df['total_engagement'] = new_df[types].sum(axis=1)
        new_df['rt_engagement'] = new_df[['regular_retweet', 'template_retweet']].sum(axis=1)
        new_df['hashtag'] = hashtag
        new_df['zero_exposure_regular'].plot()
        plt.show()
# Out:
# hooghly_chalo
# congressframedamitshah
# congressagainstnationalsecurity
# nris4modi

# %% [markdown]
# # Messing Around with Treatment Time

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='5Min',
                          cutoff_choice='earliest', include_missing=False)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
        
panel_df = pd.concat(dfs)

# %%
plot_event_study(panel_df, quantiles=(.1,.9), title='New Tweets w/o Exposure')
plt.show()
plot_event_study(panel_df, cat='regular', quantiles=(.1,.9), title='All New Tweets')
plt.show()
plot_event_study(panel_df, cat='total_engagement', quantiles=(.1,.9))

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
query = query.dropna()
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_e8063240_5fed_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8063240_5fed_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.561</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.211</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >2.660</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.008</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.148</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.975</td>
#             </tr>
#             <tr>
#                         <th id="T_e8063240_5fed_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.007</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >1.291</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.197</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.004</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.018</td>
#             </tr>
#             <tr>
#                         <th id="T_e8063240_5fed_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >-0.353</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.269</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >-1.312</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.190</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >-0.881</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >0.175</td>
#             </tr>
#             <tr>
#                         <th id="T_e8063240_5fed_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >0.007</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.008</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >0.932</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.351</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.008</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.022</td>
#             </tr>
#             <tr>
#                         <th id="T_e8063240_5fed_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.095</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.006</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >181.137</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.083</td>
#                         <td id="T_e8063240_5fed_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.107</td>
#             </tr>
#     </tbody></table>
# लक्ष्य_हमारा_मोदी_दोबारा

# %%
query = panel_df.query('time >= -60 & time <= 120').fillna(0)
query = query.dropna()
mod = smf.mixedlm("regular ~ C(hashtag)*time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-92-d3b42685f6ad> in <module>
#       1 query = panel_df.query('time >= -60 & time <= 120').fillna(0)
#       2 query = query.dropna()
# ----> 3 mod = smf.mixedlm("regular ~ C(hashtag)*time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
#       4 temp_df = mod.summary().tables[1].drop('Group Var')
#       5 temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py in fit(self, start_params, reml, niter_sa, do_cg, fe_pen, cov_pen, free, full_output, method, **kwargs)
#    2101             # Try optimizing one or more times
#    2102             for j in range(len(method)):
# -> 2103                 rslt = super(MixedLM, self).fit(start_params=packed,
#    2104                                                 skip_hessian=True,
#    2105                                                 method=method[j],
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     516         warn_convergence = kwargs.pop('warn_convergence', True)
#     517         optimizer = Optimizer()
# --> 518         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     519                                                        fargs, kwargs,
#     520                                                        hessian=hess,
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     213
#     214         func = fit_funcs[method]
# --> 215         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     216                             disp=disp, maxiter=maxiter, callback=callback,
#     217                             retall=retall, full_output=full_output,
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit_bfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     351     norm = kwargs.setdefault('norm', np.Inf)
#     352     epsilon = kwargs.setdefault('epsilon', 1.4901161193847656e-08)
# --> 353     retvals = optimize.fmin_bfgs(f, start_params, score, args=fargs,
#     354                                  gtol=gtol, norm=norm, epsilon=epsilon,
#     355                                  maxiter=maxiter, full_output=full_output,
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/scipy/optimize/optimize.py in fmin_bfgs(f, x0, fprime, args, gtol, norm, epsilon, maxiter, full_output, disp, retall, callback)
#    1041             'return_all': retall}
#    1042
# -> 1043     res = _minimize_bfgs(f, x0, args, fprime, callback=callback, **opts)
#    1044
#    1045     if full_output:
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1099         maxiter = len(x0) * 200
#    1100
# -> 1101     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1102                                   finite_diff_rel_step=finite_diff_rel_step)
#    1103
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/scipy/optimize/optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     # ScalarFunction caches. Reuse of fun(x) during grad
#     260     # calculation reduces overall function evaluations.
# --> 261     sf = ScalarFunction(fun, x0, args, grad, hess,
#     262                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     263
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#      74
#      75         self._update_fun_impl = update_fun
# ---> 76         self._update_fun()
#      77
#      78         # Gradient evaluation
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/statsmodels/base/model.py in f(params, *args)
#     498
#     499         def f(params, *args):
# --> 500             return -self.loglike(params, *args) / nobs
#     501
#     502         if method == 'newton':
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py in loglike(self, params, profile_fe)
#    1435         # Move to the profile set
#    1436         if profile_fe:
# -> 1437             fe_params = self.get_fe_params(cov_re, vcomp)
#    1438         else:
#    1439             fe_params = params.fe_params
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py in get_fe_params(self, cov_re, vcomp)
#    1282             xtxy += np.dot(exog.T, u)
#    1283
# -> 1284         fe_params = np.linalg.solve(xtxy[:, 0:-1], xtxy[:, -1])
#    1285
#    1286         return fe_params
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/numpy/linalg/linalg.py in solve(a, b)
#     392     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     393     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 394     r = gufunc(a, b, signature=signature, extobj=extobj)
#     395
#     396     return wrap(r.astype(result_t, copy=False))
#
# ~/.conda/envs/gt/lib/python3.8/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='30Min',
                          cutoff_choice='best', include_missing=False)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
        
panel_df = pd.concat(dfs)

# %%
query = panel_df.query('time >= -60 & time <= 120').fillna(0)
query = query.dropna()
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >2.024</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >1.032</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.962</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.050</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.002</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >4.046</td>
#             </tr>
#             <tr>
#                         <th id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.014</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.026</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.548</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.584</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.037</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.065</td>
#             </tr>
#             <tr>
#                         <th id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >5.724</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >1.579</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >3.626</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >2.630</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >8.819</td>
#             </tr>
#             <tr>
#                         <th id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.063</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.030</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-2.087</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.037</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.122</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.004</td>
#             </tr>
#             <tr>
#                         <th id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.097</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >207.933</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.087</td>
#                         <td id="T_9a0975d0_5ff1_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.107</td>
#             </tr>
#     </tbody></table>
# लक्ष्य_हमारा_मोदी_दोबारा

# %%
plot_event_study(panel_df, quantiles=(.1,.9), title='New Tweets w/o Exposure')
plt.show()
plot_event_study(panel_df, cat='regular', quantiles=(.1,.9), title='All New Tweets')
plt.show()
plot_event_study(panel_df, cat='total_engagement', quantiles=(.1,.9))

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='1H',
                          cutoff_choice='earliest', include_missing=False)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
        
panel_df = pd.concat(dfs)

# %%
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
query = query.dropna()
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.423</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.206</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >2.047</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.041</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.018</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.827</td>
#             </tr>
#             <tr>
#                         <th id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.000</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.086</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.932</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.009</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.010</td>
#             </tr>
#             <tr>
#                         <th id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.945</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.249</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >7.822</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >1.458</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >2.432</td>
#             </tr>
#             <tr>
#                         <th id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.037</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-5.165</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.000</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.051</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.023</td>
#             </tr>
#             <tr>
#                         <th id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.077</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >218.318</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.067</td>
#                         <td id="T_3e0cb81a_5ffa_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.087</td>
#             </tr>
#     </tbody></table>
# लक्ष्य_हमारा_मोदी_दोबारा

# %%
query = panel_df.query('time >= -100 & time <= 120').fillna(0)
query = query.dropna()
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >1.939</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >3.112</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >0.623</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.533</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-4.160</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >8.038</td>
#             </tr>
#             <tr>
#                         <th id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.019</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.047</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.407</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.684</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.073</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.111</td>
#             </tr>
#             <tr>
#                         <th id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >-0.087</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >3.921</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >-0.022</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.982</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >-7.772</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >7.597</td>
#             </tr>
#             <tr>
#                         <th id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >0.057</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.061</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >0.948</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.343</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.061</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.176</td>
#             </tr>
#             <tr>
#                         <th id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.102</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.007</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >159.479</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.089</td>
#                         <td id="T_f9f77c04_5ff5_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.116</td>
#             </tr>
#     </tbody></table>
# लक्ष्य_हमारा_मोदी_दोबारा

# %%
panel_df
# Out:
#           template  template_retweet  regular  regular_retweet  \
# adj_date
# -330           0.0               0.0      0.0              0.0
# -270           1.0               0.0      0.0              0.0
# -210           6.0               0.0      0.0              0.0
# -150           9.0               0.0      1.0              0.0
# -90          785.0             158.0     97.0             78.0
# ...            ...               ...      ...              ...
#  630           0.0               0.0     13.0             52.0
#  690           0.0               0.0     18.0             36.0
#  750           0.0               0.0     19.0             19.0
#  810           0.0               0.0     25.0             29.0
#  870           0.0               0.0     13.0             25.0
#
#           nonzero_exposure_regular  zero_exposure_regular  total_engagement  \
# adj_date
# -330                           0.0                    0.0               0.0
# -270                           0.0                    0.0               1.0
# -210                           0.0                    0.0               6.0
# -150                           0.0                    1.0              10.0
# -90                           66.0                   31.0            1118.0
# ...                            ...                    ...               ...
#  630                          13.0                    0.0              65.0
#  690                          16.0                    2.0              54.0
#  750                          18.0                    1.0              38.0
#  810                          21.0                    4.0              54.0
#  870                          12.0                    1.0              38.0
#
#           rt_engagement            hashtag  time  time_i  time_i2  \
# adj_date
# -330                0.0  jharkhandwithmodi  -330       0        0
# -270                0.0  jharkhandwithmodi  -270       1        1
# -210                0.0  jharkhandwithmodi  -210       2        4
# -150                0.0  jharkhandwithmodi  -150       3        9
# -90               236.0  jharkhandwithmodi   -90       4       16
# ...                 ...                ...   ...     ...      ...
#  630               52.0         gappupappu   630      16      256
#  690               36.0         gappupappu   690      17      289
#  750               19.0         gappupappu   750      18      324
#  810               29.0         gappupappu   810      19      361
#  870               25.0         gappupappu   870      20      400
#
#               trending_start  inferred_trending_start  threshold
# adj_date
# -330     2019-02-17 15:30:00                        0          0
# -270     2019-02-17 15:30:00                        0          0
# -210     2019-02-17 15:30:00                        0          0
# -150     2019-02-17 15:30:00                        0          0
# -90      2019-02-17 15:30:00                        0          0
# ...                      ...                      ...        ...
#  630     2018-10-11 23:30:00                        0          1
#  690     2018-10-11 23:30:00                        0          1
#  750     2018-10-11 23:30:00                        0          1
#  810     2018-10-11 23:30:00                        0          1
#  870     2018-10-11 23:30:00                        0          1
#
# [4929 rows x 15 columns]

# %%
plot_event_study(panel_df, quantiles=(.1,.9), title='New Tweets w/o Exposure')
plt.show()
plot_event_study(panel_df, cat='regular', quantiles=(.1,.9), title='All New Tweets')
plt.show()
plot_event_study(panel_df, cat='total_engagement', quantiles=(.1,.9))

# %% [markdown]
# ## Moving the Treatment

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='5Min',
                          cutoff_choice='best', include_missing=False, periods=6)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
        
panel_df = pd.concat(dfs)

# %%
plot_event_study(panel_df, quantiles=(.1,.9), title='New Tweets w/o Exposure')
plt.show()
plot_event_study(panel_df, cat='regular', quantiles=(.1,.9), title='All New Tweets')
plt.show()
plot_event_study(panel_df, cat='total_engagement', quantiles=(.1,.9))

# %%
# biggest increase over 30 minutes
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
query = query.dropna()
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.491</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.211</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >2.330</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.020</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.078</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.904</td>
#             </tr>
#             <tr>
#                         <th id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.000</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.037</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.970</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.010</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.010</td>
#             </tr>
#             <tr>
#                         <th id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.349</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.246</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >5.484</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.867</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.831</td>
#             </tr>
#             <tr>
#                         <th id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.024</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-3.333</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.001</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.038</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.010</td>
#             </tr>
#             <tr>
#                         <th id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.081</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >224.210</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.072</td>
#                         <td id="T_ac0becaa_5ffa_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.091</td>
#             </tr>
#     </tbody></table>
# लक्ष्य_हमारा_मोदी_दोबारा

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='5Min',
                          cutoff_choice='best', include_missing=False, periods=12)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
        
panel_df = pd.concat(dfs)

# %%
plot_event_study(panel_df, quantiles=(.1,.9), title='New Tweets w/o Exposure')
plt.show()
plot_event_study(panel_df, cat='regular', quantiles=(.1,.9), title='All New Tweets')
plt.show()
plot_event_study(panel_df, cat='total_engagement', quantiles=(.1,.9))

# %%
# biggest increase over 60 minutes
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
query = query.dropna()
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col0 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col1 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col2 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col3 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col4 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col5 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.925</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.215</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >4.299</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.000</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.503</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >1.346</td>
#             </tr>
#             <tr>
#                         <th id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.011</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >2.173</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.030</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >0.001</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.020</td>
#             </tr>
#             <tr>
#                         <th id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.083</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.248</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >4.364</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.597</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.569</td>
#             </tr>
#             <tr>
#                         <th id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.038</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-5.314</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.000</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.052</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.024</td>
#             </tr>
#             <tr>
#                         <th id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.076</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >219.413</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.066</td>
#                         <td id="T_1baf3d6e_5ffb_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.085</td>
#             </tr>
#     </tbody></table>
# लक्ष्य_हमारा_मोदी_दोबारा

# %%
dfs = []
for hashtag, tweet_dict in campaigns.items():
    if hashtag not in preprocessing.bandwagon_hashtags and hashtag not in preprocessing.never_trended:
        temp, _ = build_df(hashtag, tweet_dict, exposures, normalize_time=True, time_bin='5Min',
                          cutoff_choice='best', include_missing=False, periods=4)
        temp = temp.assign(threshold=(temp.time > 0).astype(int))
        temp['hashtag'] = hashtag
        dfs.append(temp)
        
panel_df = pd.concat(dfs)

# %%
plot_event_study(panel_df, quantiles=(.1,.9), title='New Tweets w/o Exposure')
plt.show()
plot_event_study(panel_df, cat='regular', quantiles=(.1,.9), title='All New Tweets')
plt.show()
plot_event_study(panel_df, cat='total_engagement', quantiles=(.1,.9))

# %%
# biggest increase over 20 minutes
query = panel_df.query('time >= -60 & time <= 60').fillna(0)
query = query.dropna()
mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
temp_df = mod.summary().tables[1].drop('Group Var')
temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
trending.highlight_reg_output(temp_df)
print(query.hashtag.max())
# Out:
# <style  type="text/css" >
#     #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.553</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.205</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >2.694</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.007</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.151</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.956</td>
#             </tr>
#             <tr>
#                         <th id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.004</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.703</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.482</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.006</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.013</td>
#             </tr>
#             <tr>
#                         <th id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.455</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.247</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >5.896</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.971</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.938</td>
#             </tr>
#             <tr>
#                         <th id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.032</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-4.431</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.000</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.046</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.018</td>
#             </tr>
#             <tr>
#                         <th id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.080</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >220.176</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.070</td>
#                         <td id="T_a39a87b8_5ffd_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.089</td>
#             </tr>
#     </tbody></table>
# लक्ष्य_हमारा_मोदी_दोबारा

# %%
temp = panel_df

# %%
for cutoff in range(-30, 31, 5):
    temp = panel_df.assign(threshold=(panel_df.time >= cutoff).astype(int))
    x,y = -60 + cutoff, 60 + cutoff
    query = temp.query(f'time >= {x} & time <= {y}').fillna(0)
    query = query.dropna()
    mod = smf.mixedlm("regular ~ time*threshold + nonzero_exposure_regular", data=query, groups=query['hashtag']).fit()#cov_type='cluster', cov_kwds={'groups': query['hashtag']})
    temp_df = mod.summary().tables[1].drop('Group Var')
    temp_df = temp_df.loc[~temp_df.index.str.startswith('C', na=False)]
    print('cutoff shifted to :' , cutoff)
    trending.highlight_reg_output(temp_df)
# Out:
# cutoff shifted to : -30
# <style  type="text/css" >
#     #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_161a2632_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_161a2632_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.418</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.406</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.031</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.303</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.377</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >1.213</td>
#             </tr>
#             <tr>
#                         <th id="T_161a2632_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.002</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.006</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.279</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.780</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.010</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.014</td>
#             </tr>
#             <tr>
#                         <th id="T_161a2632_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >0.480</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.398</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >1.205</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.228</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >-0.300</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.259</td>
#             </tr>
#             <tr>
#                         <th id="T_161a2632_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >0.016</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.008</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >2.055</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.040</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >0.001</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.031</td>
#             </tr>
#             <tr>
#                         <th id="T_161a2632_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.087</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.006</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >185.692</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.076</td>
#                         <td id="T_161a2632_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.099</td>
#             </tr>
#     </tbody></table>
# cutoff shifted to : -25
# <style  type="text/css" >
#     #T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.432</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.370</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.165</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.244</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.295</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >1.158</td>
#             </tr>
#             <tr>
#                         <th id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.002</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.006</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.404</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.686</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.010</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.014</td>
#             </tr>
#             <tr>
#                         <th id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >0.429</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.363</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >1.183</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.237</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >-0.282</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.140</td>
#             </tr>
#             <tr>
#                         <th id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >0.005</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.008</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >0.608</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.543</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.010</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.020</td>
#             </tr>
#             <tr>
#                         <th id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.087</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.006</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >194.297</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.076</td>
#                         <td id="T_164e5e70_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.098</td>
#             </tr>
#     </tbody></table>
# cutoff shifted to : -20
# <style  type="text/css" >
#     #T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.382</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.338</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.131</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.258</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.280</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >1.045</td>
#             </tr>
#             <tr>
#                         <th id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.002</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.006</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.291</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.771</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.010</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.014</td>
#             </tr>
#             <tr>
#                         <th id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >0.540</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.332</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >1.628</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.103</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >-0.110</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.191</td>
#             </tr>
#             <tr>
#                         <th id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.003</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.008</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-0.381</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.703</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.018</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.012</td>
#             </tr>
#             <tr>
#                         <th id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.086</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >202.432</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.076</td>
#                         <td id="T_1684fe1c_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.097</td>
#             </tr>
#     </tbody></table>
# cutoff shifted to : -15
# <style  type="text/css" >
#     #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.370</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.311</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.190</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.234</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.239</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.978</td>
#             </tr>
#             <tr>
#                         <th id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.001</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.006</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >0.153</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.878</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.011</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.013</td>
#             </tr>
#             <tr>
#                         <th id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >0.708</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.307</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >2.307</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.021</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.107</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.310</td>
#             </tr>
#             <tr>
#                         <th id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.008</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-1.059</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.290</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.023</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.007</td>
#             </tr>
#             <tr>
#                         <th id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.082</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >210.005</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.072</td>
#                         <td id="T_16b8c0e4_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.092</td>
#             </tr>
#     </tbody></table>
# cutoff shifted to : -10
# <style  type="text/css" >
#     #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.305</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.281</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.086</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.277</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.246</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.856</td>
#             </tr>
#             <tr>
#                         <th id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >-0.001</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.006</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >-0.118</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.906</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.012</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.011</td>
#             </tr>
#             <tr>
#                         <th id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.029</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.283</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >3.631</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.474</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.585</td>
#             </tr>
#             <tr>
#                         <th id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.014</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-1.842</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.066</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.028</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >0.001</td>
#             </tr>
#             <tr>
#                         <th id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.079</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >213.900</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.069</td>
#                         <td id="T_16eb232c_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.089</td>
#             </tr>
#     </tbody></table>
# cutoff shifted to : -5
# <style  type="text/css" >
#     #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_171e1516_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_171e1516_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.205</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.255</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >0.801</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.423</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.296</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.705</td>
#             </tr>
#             <tr>
#                         <th id="T_171e1516_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >-0.004</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.006</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >-0.617</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.537</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.015</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.008</td>
#             </tr>
#             <tr>
#                         <th id="T_171e1516_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.380</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.267</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >5.166</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.856</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.903</td>
#             </tr>
#             <tr>
#                         <th id="T_171e1516_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.017</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-2.381</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.017</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.032</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.003</td>
#             </tr>
#             <tr>
#                         <th id="T_171e1516_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.081</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >215.934</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.071</td>
#                         <td id="T_171e1516_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.091</td>
#             </tr>
#     </tbody></table>
# cutoff shifted to : 0
# <style  type="text/css" >
#     #T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_17516556_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17516556_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.348</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.232</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.498</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.134</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.107</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.802</td>
#             </tr>
#             <tr>
#                         <th id="T_17516556_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >-0.001</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.006</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >-0.214</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.830</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.012</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.010</td>
#             </tr>
#             <tr>
#                         <th id="T_17516556_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.482</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.253</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >5.846</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >0.985</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >1.979</td>
#             </tr>
#             <tr>
#                         <th id="T_17516556_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.023</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-3.169</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.002</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.037</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.009</td>
#             </tr>
#             <tr>
#                         <th id="T_17516556_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.079</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >218.349</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.070</td>
#                         <td id="T_17516556_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.089</td>
#             </tr>
#     </tbody></table>
# cutoff shifted to : 5
# <style  type="text/css" >
#     #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >0.400</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.209</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >1.918</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.055</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >-0.009</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >0.809</td>
#             </tr>
#             <tr>
#                         <th id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >-0.001</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >-0.174</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.862</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >-0.012</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.010</td>
#             </tr>
#             <tr>
#                         <th id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >1.875</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.246</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >7.620</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.000</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >1.393</td>
#                         <td id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >2.357</td>
#             </tr>
#             <tr>
#                         <th id="T_1921dc30_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
# ...
#             </tr>
#     </tbody></table>
# cutoff shifted to : 25
# <style  type="text/css" >
#     #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col0 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col1 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col2 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col3 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col4 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col5 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >1.329</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.162</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >8.205</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.000</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >1.012</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >1.647</td>
#             </tr>
#             <tr>
#                         <th id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.037</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >7.485</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.000</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >0.027</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.047</td>
#             </tr>
#             <tr>
#                         <th id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >-0.551</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.253</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >-2.178</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.029</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >-1.046</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >-0.055</td>
#             </tr>
#             <tr>
#                         <th id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.036</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.006</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-5.610</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.000</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.049</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.024</td>
#             </tr>
#             <tr>
#                         <th id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.068</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >235.979</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.059</td>
#                         <td id="T_19e87afc_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.077</td>
#             </tr>
#     </tbody></table>
# cutoff shifted to : 30
# <style  type="text/css" >
#     #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col0 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col1 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col2 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col3 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col4 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col5 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col0 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col1 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col2 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col3 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col4 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col5 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col0 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col1 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col2 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col3 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col4 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col5 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col0 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col1 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col2 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col3 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col4 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col5 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col0 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col1 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col2 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col3 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col4 {
#             background-color:  yellow;
#         }    #T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col5 {
#             background-color:  yellow;
#         }</style><table id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coef.</th>        <th class="col_heading level0 col1" >Std.Err.</th>        <th class="col_heading level0 col2" >z</th>        <th class="col_heading level0 col3" >P>|z|</th>        <th class="col_heading level0 col4" >[0.025</th>        <th class="col_heading level0 col5" >0.975]</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116alevel0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col0" class="data row0 col0" >1.203</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col1" class="data row0 col1" >0.160</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col2" class="data row0 col2" >7.521</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col3" class="data row0 col3" >0.000</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col4" class="data row0 col4" >0.890</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow0_col5" class="data row0 col5" >1.517</td>
#             </tr>
#             <tr>
#                         <th id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116alevel0_row1" class="row_heading level0 row1" >time</th>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col0" class="data row1 col0" >0.030</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col1" class="data row1 col1" >0.005</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col2" class="data row1 col2" >6.076</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col3" class="data row1 col3" >0.000</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col4" class="data row1 col4" >0.021</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow1_col5" class="data row1 col5" >0.040</td>
#             </tr>
#             <tr>
#                         <th id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116alevel0_row2" class="row_heading level0 row2" >threshold</th>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col0" class="data row2 col0" >-0.558</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col1" class="data row2 col1" >0.272</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col2" class="data row2 col2" >-2.049</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col3" class="data row2 col3" >0.040</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col4" class="data row2 col4" >-1.092</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow2_col5" class="data row2 col5" >-0.024</td>
#             </tr>
#             <tr>
#                         <th id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116alevel0_row3" class="row_heading level0 row3" >time:threshold</th>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col0" class="data row3 col0" >-0.028</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col1" class="data row3 col1" >0.007</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col2" class="data row3 col2" >-4.247</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col3" class="data row3 col3" >0.000</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col4" class="data row3 col4" >-0.040</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow3_col5" class="data row3 col5" >-0.015</td>
#             </tr>
#             <tr>
#                         <th id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116alevel0_row4" class="row_heading level0 row4" >nonzero_exposure_regular</th>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col0" class="data row4 col0" >1.068</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col1" class="data row4 col1" >0.005</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col2" class="data row4 col2" >230.163</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col3" class="data row4 col3" >0.000</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col4" class="data row4 col4" >1.058</td>
#                         <td id="T_1a17675e_5ff8_11eb_a1cb_000af7c1116arow4_col5" class="data row4 col5" >1.077</td>
#             </tr>
#     </tbody></table>

# %%
hashtag = 'jharkhandwithmodi'
tweets = campaigns[hashtag]
_ = build_df(hashtag, tweets, exposures, normalize_time=False, time_bin='5Min',
                          cutoff_choice='best', include_missing=False, periods=1)

# %%
list(tweets.values())[0]
# Out:
# {'username': 'bjp4latehar',
#  'id': '1172033856607682560',
#  'retweet_from': '',
#  'template': '',
#  'retweet_id': '',
#  'text': 'आधारभूत संरचना हो या शिक्षा या फिर स्वच्छता या जल शक्ति अभियान, झारखण्ड के जिले लगातार सबसे ऊंचे पायदान पर अपनी उपस्थिति दर्ज करवा रहे हैं। #jharkhandwithmodi',
#  'date': datetime.datetime(2019, 9, 12, 6, 27, 1),
#  'retweets': 0,
#  'favorites': 0,
#  'adj_date': datetime.datetime(2019, 9, 12, 11, 57, 1),
#  'type': 'regular',
#  'template_exposure': 151,
#  'normal_exposure': 64,
#  'total_exposure': 215,
#  'follower_data': True}

# %%
hashtag = 'jharkhandwithmodi'
tweets = campaigns[hashtag]

# %%
import sys
# !conda install --yes --prefix {sys.prefix} -c conda-forge tabulate
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /home/jschless/.conda/envs/gt:
#
# The following NEW packages will be INSTALLED:
#
#     tabulate: 0.8.7-pyh9f0ad1d_0 conda-forge
#
# tabulate-0.8.7 100% |################################| Time: 0:00:02  10.26 kB/s
